# %%
import sys, os
sys.path.append('../../../libs/')
import os.path
import IO_class
from IO_class import FileOperator
from sklearn import cross_validation
import sklearn
import numpy as np
import csv
from dateutil import parser
from datetime import timedelta
from sklearn import svm
import numpy as np
import pandas as pd
import pdb
import pickle
import numpy as np
from sklearn.cross_validation import train_test_split
from sklearn import preprocessing
import sklearn
import scipy.stats as ss
from sklearn.svm import LinearSVC
import random
from DL_libs import *
from itertools import izip #new
import math
# Out:
# /usr/local/lib/python2.7/dist-packages/scipy/spatial/__init__.py:91: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility
#   from .qhull import *
# /usr/local/lib/python2.7/dist-packages/scipy/spatial/__init__.py:91: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility
#   from .qhull import *
# /usr/local/lib/python2.7/dist-packages/scipy/lib/_util.py:35: DeprecationWarning: Module scipy.linalg.blas.fblas is deprecated, use scipy.linalg.blas instead
#   DeprecationWarning)

# %%
#filename = 'SUCCESS_log_CrossValidation_load_DL_remoteFisherM1_DL_RE_US_DL_RE_US_1_1_19MAY2014.txt'
filename = 'listOfDDIsHaveOver2InterfacesHave40-75_Examples_2010_real_selected.txt' #for testing
#filename = 'list_of_SUCCESS_log_run3DID_STAT_200_275_examples_201001MAY2014.txt'
file_obj = FileOperator(filename)
ddis = file_obj.readStripLines()
import logging
import time
current_date = time.strftime("%m_%d_%Y")

logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)

logname = 'log_DL_contact_matrix_load' + current_date + '.log'
handler = logging.FileHandler(logname)
handler.setLevel(logging.DEBUG)

# create a logging format

formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

# add the handlers to the logger

logger.addHandler(handler)

logger.info('Input DDI file: ' + filename)
#logger.debug('This message should go to the log file')
# Out:
# INFO:__main__:Input DDI file: listOfDDIsHaveOver2InterfacesHave40-75_Examples_2010_real_selected.txt
# number of lines in listOfDDIsHaveOver2InterfacesHave40-75_Examples_2010_real_selected.txt:37

# %%
ddis
# Out:
# ['6PGD_int_NAD_binding_2',
#  'Activin_recp_int_TGF_beta',
#  'ADSL_C_int_Lyase_1',
#  'AICARFT_IMPCHas_int_MGS',
#  'AIRS_int_AIRS_C',
#  'Ald_Xan_dh_C_int_FAD_binding_5',
#  'Alpha-amylase_int_CBM_48',
#  'AMNp_N_int_PNP_UDP_1',
#  'ARPC4_int_WD40',
#  'CagX_int_TrbI',
#  'Cation_ATPase_C_int_E1-E2_ATPase',
#  'Ca_chan_IQ_int_efhand',
#  'CBM_20_int_Glyco_hydro_14',
#  'Cytochrom_B_C_int_Rieske',
#  'Cytochrom_B_N_int_UCR_14kD',
#  'Cytochrom_B_N_int_UCR_Fe-S_N',
#  'Dioxygenase_C_int_Dioxygenase_N',
#  'E1-E2_ATPase_int_Hydrolase',
#  'EFG_C_int_GTP_EFTU',
#  'efhand_int_IQ',
#  'efhand_int_Troponin',
#  'Fapy_DNA_glyco_int_H2TH',
#  'Fer4_NifH_int_Oxidored_nitro',
#  'FGF_int_I-set',
#  'FumaraseC_C_int_Lyase_1',
#  'Furin-like_int_Recep_L_domain',
#  'Glyco_hydro_10_int_Ricin_B_lectin',
#  'GP120_int_ig',
#  'H2TH_int_zf-FPG_IleRS',
#  'Ion_trans_2_int_V-set',
#  'JmjC_int_JmjN',
#  'Kringle_int_PAN_1',
#  'MDH_int_PQQ',
#  'PA_int_Peptidase_M28',
#  'Peptidase_M28_int_TFR_dimer',
#  'Photo_RC_int_PSII',
#  'Stathmin_int_Tubulin']

# %%
class DDI_family_base(object):
    def __init__(self, ddi, Vectors_Fishers_aaIndex_raw_folder = '/home/du/Documents/Vectors_Fishers_aaIndex_raw_2014/'):
    #def __init__(self, ddi, Vectors_Fishers_aaIndex_raw_folder = '/home/sun/Downloads/contactmatrix/contactmatrixanddeeplearningcode/data_test/'):
    #def __init__(self, ddi, Vectors_Fishers_aaIndex_raw_folder = '/big/du/Protein_Protein_Interaction_Project/Contact_Matrix_Project/Vectors_Fishers_aaIndex_raw_2014/'):
        """ get total number of sequences in a ddi familgy
        Attributes:
            ddi: string ddi name
            Vectors_Fishers_aaIndex_raw_folder: string, folder
            total_number_of_sequences: int
            raw_data: dict raw_data[2]
        LOO_data['FisherM1'][1]

        """
        self.ddi = ddi
        self.Vectors_Fishers_aaIndex_raw_folder = Vectors_Fishers_aaIndex_raw_folder
        self.ddi_folder = self.Vectors_Fishers_aaIndex_raw_folder + ddi + '/'
        self.total_number_of_sequences = self.get_total_number_of_sequences()
        self.raw_data = {}
        self.positve_negative_number = {}
        self.equal_size_data = {}
        for seq_no in range(1, self.total_number_of_sequences+1):
            self.raw_data[seq_no] = self.get_raw_data_for_selected_seq(seq_no)
            try:
                #positive_file = self.ddi_folder + 'numPos_'+ str(seq_no) + '.txt'
                #file_obj = FileOperator(positive_file)
                #lines = file_obj.readStripLines()
                #import pdb; pdb.set_trace()
                count_pos = int(np.sum(self.raw_data[seq_no][:, -1]))
                count_neg = self.raw_data[seq_no].shape[0] - count_pos
                #self.positve_negative_number[seq_no] = {'numPos': int(float(lines[0]))}
                #assert int(float(lines[0])) == count_pos
                self.positve_negative_number[seq_no] = {'numPos': count_pos}
                #negative_file = self.ddi_folder + 'numNeg_'+ str(seq_no) + '.txt'
                #file_obj = FileOperator(negative_file)
                #lines = file_obj.readStripLines()
                #self.positve_negative_number[seq_no]['numNeg'] =  int(float(lines[0]))
                self.positve_negative_number[seq_no]['numNeg'] =  count_neg
            except Exception,e:
                print ddi, seq_no
                print str(e)
                logger.info(ddi + str(seq_no))
                logger.info(str(e))                
            # get data for equal positive and negative
            n_pos = self.positve_negative_number[seq_no]['numPos']
            n_neg = self.positve_negative_number[seq_no]['numNeg']
            index_neg = range(n_pos, n_pos + n_neg)
            random.shuffle(index_neg)
            index_neg = index_neg[: n_pos]
            positive_examples = self.raw_data[seq_no][ : n_pos, :]
            negative_examples = self.raw_data[seq_no][index_neg, :]
            self.equal_size_data[seq_no] = np.vstack((positive_examples, negative_examples))
    def get_LOO_training_and_reduced_traing(self, seq_no, fisher_mode = 'FisherM1ONLY' , reduce_ratio = 4):
        """ get the leave one out traing data, reduced traing
        Parameters:
            seq_no: 
            fisher_mode: default 'FisherM1ONLY'
        Returns:
            (train_X_LOO, train_y_LOO),(train_X_reduced, train_y_reduced),  (test_X, test_y)
        """
        train_X_LOO = np.array([])
        train_y_LOO = np.array([])
        train_X_reduced = np.array([])
        train_y_reduced = np.array([])

        total_number_of_sequences = self.total_number_of_sequences
        equal_size_data_selected_sequence = self.equal_size_data[seq_no]
        
        #get test data for selected sequence
        test_X, test_y = self.select_X_y(equal_size_data_selected_sequence, fisher_mode = fisher_mode)
        total_sequences = range(1, total_number_of_sequences+1)
        loo_sequences = [i for i in total_sequences if i != seq_no]
        number_of_reduced = len(loo_sequences)/reduce_ratio if len(loo_sequences)/reduce_ratio !=0 else 1
        random.shuffle(loo_sequences)
        reduced_sequences = loo_sequences[:number_of_reduced]

        #for loo data
        for current_no in loo_sequences:
            raw_current_data = self.equal_size_data[current_no]
            current_X, current_y = self.select_X_y(raw_current_data, fisher_mode = fisher_mode)
            if train_X_LOO.ndim ==1:
                train_X_LOO = current_X
            else:
                train_X_LOO = np.vstack((train_X_LOO, current_X))
            train_y_LOO = np.concatenate((train_y_LOO, current_y))

        #for reduced data
        for current_no in reduced_sequences:
            raw_current_data = self.equal_size_data[current_no]
            current_X, current_y = self.select_X_y(raw_current_data, fisher_mode = fisher_mode)
            if train_X_reduced.ndim ==1:
                train_X_reduced = current_X
            else:
                train_X_reduced = np.vstack((train_X_reduced, current_X))
            train_y_reduced = np.concatenate((train_y_reduced, current_y))                

        return (train_X_LOO, train_y_LOO),(train_X_reduced, train_y_reduced), (test_X, test_y)
        
    def get_ten_fold_crossvalid_one_subset(self, start_subset, end_subset, fisher_mode = 'FisherM1ONLY' , reduce_ratio = 4):
        """ get traing data, reduced traing data for 10-fold crossvalidation
        Parameters:
            start_subset: index of start of the testing data
            end_subset: index of end of the testing data
            fisher_mode: default 'FisherM1ONLY'
        Returns:
            (train_X_10fold, train_y_10fold),(train_X_reduced, train_y_reduced),  (test_X, test_y)
        """
        train_X_10fold = np.array([])
        train_y_10fold = np.array([])
        train_X_reduced = np.array([])
        train_y_reduced = np.array([])
        test_X = np.array([])
        test_y = np.array([])

        total_number_of_sequences = self.total_number_of_sequences
        
        #get test data for selected sequence
        for current_no in range(start_subset, end_subset):
            raw_current_data = self.equal_size_data[current_no]
            current_X, current_y = self.select_X_y(raw_current_data, fisher_mode = fisher_mode)
            if test_X.ndim ==1:
                test_X = current_X
            else:
                test_X = np.vstack((test_X, current_X))
            test_y = np.concatenate((test_y, current_y))
        
        total_sequences = range(1, total_number_of_sequences+1)
        ten_fold_sequences = [i for i in total_sequences if not(i in range(start_subset, end_subset))]
        number_of_reduced = len(ten_fold_sequences)/reduce_ratio if len(ten_fold_sequences)/reduce_ratio !=0 else 1
        random.shuffle(ten_fold_sequences)
        reduced_sequences = ten_fold_sequences[:number_of_reduced]

        #for 10-fold cross-validation data
        for current_no in ten_fold_sequences:
            raw_current_data = self.equal_size_data[current_no]
            current_X, current_y = self.select_X_y(raw_current_data, fisher_mode = fisher_mode)
            if train_X_10fold.ndim ==1:
                train_X_10fold = current_X
            else:
                train_X_10fold = np.vstack((train_X_10fold, current_X))
            train_y_10fold = np.concatenate((train_y_10fold, current_y))

        #for reduced data
        for current_no in reduced_sequences:
            raw_current_data = self.equal_size_data[current_no]
            current_X, current_y = self.select_X_y(raw_current_data, fisher_mode = fisher_mode)
            if train_X_reduced.ndim ==1:
                train_X_reduced = current_X
            else:
                train_X_reduced = np.vstack((train_X_reduced, current_X))
            train_y_reduced = np.concatenate((train_y_reduced, current_y))                

        return (train_X_10fold, train_y_10fold),(train_X_reduced, train_y_reduced), (test_X, test_y)
        
    def get_total_number_of_sequences(self):
        """ get total number of sequences in a ddi familgy
        Parameters:
            ddi: string
            Vectors_Fishers_aaIndex_raw_folder: string
        Returns:
            n: int
        """
        folder_path = self.Vectors_Fishers_aaIndex_raw_folder + self.ddi + '/' 
        filename = folder_path +'allPairs.txt'
        all_pairs = np.loadtxt(filename)
        return len(all_pairs)

    def get_raw_data_for_selected_seq(self, seq_no):
        """ get raw data for selected seq no in a family
        Parameters:
            ddi: 
            seq_no: 
        Returns:
            data: raw data in the sequence file
        """
        folder_path = self.Vectors_Fishers_aaIndex_raw_folder + self.ddi + '/' 
        filename = folder_path + 'F0_20_F1_20_Sliding_17_11_F0_20_F1_20_Sliding_17_11_ouput_'+ str(seq_no) + '.txt'
        data = np.loadtxt(filename)
        return data
    def select_X_y(self, data, fisher_mode = ''):
        """ select subset from the raw input data set
        Parameters:
            data: data from matlab txt file
            fisher_mode: subset base on this Fisher of AAONLY...
        Returns:
            selected X,  y
        """
        y = data[:,-1] # get lable
        if fisher_mode == 'FisherM1': # fisher m1 plus AA index
            a = data[:, 20:227]
            b = data[:, 247:454]
            X = np.hstack((a,b))
        elif fisher_mode == 'FisherM1ONLY': 
            a = data[:, 20:40]
            b = data[:, 247:267]
            X = np.hstack((a,b))
        elif fisher_mode == 'AAONLY':
            a = data[:, 40:227]
            b = data[:, 267:454]
            X = np.hstack((a,b))
        else:
            raise('there is an error in mode')
        return X, y

# %%
import sklearn.preprocessing
class Precessing_Scaler_0_9(sklearn.preprocessing.StandardScaler):
    def __init__(self):
        super(Precessing_Scaler_0_9, self).__init__(self, with_std=0.333)
    def transform(self, X): # transform data to 0.1 to 0.9
        new_X = super(Precessing_Scaler_0_9, self).transform(X)
        print 
        new_X[new_X > 1] = 1
        new_X[new_X < -1] = -1
        new_X = (new_X + 1) * 0.4 + 0.1
        return new_X
    def fit_transform(self):
        print 'Did not implement'
def performance_score(target_label, predicted_label, predicted_score = False, print_report = True): 
    """ get performance matrix for prediction
        Attributes:
            target_label: int 0, 1
            predicted_label: 0, 1 or ranking
            predicted_score: bool if False, predicted_label is from 0, 1. If Ture, predicted_label is ranked, need to get AUC score.
            print_report: if True, print the perfromannce on screen
    """
    import sklearn
    from sklearn.metrics import roc_auc_score
    score = {}
    if predicted_score == False:
        score['accuracy'] = sklearn.metrics.accuracy_score(target_label, predicted_label)
        score['precision'] = sklearn.metrics.precision_score(target_label, predicted_label, pos_label=1)
        score['recall'] = sklearn.metrics.recall_score(target_label, predicted_label, pos_label=1)
    if predicted_score == True:
        auc_score  = roc_auc_score(target_label, predicted_label)
        score['auc_score'] = auc_score
        target_label = [x >= 0.5 for x in target_label]
        score['accuracy'] = sklearn.metrics.accuracy_score(target_label, predicted_label)
        score['precision'] = sklearn.metrics.precision_score(target_label, predicted_label, pos_label=1)
        score['recall'] = sklearn.metrics.recall_score(target_label, predicted_label, pos_label=1)
    if print_report == True:
        for key, value in score.iteritems():
            print key, '{percent:.1%}'.format(percent=value)
    return score

def saveAsCsv(predicted_score, fname, score_dict, *arguments): #new
    newfile = False
    if os.path.isfile(fname + '_report.csv'):
        pass
    else:
        newfile = True
    csvfile = open(fname + '_report.csv', 'a+')
    writer = csv.writer(csvfile)
    if newfile == True:
        if predicted_score == False:
            writer.writerow(['DDI', 'no.', 'FisherMode', 'method', 'isTest']+ score_dict.keys()) #, 'AUC'])
        else:
            writer.writerow(['DDI', 'no.', 'FisherMode', 'method', 'isTest'] + score_dict.keys())
    for arg in arguments:        
        writer.writerows(arg)
    csvfile.close()

def LOO_out_performance_for_all(ddis):
    for ddi in ddis:
        try:
            one_ddi_family = LOO_out_performance_for_one_ddi(ddi)
            one_ddi_family.get_LOO_perfermance('FisherM1', '')
        except Exception,e:
            print str(e)
            logger.info("There is a error in this ddi: %s" % ddi)
            logger.info(str(e))

        
class LOO_out_performance_for_one_ddi(object):
        """ get the performance of ddi families
        Attributes:
            ddi: string ddi name
            Vectors_Fishers_aaIndex_raw_folder: string, folder
            total_number_of_sequences: int
            raw_data: dict raw_data[2]

        """
        def __init__(self, ddi):
            self.ddi_obj = DDI_family_base(ddi)
            self.ddi = ddi

        def get_LOO_perfermance(self, fisher_mode, settings = None):
            analysis_scr = []
            predicted_score = False
            reduce_ratio = 1
            for seq_no in range(1, self.ddi_obj.total_number_of_sequences+1):
                print seq_no
                logger.info('sequence number: ' + str(seq_no))
                if 1:
                    print "SVM"
                    (train_X_LOO, train_y_LOO),(train_X_reduced, train_y_reduced), (test_X, test_y) = self.ddi_obj.get_LOO_training_and_reduced_traing(seq_no, reduce_ratio = reduce_ratio)
                    standard_scaler = preprocessing.StandardScaler().fit(train_X_reduced)
                    scaled_train_X = standard_scaler.transform(train_X_reduced)
                    scaled_test_X = standard_scaler.transform(test_X)
                    Linear_SVC = LinearSVC(C=1, penalty="l2")
                    Linear_SVC.fit(scaled_train_X, train_y_reduced)
                    predicted_test_y = Linear_SVC.predict(scaled_test_X)
                    isTest = True; #new
                    analysis_scr.append((self.ddi, seq_no, fisher_mode, 'SVM', isTest) + tuple(performance_score(test_y, predicted_test_y).values())) #new

                    predicted_train_y = Linear_SVC.predict(scaled_train_X)
                    isTest = False; #new
                    analysis_scr.append((self.ddi, seq_no, fisher_mode, 'SVM', isTest) + tuple(performance_score(train_y_reduced, predicted_train_y).values()))
                # Deep learning part
                min_max_scaler = Precessing_Scaler_0_9()
                X_train_pre_validation_minmax = min_max_scaler.fit(train_X_reduced)
                X_train_pre_validation_minmax = min_max_scaler.transform(train_X_reduced)
                x_test_minmax = min_max_scaler.transform(test_X)
                pretraining_X_minmax = min_max_scaler.transform(train_X_LOO)
                x_train_minmax, x_validation_minmax, y_train_minmax, y_validation_minmax = train_test_split(X_train_pre_validation_minmax, 
                                                                                                  train_y_reduced
                                                                    , test_size=0.4, random_state=42)
                finetune_lr = 1
                batch_size = 100
                pretraining_epochs = cal_epochs(1500, x_train_minmax, batch_size = batch_size)
                #pretrain_lr=0.001
                pretrain_lr = 0.001
                training_epochs = 1500
                hidden_layers_sizes= [100, 100]
                corruption_levels = [0,0]
                if 1:
                    print "direct deep learning"
                    # direct deep learning 
                    sda = trainSda(x_train_minmax, y_train_minmax,
                                 x_validation_minmax, y_validation_minmax , 
                                 x_test_minmax, test_y,
                                 hidden_layers_sizes = hidden_layers_sizes, corruption_levels = corruption_levels, batch_size = batch_size , \
                                 training_epochs = training_epochs, pretraining_epochs = pretraining_epochs, 
                                 pretrain_lr = pretrain_lr, finetune_lr=finetune_lr
                     )
                    print 'hidden_layers_sizes:', hidden_layers_sizes
                    print 'corruption_levels:', corruption_levels
                    training_predicted = sda.predict(x_train_minmax)
                    y_train = y_train_minmax
                    isTest = False; #new
                    analysis_scr.append((self.ddi, seq_no, fisher_mode, 'DL', isTest) + tuple(performance_score(y_train, training_predicted).values()))

                    test_predicted = sda.predict(x_test_minmax)
                    y_test = test_y
                    isTest = True; #new
                    analysis_scr.append((self.ddi, seq_no, fisher_mode, 'DL', isTest) + tuple(performance_score(y_test, test_predicted).values()))

                if 0:
                    # deep learning using unlabeled data for pretraining
                    print 'deep learning with unlabel data'
                    pretraining_epochs_for_reduced = cal_epochs(1500, pretraining_X_minmax, batch_size = batch_size)
                    sda_unlabel = trainSda(x_train_minmax, y_train_minmax,
                                 x_validation_minmax, y_validation_minmax , 
                                 x_test_minmax, test_y, 
                                 pretraining_X_minmax = pretraining_X_minmax,
                                 hidden_layers_sizes = hidden_layers_sizes, corruption_levels = corruption_levels, batch_size = batch_size , \
                                 training_epochs = training_epochs, pretraining_epochs = pretraining_epochs_for_reduced, 
                                 pretrain_lr = pretrain_lr, finetune_lr=finetune_lr
                     )
                    print 'hidden_layers_sizes:', hidden_layers_sizes
                    print 'corruption_levels:', corruption_levels
                    training_predicted = sda_unlabel.predict(x_train_minmax)
                    y_train = y_train_minmax
                    isTest = False; #new
                    analysis_scr.append((self.ddi, seq_no, fisher_mode, 'DL_U', isTest) + tuple(performance_score(y_train, training_predicted, predicted_score).values()))

                    test_predicted = sda_unlabel.predict(x_test_minmax)
                    y_test = test_y

                    isTest = True; #new
                    analysis_scr.append((self.ddi, seq_no, fisher_mode, 'DL_U', isTest) + tuple(performance_score(y_test, test_predicted, predicted_score).values()))
                if 1:
                    # deep learning using split network
                    print 'deep learning using split network'
                    # get the new representation for A set. first 784-D
                    pretraining_epochs=1500
                    hidden_layers_sizes =[50, 50]
                    corruption_levels=[0, 0]
                    
                    x = x_train_minmax[:, :x_train_minmax.shape[1]/2]
                    print "original shape for A", x.shape
                    a_MAE_A = train_a_MultipleAEs(x, pretraining_epochs=pretraining_epochs, pretrain_lr=pretrain_lr, batch_size=batch_size, 
                                            hidden_layers_sizes =hidden_layers_sizes, corruption_levels=corruption_levels)
                    new_x_train_minmax_A =  a_MAE_A.transform(x_train_minmax[:, :x_train_minmax.shape[1]/2])
                    x = x_train_minmax[:, x_train_minmax.shape[1]/2:]
                    
                    print "original shape for B", x.shape
                    a_MAE_B = train_a_MultipleAEs(x, pretraining_epochs=pretraining_epochs, pretrain_lr=pretrain_lr, batch_size=batch_size, 
                                            hidden_layers_sizes =hidden_layers_sizes, corruption_levels=corruption_levels)
                    new_x_train_minmax_B =  a_MAE_B.transform(x_train_minmax[:, x_train_minmax.shape[1]/2:])
                    
                    new_x_test_minmax_A = a_MAE_A.transform(x_test_minmax[:, :x_test_minmax.shape[1]/2])
                    new_x_test_minmax_B = a_MAE_B.transform(x_test_minmax[:, x_test_minmax.shape[1]/2:])
                    new_x_validation_minmax_A = a_MAE_A.transform(x_validation_minmax[:, :x_validation_minmax.shape[1]/2])
                    new_x_validation_minmax_B = a_MAE_B.transform(x_validation_minmax[:, x_validation_minmax.shape[1]/2:])
                    new_x_train_minmax_whole = np.hstack((new_x_train_minmax_A, new_x_train_minmax_B))
                    new_x_test_minmax_whole = np.hstack((new_x_test_minmax_A, new_x_test_minmax_B))
                    new_x_validationt_minmax_whole = np.hstack((new_x_validation_minmax_A, new_x_validation_minmax_B))

                    finetune_lr = 1
                    batch_size = 100
                    pretraining_epochs = cal_epochs(1500, x_train_minmax, batch_size = batch_size)
                    #pretrain_lr=0.001
                    pretrain_lr = 0.001
                    training_epochs = 1500
                    hidden_layers_sizes= [100, 100]
                    corruption_levels = [0,0]
                    
                    sda_transformed = trainSda(new_x_train_minmax_whole, y_train_minmax,
                         new_x_validationt_minmax_whole, y_validation_minmax , 
                         new_x_test_minmax_whole, y_test,
                         hidden_layers_sizes = hidden_layers_sizes, corruption_levels = corruption_levels, batch_size = batch_size , \
                         training_epochs = training_epochs, pretraining_epochs = pretraining_epochs, 
                         pretrain_lr = pretrain_lr, finetune_lr=finetune_lr
                         )
                    
                    print 'hidden_layers_sizes:', hidden_layers_sizes
                    print 'corruption_levels:', corruption_levels
                    training_predicted = sda_transformed.predict(new_x_train_minmax_whole)
                    y_train = y_train_minmax
                    
                    isTest = False; #new
                    analysis_scr.append((self.ddi, seq_no, fisher_mode, 'DL_S', isTest) + tuple(performance_score(y_train, training_predicted, predicted_score).values()))

                    test_predicted = sda_transformed.predict(new_x_test_minmax_whole)
                    y_test = test_y

                    isTest = True; #new
                    analysis_scr.append((self.ddi, seq_no, fisher_mode, 'DL_S', isTest) + tuple(performance_score(y_test, test_predicted, predicted_score).values()))
            
            
            
            report_name = filename + '_' + '_'.join(map(str, hidden_layers_sizes)) + \
                            '_' + str(pretrain_lr) + '_' + str(finetune_lr) + '_' + str(reduce_ratio)+ \
                            '_' +str(training_epochs) + '_' + current_date
            saveAsCsv(predicted_score, report_name, performance_score(y_test, test_predicted, predicted_score), analysis_scr)

# %%
#for 10-fold cross validation

def ten_fold_crossvalid_performance_for_all(ddis):
    for ddi in ddis:
        try:
            process_one_ddi_tenfold(ddi)
        except Exception,e:
            print str(e)
            logger.debug("There is a error in this ddi: %s" % ddi)
            logger.info(str(e))
def process_one_ddi_tenfold(ddi):
    """A function to waste CPU cycles"""
    logger.info('DDI: %s' % ddi)
    one_ddi_family = {}
    one_ddi_family[ddi] = Ten_fold_crossvalid_performance_for_one_ddi(ddi)
    one_ddi_family[ddi].get_ten_fold_crossvalid_perfermance('FisherM1', '')
    return None
class Ten_fold_crossvalid_performance_for_one_ddi(object):
        """ get the performance of ddi families
        Attributes:
            ddi: string ddi name
            Vectors_Fishers_aaIndex_raw_folder: string, folder
            total_number_of_sequences: int
            raw_data: dict raw_data[2]

        """
        def __init__(self, ddi):
            self.ddi_obj = DDI_family_base(ddi)
            self.ddi = ddi
        def get_ten_fold_crossvalid_perfermance(self, fisher_mode, settings = None):
            analysis_scr = []
            predicted_score = False
            reduce_ratio = 1
            #for seq_no in range(1, self.ddi_obj.total_number_of_sequences+1):
            subset_size = math.floor(self.ddi_obj.total_number_of_sequences / 10.0)
            for subset_no in range(1, 11):
                print subset_no
                logger.info('subset number: ' + str(subset_no))
                if 1:
                    print "SVM"
                    start_index = int((subset_no - 1) * subset_size + 1)
                    if subset_no == 10:
                        end_index  = int(max(start_index + subset_size, self.ddi_obj.total_number_of_sequences))
                    else:
                        end_index  = int(start_index + subset_size)
                    print  start_index, end_index
                    (train_X_10fold, train_y_10fold),(train_X_reduced, train_y_reduced), (test_X, test_y) = self.ddi_obj.get_ten_fold_crossvalid_one_subset(start_index, end_index, reduce_ratio = reduce_ratio)
                    standard_scaler = preprocessing.StandardScaler().fit(train_X_reduced)
                    scaled_train_X = standard_scaler.transform(train_X_reduced)
                    scaled_test_X = standard_scaler.transform(test_X)
                    Linear_SVC = LinearSVC(C=1, penalty="l2")
                    Linear_SVC.fit(scaled_train_X, train_y_reduced)
                    predicted_test_y = Linear_SVC.predict(scaled_test_X)
                    isTest = True; #new
                    analysis_scr.append((self.ddi, subset_no, fisher_mode, 'SVM', isTest) + tuple(performance_score(test_y, predicted_test_y).values())) #new

                    predicted_train_y = Linear_SVC.predict(scaled_train_X)
                    isTest = False; #new
                    analysis_scr.append((self.ddi, subset_no, fisher_mode, 'SVM', isTest) + tuple(performance_score(train_y_reduced, predicted_train_y).values()))
               
                # direct deep learning 
                min_max_scaler = Precessing_Scaler_0_9()
                X_train_pre_validation_minmax = min_max_scaler.fit(train_X_reduced)
                X_train_pre_validation_minmax = min_max_scaler.transform(train_X_reduced)
                x_test_minmax = min_max_scaler.transform(test_X)
                pretraining_X_minmax = min_max_scaler.transform(train_X_10fold)
                x_train_minmax, x_validation_minmax, y_train_minmax, y_validation_minmax = train_test_split(X_train_pre_validation_minmax, 
                                                                                                  train_y_reduced
                                                                    , test_size=0.4, random_state=42)
                finetune_lr = 0.1
                batch_size = 100
                pretraining_epochs = cal_epochs(5000, x_train_minmax, batch_size = batch_size)
                #pretrain_lr=0.001
                pretrain_lr = 0.001
                training_epochs = 1500
                hidden_layers_sizes= [100, 100]
                corruption_levels = [0,0]
                if 1:
                    print "direct deep learning"
                    sda = trainSda(x_train_minmax, y_train_minmax,
                                 x_validation_minmax, y_validation_minmax , 
                                 x_test_minmax, test_y,
                                 hidden_layers_sizes = hidden_layers_sizes, corruption_levels = corruption_levels, batch_size = batch_size , \
                                 training_epochs = training_epochs, pretraining_epochs = pretraining_epochs, 
                                 pretrain_lr = pretrain_lr, finetune_lr=finetune_lr
                     )
                    print 'hidden_layers_sizes:', hidden_layers_sizes
                    print 'corruption_levels:', corruption_levels
                    training_predicted = sda.predict(x_train_minmax)
                    y_train = y_train_minmax
                    isTest = False; #new
                    analysis_scr.append((self.ddi, subset_no, fisher_mode, 'DL', isTest) + tuple(performance_score(y_train, training_predicted).values()))

                    test_predicted = sda.predict(x_test_minmax)
                    y_test = test_y
                    isTest = True; #new
                    analysis_scr.append((self.ddi, subset_no, fisher_mode, 'DL', isTest) + tuple(performance_score(y_test, test_predicted).values()))

                if 0:
                # deep learning using unlabeled data for pretraining
                    print 'deep learning with unlabel data'
                    pretraining_epochs = cal_epochs(1, pretraining_X_minmax, batch_size = batch_size)
                    sda_unlabel = trainSda(x_train_minmax, y_train_minmax,
                                 x_validation_minmax, y_validation_minmax , 
                                 x_test_minmax, test_y, 
                                 pretraining_X_minmax = pretraining_X_minmax,
                                 hidden_layers_sizes = hidden_layers_sizes, corruption_levels = corruption_levels, batch_size = batch_size , \
                                 training_epochs = training_epochs, pretraining_epochs = pretraining_epochs, 
                                 pretrain_lr = pretrain_lr, finetune_lr=finetune_lr
                     )
                    print 'hidden_layers_sizes:', hidden_layers_sizes
                    print 'corruption_levels:', corruption_levels
                    training_predicted = sda_unlabel.predict(x_train_minmax)
                    y_train = y_train_minmax
                    isTest = False; #new
                    analysis_scr.append((self.ddi, subset_no, fisher_mode, 'DL_U', isTest) + tuple(performance_score(y_train, training_predicted, predicted_score).values()))

                    test_predicted = sda_unlabel.predict(x_test_minmax)
                    y_test = test_y

                    isTest = True; #new
                    analysis_scr.append((self.ddi, subset_no, fisher_mode, 'DL_U', isTest) + tuple(performance_score(y_test, test_predicted, predicted_score).values()))
                if 1:
                    # deep learning using split network
                    print 'deep learning using split network'
                    # get the new representation for A set. first 784-D
                    pretraining_epochs=5000
                    hidden_layers_sizes =[100, 100, 100]
                    corruption_levels=[0, 0, 0]
                    
                    x = x_train_minmax[:, :x_train_minmax.shape[1]/2]
                    print "original shape for A", x.shape
                    a_MAE_A = train_a_MultipleAEs(x, pretraining_epochs=pretraining_epochs, pretrain_lr=pretrain_lr, batch_size=batch_size, 
                                            hidden_layers_sizes =hidden_layers_sizes, corruption_levels=corruption_levels)
                    new_x_train_minmax_A =  a_MAE_A.transform(x_train_minmax[:, :x_train_minmax.shape[1]/2])
                    x = x_train_minmax[:, x_train_minmax.shape[1]/2:]
                    
                    print "original shape for B", x.shape
                    a_MAE_B = train_a_MultipleAEs(x, pretraining_epochs=pretraining_epochs, pretrain_lr=pretrain_lr, batch_size=batch_size, 
                                            hidden_layers_sizes =hidden_layers_sizes, corruption_levels=corruption_levels)
                    new_x_train_minmax_B =  a_MAE_B.transform(x_train_minmax[:, x_train_minmax.shape[1]/2:])
                    
                    new_x_test_minmax_A = a_MAE_A.transform(x_test_minmax[:, :x_test_minmax.shape[1]/2])
                    new_x_test_minmax_B = a_MAE_B.transform(x_test_minmax[:, x_test_minmax.shape[1]/2:])
                    new_x_validation_minmax_A = a_MAE_A.transform(x_validation_minmax[:, :x_validation_minmax.shape[1]/2])
                    new_x_validation_minmax_B = a_MAE_B.transform(x_validation_minmax[:, x_validation_minmax.shape[1]/2:])
                    new_x_train_minmax_whole = np.hstack((new_x_train_minmax_A, new_x_train_minmax_B))
                    new_x_test_minmax_whole = np.hstack((new_x_test_minmax_A, new_x_test_minmax_B))
                    new_x_validationt_minmax_whole = np.hstack((new_x_validation_minmax_A, new_x_validation_minmax_B))

                    finetune_lr = 1
                    batch_size = 100
                    pretraining_epochs = cal_epochs(5000, x_train_minmax, batch_size = batch_size)
                    #pretrain_lr=0.001
                    pretrain_lr = 0.001
                    training_epochs = 1500
                    hidden_layers_sizes= [100, 100, 100]
                    corruption_levels = [0,0,0]
                    
                    sda_transformed = trainSda(new_x_train_minmax_whole, y_train_minmax,
                         new_x_validationt_minmax_whole, y_validation_minmax , 
                         new_x_test_minmax_whole, y_test,
                         hidden_layers_sizes = hidden_layers_sizes, corruption_levels = corruption_levels, batch_size = batch_size , \
                         training_epochs = training_epochs, pretraining_epochs = pretraining_epochs, 
                         pretrain_lr = pretrain_lr, finetune_lr=finetune_lr
                         )
                    
                    print 'hidden_layers_sizes:', hidden_layers_sizes
                    print 'corruption_levels:', corruption_levels
                    training_predicted = sda_transformed.predict(new_x_train_minmax_whole)
                    y_train = y_train_minmax
                    
                    isTest = False; #new
                    analysis_scr.append((self.ddi, subset_no, fisher_mode, 'DL_S', isTest) + tuple(performance_score(y_train, training_predicted, predicted_score).values()))

                    test_predicted = sda_transformed.predict(new_x_test_minmax_whole)
                    y_test = test_y

                    isTest = True; #new
                    analysis_scr.append((self.ddi, subset_no, fisher_mode, 'DL_S', isTest) + tuple(performance_score(y_test, test_predicted, predicted_score).values()))
            
            
            report_name = filename + '_' + '_test10fold_'.join(map(str, hidden_layers_sizes)) + \
                            '_' + str(pretrain_lr) + '_' + str(finetune_lr) + '_' + str(reduce_ratio)+ \
                    '_' + str(training_epochs) + '_' + current_date
            saveAsCsv(predicted_score, report_name, analysis_scr)

# %%
ten_fold_crossvalid_performance_for_all(ddis[:1])
# Out:
# INFO:__main__:DDI: 6PGD_int_NAD_binding_2
# INFO:__main__:subset number: 1
# 1
# SVM
# 1 6
# recall
#  54.8%
# precision 51.2%
# accuracy 51.3%
# recall 56.4%
# precision 53.2%
# accuracy 53.4%
#
#
#
# direct deep learning
# ... building the model
# ... getting the pretraining functions
# ... pre-training the model
# Pre-training layer 0, epoch 0, cost
#  58.3511182226
# Pre-training layer 0, epoch 1, cost  51.3345048636
# Pre-training layer 0, epoch 2, cost
#  45.6065191235
# Pre-training layer 0, epoch 3, cost  40.9980612896
# Pre-training layer 0, epoch 4, cost
#  37.3383888123
# Pre-training layer 0, epoch 5, cost  34.4640631024
# Pre-training layer 0, epoch 6, cost
#  32.2270818455
# Pre-training layer 0, epoch 7, cost  30.4992715798
# Pre-training layer 0, epoch 8, cost
#  29.1728887236
# Pre-training layer 0, epoch 9, cost  28.159230912
# Pre-training layer 0, epoch 10, cost
#  27.3865897927
# Pre-training layer 0, epoch 11, cost  26.798024014
# Pre-training layer 0, epoch 12, cost
#  26.3490787714
# Pre-training layer 0, epoch 13, cost  26.0055551994
# Pre-training layer 0, epoch 14, cost
#  25.7414504617
# Pre-training layer 0, epoch 15, cost  25.5371601972
# Pre-training layer 0, epoch 16, cost
#  25.3779833503
# Pre-training layer 0, epoch 17, cost  25.2529249142
# Pre-training layer 0, epoch 18, cost
#  25.1537646896
# Pre-training layer 0, epoch 19, cost  25.0743482768
# Pre-training layer 0, epoch 20, cost
#  25.0100552644
# Pre-training layer 0, epoch 21, cost  24.9574041505
# Pre-training layer 0, epoch 22, cost
#  24.913760425
# Pre-training layer 0, epoch 23, cost  24.8771213431
# Pre-training layer 0, epoch 24, cost
#  24.8459572043
# Pre-training layer 0, epoch 25, cost  24.8190940664
# Pre-training layer 0, epoch 26, cost
#  24.7956268016
# Pre-training layer 0, epoch 27, cost  24.7748543846
# Pre-training layer 0, epoch 28, cost
#  24.7562315105
# Pre-training layer 0, epoch 29, cost  24.7393322472
# Pre-training layer 0, epoch 30, cost
#  24.7238225939
# Pre-training layer 0, epoch 31, cost  24.7094396618
# Pre-training layer 0, epoch 32, cost
#  24.6959758019
# Pre-training layer 0, epoch 33, cost  24.6832664466
# Pre-training layer 0, epoch 34, cost
#  24.6711807543
# Pre-training layer 0, epoch 35, cost  24.6596143796
# Pre-training layer 0, epoch 36, cost
#  24.6484838621
# Pre-training layer 0, epoch 37, cost  24.6377222551
# Pre-training layer 0, epoch 38, cost
#  24.6272757071
# Pre-training layer 0, epoch 39, cost  24.6171007789
# Pre-training layer 0, epoch 40, cost
#  24.6071623323
# Pre-training layer 0, epoch 41, cost  24.5974318613
# Pre-training layer 0, epoch 42, cost
#  24.5878861715
# Pre-training layer 0, epoch 43, cost  24.5785063309
# Pre-training layer 0, epoch 44, cost
#  24.5692768347
# Pre-training layer 0, epoch 45, cost  24.5601849384
# Pre-training layer 0, epoch 46, cost
#  24.5512201253
# Pre-training layer 0, epoch 47, cost  24.5423736786
# Pre-training layer 0, epoch 48, cost
#  24.5336383394
# Pre-training layer 0, epoch 49, cost  24.52500803
# Pre-training layer 0, epoch 50, cost
#  24.5164776323
# Pre-training layer 0, epoch 51, cost
#  24.5080428084
# Pre-training layer 0, epoch 52, cost  24.4996998558
# Pre-training layer 0, epoch 53, cost
#  24.4914455905
# Pre-training layer 0, epoch 54, cost
#  24.483277252
# Pre-training layer 0, epoch 55, cost  24.4751924266
# Pre-training layer 0, epoch 56, cost
#  24.4671889851
# Pre-training layer 0, epoch 57, cost  24.4592650318
# Pre-training layer 0, epoch 58, cost
#  24.451418864
# Pre-training layer 0, epoch 59, cost  24.4436489381
# Pre-training layer 0, epoch 60, cost
#  24.4359538422
# Pre-training layer 0, epoch 61, cost  24.4283322744
# Pre-training layer 0, epoch 62, cost
#  24.4207830242
# Pre-training layer 0, epoch 63, cost
#  24.4133049584
# Pre-training layer 0, epoch 64, cost  24.4058970082
# Pre-training layer 0, epoch 65, cost
#  24.39855816
# Pre-training layer 0, epoch 66, cost  24.3912874471
# Pre-training layer 0, epoch 67, cost
#  24.3840839433
# Pre-training layer 0, epoch 68, cost  24.3769467571
# Pre-training layer 0, epoch 69, cost
#  24.3698750277
# Pre-training layer 0, epoch 70, cost  24.3628679212
# Pre-training layer 0, epoch 71, cost
#  24.3559246275
# Pre-training layer 0, epoch 72, cost
#  24.3490443578
# Pre-training layer 0, epoch 73, cost
#  24.342226343
# Pre-training layer 0, epoch 74, cost  24.3354698313
# Pre-training layer 0, epoch 75, cost
#  24.3287740874
# Pre-training layer 0, epoch 76, cost  24.322138391
# Pre-training layer 0, epoch 77, cost
#  24.3155620359
# Pre-training layer 0, epoch 78, cost  24.309044329
# Pre-training layer 0, epoch 79, cost
#  24.3025845898
# Pre-training layer 0, epoch 80, cost  24.2961821499
# Pre-training layer 0, epoch 81, cost
#  24.289836352
# Pre-training layer 0, epoch 82, cost  24.2835465499
# Pre-training layer 0, epoch 83, cost
#  24.2773121078
# Pre-training layer 0, epoch 84, cost  24.2711324002
# Pre-training layer 0, epoch 85, cost
#  24.2650068114
# Pre-training layer 0, epoch 86, cost
#  24.2589347352
# Pre-training layer 0, epoch 87, cost  24.2529155748
# Pre-training layer 0, epoch 88, cost
#  24.2469487422
# Pre-training layer 0, epoch 89, cost  24.2410336586
# Pre-training layer 0, epoch 90, cost
#  24.2351697535
# Pre-training layer 0, epoch 91, cost
#  24.229356465
# Pre-training layer 0, epoch 92, cost  24.2235932393
# Pre-training layer 0, epoch 93, cost
#  24.2178795307
# Pre-training layer 0, epoch 94, cost  24.2122148014
# Pre-training layer 0, epoch 95, cost
#  24.2065985212
# Pre-training layer 0, epoch 96, cost
#  24.2010301677
# Pre-training layer 0, epoch 97, cost  24.1955092257
# Pre-training layer 0, epoch 98, cost
#  24.1900351872
# Pre-training layer 0, epoch 99, cost
#  24.1846075515
# Pre-training layer 0, epoch 100, cost  24.1792258248
# Pre-training layer 0, epoch 101, cost
#  24.1738895199
# Pre-training layer 0, epoch 102, cost  24.1685981567
# Pre-training layer 0, epoch 103, cost
#  24.1633512613
# Pre-training layer 0, epoch 104, cost  24.1581483665
# Pre-training layer 0, epoch 105, cost
#  24.1529890113
# Pre-training layer 0, epoch 106, cost  24.1478727409
# Pre-training layer 0, epoch 107, cost
#  24.1427991066
# Pre-training layer 0, epoch 108, cost
#  24.1377676657
# Pre-training layer 0, epoch 109, cost  24.1327779812
# Pre-training layer 0, epoch 110, cost
#  24.127829622
# Pre-training layer 0, epoch 111, cost  24.1229221625
# Pre-training layer 0, epoch 112, cost
#  24.1180551829
# Pre-training layer 0, epoch 113, cost  24.1132282685
# Pre-training layer 0, epoch 114, cost
#  24.1084410102
# Pre-training layer 0, epoch 115, cost  24.1036930038
# Pre-training layer 0, epoch 116, cost
#  24.0989838507
# Pre-training layer 0, epoch 117, cost  24.0943131569
# Pre-training layer 0, epoch 118, cost
#  24.0896805336
# Pre-training layer 0, epoch 119, cost  24.0850855968
# Pre-training layer 0, epoch 120, cost
#  24.0805279674
# Pre-training layer 0, epoch 121, cost  24.0760072709
# Pre-training layer 0, epoch 122, cost
#  24.0715231372
# Pre-training layer 0, epoch 123, cost  24.0670752012
# Pre-training layer 0, epoch 124, cost
#  24.0626631019
# Pre-training layer 0, epoch 125, cost  24.0582864827
# Pre-training layer 0, epoch 126, cost
#  24.0539449916
# Pre-training layer 0, epoch 127, cost  24.0496382806
# Pre-training layer 0, epoch 128, cost
#  24.0453660058
# Pre-training layer 0, epoch 129, cost  24.0411278276
# Pre-training layer 0, epoch 130, cost
#  24.0369234104
# Pre-training layer 0, epoch 131, cost  24.0327524223
# Pre-training layer 0, epoch 132, cost
#  24.0286145357
# Pre-training layer 0, epoch 133, cost  24.0245094266
# Pre-training layer 0, epoch 134, cost
#  24.0204367748
# Pre-training layer 0, epoch 135, cost  24.0163962639
# Pre-training layer 0, epoch 136, cost
#  24.0123875811
# Pre-training layer 0, epoch 137, cost  24.0084104172
# Pre-training layer 0, epoch 138, cost
#  24.0044644666
# Pre-training layer 0, epoch 139, cost  24.0005494271
# Pre-training layer 0, epoch 140, cost
#  23.9966650001
# Pre-training layer 0, epoch 141, cost  23.9928108902
# Pre-training layer 0, epoch 142, cost
#  23.9889868054
# Pre-training layer 0, epoch 143, cost  23.9851924572
# Pre-training layer 0, epoch 144, cost
#  23.9814275602
# Pre-training layer 0, epoch 145, cost  23.9776918319
# Pre-training layer 0, epoch 146, cost
#  23.9739849935
# Pre-training layer 0, epoch 147, cost  23.9703067689
# Pre-training layer 0, epoch 148, cost
#  23.9666568852
# Pre-training layer 0, epoch 149, cost  23.9630350726
# Pre-training layer 0, epoch 150, cost
#  23.9594410641
# Pre-training layer 0, epoch 151, cost  23.9558745957
# Pre-training layer 0, epoch 152, cost
#  23.9523354064
# Pre-training layer 0, epoch 153, cost  23.9488232379
# Pre-training layer 0, epoch 154, cost
#  23.9453378349
# Pre-training layer 0, epoch 155, cost  23.9418789446
# Pre-training layer 0, epoch 156, cost
#  23.9384463173
# Pre-training layer 0, epoch 157, cost  23.9350397057
# Pre-training layer 0, epoch 158, cost
#  23.9316588652
# Pre-training layer 0, epoch 159, cost  23.9283035541
# Pre-training layer 0, epoch 160, cost
#  23.9249735331
# Pre-training layer 0, epoch 161, cost  23.9216685653
# Pre-training layer 0, epoch 162, cost
#  23.9183884167
# Pre-training layer 0, epoch 163, cost  23.9151328556
# Pre-training layer 0, epoch 164, cost
#  23.9119016527
# Pre-training layer 0, epoch 165, cost  23.9086945812
# Pre-training layer 0, epoch 166, cost
#  23.9055114168
# Pre-training layer 0, epoch 167, cost  23.9023519374
# Pre-training layer 0, epoch 168, cost
#  23.8992159235
# Pre-training layer 0, epoch 169, cost  23.8961031577
# Pre-training layer 0, epoch 170, cost
#  23.8930134248
# Pre-training layer 0, epoch 171, cost  23.8899465123
# Pre-training layer 0, epoch 172, cost
#  23.8869022094
# Pre-training layer 0, epoch 173, cost  23.8838803078
# Pre-training layer 0, epoch 174, cost
#  23.8808806014
# Pre-training layer 0, epoch 175, cost  23.8779028861
# Pre-training layer 0, epoch 176, cost
#  23.8749469601
# Pre-training layer 0, epoch 177, cost  23.8720126235
# Pre-training layer 0, epoch 178, cost
#  23.8690996787
# Pre-training layer 0, epoch 179, cost  23.8662079298
# Pre-training layer 0, epoch 180, cost
#  23.8633371834
# Pre-training layer 0, epoch 181, cost  23.8604872478
# Pre-training layer 0, epoch 182, cost
#  23.8576579332
# Pre-training layer 0, epoch 183, cost  23.854849052
# Pre-training layer 0, epoch 184, cost
#  23.8520604185
# Pre-training layer 0, epoch 185, cost  23.8492918487
# Pre-training layer 0, epoch 186, cost
#  23.8465431607
# Pre-training layer 0, epoch 187, cost  23.8438141744
# Pre-training layer 0, epoch 188, cost
#  23.8411047114
# Pre-training layer 0, epoch 189, cost  23.8384145955
# Pre-training layer 0, epoch 190, cost
#  23.8357436518
# Pre-training layer 0, epoch 191, cost  23.8330917076
# Pre-training layer 0, epoch 192, cost
#  23.8304585918
# Pre-training layer 0, epoch 193, cost  23.827844135
# Pre-training layer 0, epoch 194, cost
#  23.8252481696
# Pre-training layer 0, epoch 195, cost  23.8226705296
# Pre-training layer 0, epoch 196, cost
#  23.8201110509
# Pre-training layer 0, epoch 197, cost  23.8175695708
# Pre-training layer 0, epoch 198, cost
#  23.8150459283
# Pre-training layer 0, epoch 199, cost  23.8125399642
# Pre-training layer 0, epoch 200, cost
#  23.8100515208
# Pre-training layer 0, epoch 201, cost  23.807580442
# Pre-training layer 0, epoch 202, cost
#  23.8051265732
# Pre-training layer 0, epoch 203, cost  23.8026897614
# Pre-training layer 0, epoch 204, cost
#  23.8002698552
# Pre-training layer 0, epoch 205, cost  23.7978667047
# Pre-training layer 0, epoch 206, cost
#  23.7954801615
# Pre-training layer 0, epoch 207, cost  23.7931100786
# Pre-training layer 1, epoch 0, cost
#  129.767204187
# Pre-training layer 1, epoch 1, cost
#  106.989075591
# Pre-training layer 1, epoch 2, cost
#  91.10151529
# Pre-training layer 1, epoch 3, cost
#  80.225285862
# Pre-training layer 1, epoch 4, cost
#  72.8674152045
# Pre-training layer 1, epoch 5, cost
#  67.9060886912
# Pre-training layer 1, epoch 6, cost
#  64.5275073203
# Pre-training layer 1, epoch 7, cost
#  62.1764657388
# Pre-training layer 1, epoch 8, cost
#  60.4960142537
# Pre-training layer 1, epoch 9, cost
#  59.2630765075
# Pre-training layer 1, epoch 10, cost
#  58.3377281249
# Pre-training layer 1, epoch 11, cost
#  57.6301006135
# Pre-training layer 1, epoch 12, cost
#  57.0806046529
# Pre-training layer 1, epoch 13, cost
#  56.6484260651
# Pre-training layer 1, epoch 14, cost
#  56.3047855176
# Pre-training layer 1, epoch 15, cost
#  56.0288885354
# Pre-training layer 1, epoch 16, cost
#  55.8054096053
# Pre-training layer 1, epoch 17, cost
#  55.6228733017
# Pre-training layer 1, epoch 18, cost
#  55.4725772242
# Pre-training layer 1, epoch 19, cost
#  55.3478537286
# Pre-training layer 1, epoch 20, cost
#  55.2435507595
# Pre-training layer 1, epoch 21, cost
#  55.1556588459
# Pre-training layer 1, epoch 22, cost
#  55.0810383325
# Pre-training layer 1, epoch 23, cost
#  55.0172170156
# Pre-training layer 1, epoch 24, cost
#  54.9622382431
# Pre-training layer 1, epoch 25, cost
#  54.9145458027
# Pre-training layer 1, epoch 26, cost
#  54.8728960035
# Pre-training layer 1, epoch 27, cost
#  54.8362900903
# Pre-training layer 1, epoch 28, cost
#  54.8039220026
# Pre-training layer 1, epoch 29, cost
#  54.7751378076
# Pre-training layer 1, epoch 30, cost
#  54.7494040723
# Pre-training layer 1, epoch 31, cost
#  54.7262831212
# Pre-training layer 1, epoch 32, cost
#  54.7054136234
# Pre-training layer 1, epoch 33, cost
#  54.6864953262
# Pre-training layer 1, epoch 34, cost
#  54.6692770222
# Pre-training layer 1, epoch 35, cost
#  54.6535470522
# Pre-training layer 1, epoch 36, cost
#  54.6391257966
# Pre-training layer 1, epoch 37, cost
#  54.6258597335
# Pre-training layer 1, epoch 38, cost
#  54.6136167283
# Pre-training layer 1, epoch 39, cost
#  54.6022822965
# Pre-training layer 1, epoch 40, cost
#  54.5917566302
# Pre-training layer 1, epoch 41, cost
#  54.5819522277
# Pre-training layer 1, epoch 42, cost
#  54.5727919954
# Pre-training layer 1, epoch 43, cost
#  54.5642077213
# Pre-training layer 1, epoch 44, cost
#  54.5561388383
# Pre-training layer 1, epoch 45, cost
#  54.5485314149
# Pre-training layer 1, epoch 46, cost
#  54.5413373237
# Pre-training layer 1, epoch 47, cost
#  54.5345135482
# Pre-training layer 1, epoch 48, cost
#  54.5280215989
# Pre-training layer 1, epoch 49, cost
#  54.5218270155
# Pre-training layer 1, epoch 50, cost
#  54.5158989366
# Pre-training layer 1, epoch 51, cost
#  54.5102097251
# Pre-training layer 1, epoch 52, cost
#  54.504734638
# Pre-training layer 1, epoch 53, cost
#  54.499451533
# Pre-training layer 1, epoch 54, cost
#  54.494340606
# Pre-training layer 1, epoch 55, cost
#  54.4893841562
# Pre-training layer 1, epoch 56, cost
#  54.4845663729
# Pre-training layer 1, epoch 57, cost
#  54.479873144
# Pre-training layer 1, epoch 58, cost
#  54.4752918822
# Pre-training layer 1, epoch 59, cost
#  54.4708113676
# Pre-training layer 1, epoch 60, cost
#  54.4664216056
# Pre-training layer 1, epoch 61, cost
#  54.4621136983
# Pre-training layer 1, epoch 62, cost
#  54.4578797281
# Pre-training layer 1, epoch 63, cost
#  54.4537126529
# Pre-training layer 1, epoch 64, cost
#  54.449606212
# Pre-training layer 1, epoch 65, cost
#  54.4455548411
# Pre-training layer 1, epoch 66, cost
#  54.4415535958
# Pre-training layer 1, epoch 67, cost
#  54.437598084
# Pre-training layer 1, epoch 68, cost
#  54.4336844041
# Pre-training layer 1, epoch 69, cost
#  54.4298090907
# Pre-training layer 1, epoch 70, cost
#  54.4259690659
# Pre-training layer 1, epoch 71, cost
#  54.4221615956
# Pre-training layer 1, epoch 72, cost
#  54.4183842511
# Pre-training layer 1, epoch 73, cost
#  54.4146348741
# Pre-training layer 1, epoch 74, cost
#  54.4109115467
# Pre-training layer 1, epoch 75, cost
#  54.407212564
# Pre-training layer 1, epoch 76, cost
#  54.4035364097
# Pre-training layer 1, epoch 77, cost
#  54.399881735
# Pre-training layer 1, epoch 78, cost
#  54.3962473394
# Pre-training layer 1, epoch 79, cost
#  54.3926321542
# Pre-training layer 1, epoch 80, cost
#  54.389035227
# Pre-training layer 1, epoch 81, cost
#  54.3854557093
# Pre-training layer 1, epoch 82, cost
#  54.3818928439
# Pre-training layer 1, epoch 83, cost
#  54.3783459554
# Pre-training layer 1, epoch 84, cost
#  54.3748144403
# Pre-training layer 1, epoch 85, cost
#  54.3712977594
# Pre-training layer 1, epoch 86, cost
#  54.3677954304
# Pre-training layer 1, epoch 87, cost
#  54.3643070215
# Pre-training layer 1, epoch 88, cost
#  54.360832146
# Pre-training layer 1, epoch 89, cost
#  54.3573704567
# Pre-training layer 1, epoch 90, cost
#  54.3539216425
# Pre-training layer 1, epoch 91, cost
#  54.3504854233
# Pre-training layer 1, epoch 92, cost
#  54.3470615474
# Pre-training layer 1, epoch 93, cost
#  54.3436497882
# Pre-training layer 1, epoch 94, cost
#  54.3402499411
# Pre-training layer 1, epoch 95, cost
#  54.3368618217
# Pre-training layer 1, epoch 96, cost
#  54.333485263
# Pre-training layer 1, epoch 97, cost
#  54.3301201141
# Pre-training layer 1, epoch 98, cost
#  54.3267662379
# Pre-training layer 1, epoch 99, cost
#  54.3234235102
# Pre-training layer 1, epoch 100, cost
#  54.3200918179
# Pre-training layer 1, epoch 101, cost
#  54.316771058
# Pre-training layer 1, epoch 102, cost
#  54.3134611365
# Pre-training layer 1, epoch 103, cost
#  54.3101619675
# Pre-training layer 1, epoch 104, cost
#  54.3068734723
# Pre-training layer 1, epoch 105, cost
#  54.3035955788
# Pre-training layer 1, epoch 106, cost
#  54.3003282205
# Pre-training layer 1, epoch 107, cost
#  54.2970713363
# Pre-training layer 1, epoch 108, cost
#  54.2938248698
# Pre-training layer 1, epoch 109, cost
#  54.2905887687
# Pre-training layer 1, epoch 110, cost
#  54.2873629845
# Pre-training layer 1, epoch 111, cost
#  54.2841474724
# Pre-training layer 1, epoch 112, cost
#  54.2809421902
# Pre-training layer 1, epoch 113, cost
#  54.2777470988
# Pre-training layer 1, epoch 114, cost
#  54.2745621616
# Pre-training layer 1, epoch 115, cost
#  54.2713873443
# Pre-training layer 1, epoch 116, cost
#  54.2682226143
# Pre-training layer 1, epoch 117, cost
#  54.2650679414
# Pre-training layer 1, epoch 118, cost
#  54.2619232965
# Pre-training layer 1, epoch 119, cost
#  54.2587886525
# Pre-training layer 1, epoch 120, cost
#  54.2556639834
# Pre-training layer 1, epoch 121, cost
#  54.2525492646
# Pre-training layer 1, epoch 122, cost
#  54.2494444724
# Pre-training layer 1, epoch 123, cost
#  54.2463495844
# Pre-training layer 1, epoch 124, cost
#  54.243264579
# Pre-training layer 1, epoch 125, cost
#  54.2401894355
# Pre-training layer 1, epoch 126, cost
#  54.2371241338
# Pre-training layer 1, epoch 127, cost
#  54.2340686548
# Pre-training layer 1, epoch 128, cost
#  54.2310229797
# Pre-training layer 1, epoch 129, cost
#  54.2279870907
# Pre-training layer 1, epoch 130, cost
#  54.22496097
# Pre-training layer 1, epoch 131, cost
#  54.2219446008
# Pre-training layer 1, epoch 132, cost
#  54.2189379664
# Pre-training layer 1, epoch 133, cost
#  54.2159410506
# Pre-training layer 1, epoch 134, cost
#  54.2129538376
# Pre-training layer 1, epoch 135, cost
#  54.2099763118
# Pre-training layer 1, epoch 136, cost
#  54.2070084581
# Pre-training layer 1, epoch 137, cost
#  54.2040502614
# Pre-training layer 1, epoch 138, cost
#  54.2011017071
# Pre-training layer 1, epoch 139, cost
#  54.1981627807
# Pre-training layer 1, epoch 140, cost
#  54.1952334678
# Pre-training layer 1, epoch 141, cost
#  54.1923137544
# Pre-training layer 1, epoch 142, cost
#  54.1894036264
# Pre-training layer 1, epoch 143, cost
#  54.18650307
# Pre-training layer 1, epoch 144, cost
#  54.1836120715
# Pre-training layer 1, epoch 145, cost
#  54.1807306173
# Pre-training layer 1, epoch 146, cost
#  54.1778586938
# Pre-training layer 1, epoch 147, cost
#  54.1749962876
# Pre-training layer 1, epoch 148, cost
#  54.1721433853
# Pre-training layer 1, epoch 149, cost
#  54.1692999736
# Pre-training layer 1, epoch 150, cost
#  54.1664660391
# Pre-training layer 1, epoch 151, cost
#  54.1636415686
# Pre-training layer 1, epoch 152, cost
#  54.1608265489
# Pre-training layer 1, epoch 153, cost
#  54.1580209667
# Pre-training layer 1, epoch 154, cost
#  54.1552248087
# Pre-training layer 1, epoch 155, cost
#  54.1524380617
# Pre-training layer 1, epoch 156, cost
#  54.1496607124
# Pre-training layer 1, epoch 157, cost
#  54.1468927476
# Pre-training layer 1, epoch 158, cost
#  54.1441341539
# Pre-training layer 1, epoch 159, cost
#  54.1413849179
# Pre-training layer 1, epoch 160, cost
#  54.1386450263
# Pre-training layer 1, epoch 161, cost
#  54.1359144656
# Pre-training layer 1, epoch 162, cost
#  54.1331932224
# Pre-training layer 1, epoch 163, cost
#  54.1304812829
# Pre-training layer 1, epoch 164, cost
#  54.1277786336
# Pre-training layer 1, epoch 165, cost
#  54.1250852608
# Pre-training layer 1, epoch 166, cost
#  54.1224011507
# Pre-training layer 1, epoch 167, cost
#  54.1197262894
# Pre-training layer 1, epoch 168, cost
#  54.117060663
# Pre-training layer 1, epoch 169, cost
#  54.1144042574
# Pre-training layer 1, epoch 170, cost
#  54.1117570585
# Pre-training layer 1, epoch 171, cost
#  54.1091190521
# Pre-training layer 1, epoch 172, cost
#  54.1064902237
# Pre-training layer 1, epoch 173, cost
#  54.1038705591
# Pre-training layer 1, epoch 174, cost
#  54.1012600435
# Pre-training layer 1, epoch 175, cost
#  54.0986586625
# Pre-training layer 1, epoch 176, cost
#  54.0960664011
# Pre-training layer 1, epoch 177, cost
#  54.0934832446
# Pre-training layer 1, epoch 178, cost
#  54.0909091779
# Pre-training layer 1, epoch 179, cost
#  54.0883441858
# Pre-training layer 1, epoch 180, cost
#  54.0857882532
# Pre-training layer 1, epoch 181, cost
#  54.0832413647
# Pre-training layer 1, epoch 182, cost
#  54.0807035048
# Pre-training layer 1, epoch 183, cost
#  54.0781746578
# Pre-training layer 1, epoch 184, cost
#  54.075654808
# Pre-training layer 1, epoch 185, cost
#  54.0731439394
# Pre-training layer 1, epoch 186, cost
#  54.0706420362
# Pre-training layer 1, epoch 187, cost
#  54.0681490821
# Pre-training layer 1, epoch 188, cost
#  54.0656650608
# Pre-training layer 1, epoch 189, cost
#  54.063189956
# Pre-training layer 1, epoch 190, cost
#  54.0607237509
# Pre-training layer 1, epoch 191, cost
#  54.0582664291
# Pre-training layer 1, epoch 192, cost
#  54.0558179735
# Pre-training layer 1, epoch 193, cost
#  54.0533783672
# Pre-training layer 1, epoch 194, cost
#  54.0509475931
# Pre-training layer 1, epoch 195, cost
#  54.048525634
# Pre-training layer 1, epoch 196, cost
#  54.0461124723
# Pre-training layer 1, epoch 197, cost
#  54.0437080907
# Pre-training layer 1, epoch 198, cost
#  54.0413124714
# Pre-training layer 1, epoch 199, cost
#  54.0389255965
# Pre-training layer 1, epoch 200, cost
#  54.0365474481
# Pre-training layer 1, epoch 201, cost
#  54.0341780082
# Pre-training layer 1, epoch 202, cost
#  54.0318172584
# Pre-training layer 1, epoch 203, cost
#  54.0294651804
# Pre-training layer 1, epoch 204, cost
#  54.0271217555
# Pre-training layer 1, epoch 205, cost
#  54.0247869653
# Pre-training layer 1, epoch 206, cost
#  54.0224607908
# Pre-training layer 1, epoch 207, cost
#  54.0201432131
# ... getting the finetuning functions
# ... finetunning the model
# epoch 1, minibatch 24/24, validation error 50.937500 %
#  epoch 1, minibatch 24/24, test error of best model 48.166667 %
# epoch 2, minibatch 24/24, validation error 49.500000 %
#  epoch 2, minibatch 24/24, test error of best model 48.500000 %
# epoch 3, minibatch 24/24, validation error 49.875000 %
# epoch 4, minibatch 24/24, validation error 48.625000 %
#  epoch 4, minibatch 24/24, test error of best model 48.833333 %
# epoch 5, minibatch 24/24, validation error 49.000000 %
# epoch 6, minibatch 24/24, validation error 48.937500 %
# epoch 7, minibatch 24/24, validation error 49.562500 %
# epoch 8, minibatch 24/24, validation error 48.937500 %
# epoch 9, minibatch 24/24, validation error 48.500000 %
#  epoch 9, minibatch 24/24, test error of best model 48.833333 %
# epoch 10, minibatch 24/24, validation error 48.500000 %
# epoch 11, minibatch 24/24, validation error 48.250000 %
#  epoch 11, minibatch 24/24, test error of best model 49.000000 %
# epoch 12, minibatch 24/24, validation error 48.812500 %
# epoch 13, minibatch 24/24, validation error 49.125000 %
# epoch 14, minibatch 24/24, validation error 48.875000 %
# epoch 15, minibatch 24/24, validation error 48.500000 %
# epoch 16, minibatch 24/24, validation error 48.687500 %
# epoch 17, minibatch 24/24, validation error 48.437500 %
# epoch 18, minibatch 24/24, validation error 48.437500 %
# epoch 19, minibatch 24/24, validation error 48.250000 %
# epoch 20, minibatch 24/24, validation error 48.187500 %
#  epoch 20, minibatch 24/24, test error of best model 48.166667 %
# epoch 21, minibatch 24/24, validation error 48.062500 %
#  epoch 21, minibatch 24/24, test error of best model 47.833333 %
# epoch 22, minibatch 24/24, validation error 47.812500 %
#  epoch 22, minibatch 24/24, test error of best model 47.833333 %
# epoch 23, minibatch 24/24, validation error 47.562500 %
#  epoch 23, minibatch 24/24, test error of best model 47.500000 %
# epoch 24, minibatch 24/24, validation error 47.812500 %
# epoch 25, minibatch 24/24, validation error 47.625000 %
# epoch 26, minibatch 24/24, validation error 47.750000 %
# epoch 27, minibatch 24/24, validation error 47.687500 %
# epoch 28, minibatch 24/24, validation error 47.375000 %
#  epoch 28, minibatch 24/24, test error of best model 47.000000 %
# epoch 29, minibatch 24/24, validation error 47.562500 %
# epoch 30, minibatch 24/24, validation error 47.562500 %
# epoch 31, minibatch 24/24, validation error 46.750000 %
#  epoch 31, minibatch 24/24, test error of best model 46.333333 %
# epoch 32, minibatch 24/24, validation error 47.000000 %
# epoch 33, minibatch 24/24, validation error 46.937500 %
# epoch 34, minibatch 24/24, validation error 46.812500 %
# epoch 35, minibatch 24/24, validation error 47.250000 %
# epoch 36, minibatch 24/24, validation error 47.250000 %
# epoch 37, minibatch 24/24, validation error 47.312500 %
# epoch 38, minibatch 24/24, validation error 47.125000 %
# epoch 39, minibatch 24/24, validation error 46.875000 %
# epoch 40, minibatch 24/24, validation error 46.750000 %
# epoch 41, minibatch 24/24, validation error 46.750000 %
# epoch 42, minibatch 24/24, validation error 46.562500 %
#  epoch 42, minibatch 24/24, test error of best model 45.333333 %
# epoch 43, minibatch 24/24, validation error 46.187500 %
#  epoch 43, minibatch 24/24, test error of best model 45.500000 %
# epoch 44, minibatch 24/24, validation error 46.125000 %
#  epoch 44, minibatch 24/24, test error of best model 45.333333 %
# epoch 45, minibatch 24/24, validation error 46.312500 %
# epoch 46, minibatch 24/24, validation error 45.875000 %
#  epoch 46, minibatch 24/24, test error of best model 44.833333 %
# epoch 47, minibatch 24/24, validation error 45.750000 %
#  epoch 47, minibatch 24/24, test error of best model 44.666667 %
# epoch 48, minibatch 24/24, validation error 45.750000 %
# epoch 49, minibatch 24/24, validation error 45.687500 %
#  epoch 49, minibatch 24/24, test error of best model 44.166667 %
# epoch 50, minibatch 24/24, validation error 45.937500 %
# epoch 51, minibatch 24/24, validation error 45.875000 %
# epoch 52, minibatch 24/24, validation error 45.625000 %
#  epoch 52, minibatch 24/24, test error of best model 44.333333 %
# epoch 53, minibatch 24/24, validation error 45.312500 %
#  epoch 53, minibatch 24/24, test error of best model 44.000000 %
# epoch 54, minibatch 24/24, validation error 45.437500 %
# epoch 55, minibatch 24/24, validation error 45.500000 %
# epoch 56, minibatch 24/24, validation error 45.375000 %
# epoch 57, minibatch 24/24, validation error 45.250000 %
#  epoch 57, minibatch 24/24, test error of best model 44.166667 %
# epoch 58, minibatch 24/24, validation error 45.125000 %
#  epoch 58, minibatch 24/24, test error of best model 44.666667 %
# epoch 59, minibatch 24/24, validation error 45.062500 %
#  epoch 59, minibatch 24/24, test error of best model 44.333333 %
# epoch 60, minibatch 24/24, validation error 44.937500 %
#  epoch 60, minibatch 24/24, test error of best model 44.000000 %
# epoch 61, minibatch 24/24, validation error 44.875000 %
#  epoch 61, minibatch 24/24, test error of best model 43.666667 %
# epoch 62, minibatch 24/24, validation error 44.875000 %
# epoch 63, minibatch 24/24, validation error 44.875000 %
# epoch 64, minibatch 24/24, validation error 44.875000 %
# epoch 65, minibatch 24/24, validation error 44.750000 %
#  epoch 65, minibatch 24/24, test error of best model 42.833333 %
# epoch 66, minibatch 24/24, validation error 44.750000 %
# epoch 67, minibatch 24/24, validation error 44.687500 %
#  epoch 67, minibatch 24/24, test error of best model 43.000000 %
# epoch 68, minibatch 24/24, validation error 44.750000 %
# epoch 69, minibatch 24/24, validation error 44.500000 %
#  epoch 69, minibatch 24/24, test error of best model 43.166667 %
# epoch 70, minibatch 24/24, validation error 44.375000 %
#  epoch 70, minibatch 24/24, test error of best model 43.166667 %
# epoch 71, minibatch 24/24, validation error 44.312500 %
#  epoch 71, minibatch 24/24, test error of best model 43.000000 %
# epoch 72, minibatch 24/24, validation error 44.312500 %
# epoch 73, minibatch 24/24, validation error 44.187500 %
#  epoch 73, minibatch 24/24, test error of best model 43.166667 %
# epoch 74, minibatch 24/24, validation error 43.875000 %
#  epoch 74, minibatch 24/24, test error of best model 43.166667 %
# epoch 75, minibatch 24/24, validation error 43.750000 %
#  epoch 75, minibatch 24/24, test error of best model 42.833333 %
# epoch 76, minibatch 24/24, validation error 43.625000 %
#  epoch 76, minibatch 24/24, test error of best model 42.666667 %
# epoch 77, minibatch 24/24, validation error 43.250000 %
#  epoch 77, minibatch 24/24, test error of best model 42.500000 %
# epoch 78, minibatch 24/24, validation error 43.187500 %
#  epoch 78, minibatch 24/24, test error of best model 42.500000 %
# epoch 79, minibatch 24/24, validation error 43.187500 %
# epoch 80, minibatch 24/24, validation error 43.125000 %
#  epoch 80, minibatch 24/24, test error of best model 42.500000 %
# epoch 81, minibatch 24/24, validation error 43.062500 %
#  epoch 81, minibatch 24/24, test error of best model 42.500000 %
# epoch 82, minibatch 24/24, validation error 42.937500 %
#  epoch 82, minibatch 24/24, test error of best model 42.833333 %
# epoch 83, minibatch 24/24, validation error 42.562500 %
#  epoch 83, minibatch 24/24, test error of best model 42.666667 %
# epoch 84, minibatch 24/24, validation error 42.562500 %
# epoch 85, minibatch 24/24, validation error 42.500000 %
#  epoch 85, minibatch 24/24, test error of best model 42.500000 %
# epoch 86, minibatch 24/24, validation error 42.375000 %
#  epoch 86, minibatch 24/24, test error of best model 41.666667 %
# epoch 87, minibatch 24/24, validation error 42.312500 %
#  epoch 87, minibatch 24/24, test error of best model 41.666667 %
# epoch 88, minibatch 24/24, validation error 42.250000 %
#  epoch 88, minibatch 24/24, test error of best model 41.833333 %
# epoch 89, minibatch 24/24, validation error 42.125000 %
#  epoch 89, minibatch 24/24, test error of best model 41.833333 %
# epoch 90, minibatch 24/24, validation error 42.062500 %
#  epoch 90, minibatch 24/24, test error of best model 41.833333 %
# epoch 91, minibatch 24/24, validation error 42.000000 %
#  epoch 91, minibatch 24/24, test error of best model 41.833333 %
# epoch 92, minibatch 24/24, validation error 42.000000 %
# epoch 93, minibatch 24/24, validation error 41.937500 %
#  epoch 93, minibatch 24/24, test error of best model 41.500000 %
# epoch 94, minibatch 24/24, validation error 41.625000 %
#  epoch 94, minibatch 24/24, test error of best model 41.500000 %
# epoch 95, minibatch 24/24, validation error 41.437500 %
#  epoch 95, minibatch 24/24, test error of best model 41.500000 %
# epoch 96, minibatch 24/24, validation error 41.375000 %
#  epoch 96, minibatch 24/24, test error of best model 41.500000 %
# epoch 97, minibatch 24/24, validation error 41.437500 %
# epoch 98, minibatch 24/24, validation error 41.562500 %
# epoch 99, minibatch 24/24, validation error 41.437500 %
# epoch 100, minibatch 24/24, validation error 41.312500 %
#  epoch 100, minibatch 24/24, test error of best model 41.333333 %
# epoch 101, minibatch 24/24, validation error 41.312500 %
# epoch 102, minibatch 24/24, validation error 41.187500 %
#  epoch 102, minibatch 24/24, test error of best model 41.333333 %
# epoch 103, minibatch 24/24, validation error 41.250000 %
# epoch 104, minibatch 24/24, validation error 41.437500 %
# epoch 105, minibatch 24/24, validation error 41.500000 %
# epoch 106, minibatch 24/24, validation error 41.375000 %
# epoch 107, minibatch 24/24, validation error 41.375000 %
# epoch 108, minibatch 24/24, validation error 41.375000 %
# epoch 109, minibatch 24/24, validation error 41.500000 %
# epoch 110, minibatch 24/24, validation error 40.687500 %
#  epoch 110, minibatch 24/24, test error of best model 40.166667 %
# epoch 111, minibatch 24/24, validation error 40.625000 %
#  epoch 111, minibatch 24/24, test error of best model 40.166667 %
# epoch 112, minibatch 24/24, validation error 40.562500 %
#  epoch 112, minibatch 24/24, test error of best model 40.166667 %
# epoch 113, minibatch 24/24, validation error 40.687500 %
# epoch 114, minibatch 24/24, validation error 40.687500 %
# epoch 115, minibatch 24/24, validation error 40.625000 %
# epoch 116, minibatch 24/24, validation error 40.625000 %
# epoch 117, minibatch 24/24, validation error 40.687500 %
# epoch 118, minibatch 24/24, validation error 40.437500 %
#  epoch 118, minibatch 24/24, test error of best model 39.500000 %
# epoch 119, minibatch 24/24, validation error 40.312500 %
#  epoch 119, minibatch 24/24, test error of best model 39.500000 %
# epoch 120, minibatch 24/24, validation error 40.375000 %
# epoch 121, minibatch 24/24, validation error 40.375000 %
# epoch 122, minibatch 24/24, validation error 40.375000 %
# epoch 123, minibatch 24/24, validation error 40.500000 %
# epoch 124, minibatch 24/24, validation error 40.250000 %
#  epoch 124, minibatch 24/24, test error of best model 39.333333 %
# epoch 125, minibatch 24/24, validation error 40.187500 %
#  epoch 125, minibatch 24/24, test error of best model 39.333333 %
# epoch 126, minibatch 24/24, validation error 40.250000 %
# epoch 127, minibatch 24/24, validation error 40.312500 %
# epoch 128, minibatch 24/24, validation error 40.312500 %
# epoch 129, minibatch 24/24, validation error 40.312500 %
# epoch 130, minibatch 24/24, validation error 40.250000 %
# epoch 131, minibatch 24/24, validation error 40.250000 %
# epoch 132, minibatch 24/24, validation error 40.250000 %
# epoch 133, minibatch 24/24, validation error 40.000000 %
#  epoch 133, minibatch 24/24, test error of best model 39.333333 %
# epoch 134, minibatch 24/24, validation error 40.062500 %
# epoch 135, minibatch 24/24, validation error 39.687500 %
#  epoch 135, minibatch 24/24, test error of best model 39.166667 %
# epoch 136, minibatch 24/24, validation error 39.687500 %
# epoch 137, minibatch 24/24, validation error 39.812500 %
# epoch 138, minibatch 24/24, validation error 39.812500 %
# epoch 139, minibatch 24/24, validation error 39.812500 %
# epoch 140, minibatch 24/24, validation error 39.750000 %
# epoch 141, minibatch 24/24, validation error 39.875000 %
# epoch 142, minibatch 24/24, validation error 39.812500 %
# epoch 143, minibatch 24/24, validation error 39.812500 %
# epoch 144, minibatch 24/24, validation error 39.875000 %
# epoch 145, minibatch 24/24, validation error 39.875000 %
# epoch 146, minibatch 24/24, validation error 40.000000 %
# epoch 147, minibatch 24/24, validation error 40.125000 %
# epoch 148, minibatch 24/24, validation error 40.125000 %
# epoch 149, minibatch 24/24, validation error 40.125000 %
# epoch 150, minibatch 24/24, validation error 40.125000 %
# epoch 151, minibatch 24/24, validation error 40.062500 %
# epoch 152, minibatch 24/24, validation error 40.187500 %
# epoch 153, minibatch 24/24, validation error 40.187500 %
# epoch 154, minibatch 24/24, validation error 40.000000 %
# epoch 155, minibatch 24/24, validation error 40.187500 %
# epoch 156, minibatch 24/24, validation error 40.250000 %
# epoch 157, minibatch 24/24, validation error 40.250000 %
# epoch 158, minibatch 24/24, validation error 40.312500 %
# epoch 159, minibatch 24/24, validation error 40.500000 %
# epoch 160, minibatch 24/24, validation error 40.625000 %
# epoch 161, minibatch 24/24, validation error 40.687500 %
# epoch 162, minibatch 24/24, validation error 40.687500 %
# epoch 163, minibatch 24/24, validation error 40.625000 %
# epoch 164, minibatch 24/24, validation error 40.687500 %
# epoch 165, minibatch 24/24, validation error 40.687500 %
# epoch 166, minibatch 24/24, validation error 40.437500 %
# epoch 167, minibatch 24/24, validation error 40.500000 %
# epoch 168, minibatch 24/24, validation error 40.437500 %
# epoch 169, minibatch 24/24, validation error 40.000000 %
# epoch 170, minibatch 24/24, validation error 40.000000 %
# epoch 171, minibatch 24/24, validation error 40.062500 %
# epoch 172, minibatch 24/24, validation error 40.062500 %
# epoch 173, minibatch 24/24, validation error 39.937500 %
# epoch 174, minibatch 24/24, validation error 39.875000 %
# epoch 175, minibatch 24/24, validation error 39.875000 %
# epoch 176, minibatch 24/24, validation error 39.937500 %
# epoch 177, minibatch 24/24, validation error 40.000000 %
# epoch 178, minibatch 24/24, validation error 40.062500 %
# epoch 179, minibatch 24/24, validation error 40.062500 %
# epoch 180, minibatch 24/24, validation error 40.000000 %
# epoch 181, minibatch 24/24, validation error 39.937500 %
# epoch 182, minibatch 24/24, validation error 39.687500 %
# epoch 183, minibatch 24/24, validation error 39.687500 %
# epoch 184, minibatch 24/24, validation error 39.687500 %
# epoch 185, minibatch 24/24, validation error 39.562500 %
#  epoch 185, minibatch 24/24, test error of best model 38.166667 %
# epoch 186, minibatch 24/24, validation error 39.750000 %
# epoch 187, minibatch 24/24, validation error 39.750000 %
# epoch 188, minibatch 24/24, validation error 39.750000 %
# epoch 189, minibatch 24/24, validation error 39.750000 %
# epoch 190, minibatch 24/24, validation error 39.875000 %
# epoch 191, minibatch 24/24, validation error 39.937500 %
# epoch 192, minibatch 24/24, validation error 39.500000 %
#  epoch 192, minibatch 24/24, test error of best model 38.333333 %
# epoch 193, minibatch 24/24, validation error 39.562500 %
# epoch 194, minibatch 24/24, validation error 39.250000 %
#  epoch 194, minibatch 24/24, test error of best model 38.333333 %
# epoch 195, minibatch 24/24, validation error 39.250000 %
# epoch 196, minibatch 24/24, validation error 39.000000 %
#  epoch 196, minibatch 24/24, test error of best model 38.333333 %
# epoch 197, minibatch 24/24, validation error 38.750000 %
#  epoch 197, minibatch 24/24, test error of best model 38.000000 %
# epoch 198, minibatch 24/24, validation error 39.125000 %
# epoch 199, minibatch 24/24, validation error 38.625000 %
#  epoch 199, minibatch 24/24, test error of best model 37.500000 %
# epoch 200, minibatch 24/24, validation error 38.625000 %
# epoch 201, minibatch 24/24, validation error 38.625000 %
# epoch 202, minibatch 24/24, validation error 38.562500 %
#  epoch 202, minibatch 24/24, test error of best model 37.500000 %
# epoch 203, minibatch 24/24, validation error 38.437500 %
#  epoch 203, minibatch 24/24, test error of best model 37.666667 %
# epoch 204, minibatch 24/24, validation error 38.062500 %
#  epoch 204, minibatch 24/24, test error of best model 37.333333 %
# epoch 205, minibatch 24/24, validation error 38.000000 %
#  epoch 205, minibatch 24/24, test error of best model 37.500000 %
# epoch 206, minibatch 24/24, validation error 38.187500 %
# epoch 207, minibatch 24/24, validation error 37.562500 %
#  epoch 207, minibatch 24/24, test error of best model 37.166667 %
# epoch 208, minibatch 24/24, validation error 37.562500 %
# epoch 209, minibatch 24/24, validation error 37.500000 %
#  epoch 209, minibatch 24/24, test error of best model 37.166667 %
# epoch 210, minibatch 24/24, validation error 37.500000 %
# epoch 211, minibatch 24/24, validation error 37.625000 %
# epoch 212, minibatch 24/24, validation error 37.500000 %
# epoch 213, minibatch 24/24, validation error 37.562500 %
# epoch 214, minibatch 24/24, validation error 37.687500 %
# epoch 215, minibatch 24/24, validation error 37.687500 %
# epoch 216, minibatch 24/24, validation error 37.625000 %
# epoch 217, minibatch 24/24, validation error 37.625000 %
# epoch 218, minibatch 24/24, validation error 37.500000 %
# epoch 219, minibatch 24/24, validation error 37.500000 %
# epoch 220, minibatch 24/24, validation error 37.500000 %
# epoch 221, minibatch 24/24, validation error 37.437500 %
#  epoch 221, minibatch 24/24, test error of best model 37.333333 %
# epoch 222, minibatch 24/24, validation error 37.437500 %
# epoch 223, minibatch 24/24, validation error 37.437500 %
# epoch 224, minibatch 24/24, validation error 37.437500 %
# epoch 225, minibatch 24/24, validation error 37.437500 %
# epoch 226, minibatch 24/24, validation error 37.312500 %
#  epoch 226, minibatch 24/24, test error of best model 37.333333 %
# epoch 227, minibatch 24/24, validation error 37.312500 %
# epoch 228, minibatch 24/24, validation error 37.312500 %
# epoch 229, minibatch 24/24, validation error 37.312500 %
# epoch 230, minibatch 24/24, validation error 37.500000 %
# epoch 231, minibatch 24/24, validation error 37.500000 %
# epoch 232, minibatch 24/24, validation error 37.500000 %
# epoch 233, minibatch 24/24, validation error 37.500000 %
# epoch 234, minibatch 24/24, validation error 37.437500 %
# epoch 235, minibatch 24/24, validation error 37.375000 %
# epoch 236, minibatch 24/24, validation error 37.375000 %
# epoch 237, minibatch 24/24, validation error 37.250000 %
#  epoch 237, minibatch 24/24, test error of best model 37.500000 %
# epoch 238, minibatch 24/24, validation error 37.250000 %
# epoch 239, minibatch 24/24, validation error 37.250000 %
# epoch 240, minibatch 24/24, validation error 37.250000 %
# epoch 241, minibatch 24/24, validation error 37.312500 %
# epoch 242, minibatch 24/24, validation error 37.000000 %
#  epoch 242, minibatch 24/24, test error of best model 37.666667 %
# epoch 243, minibatch 24/24, validation error 36.687500 %
#  epoch 243, minibatch 24/24, test error of best model 37.666667 %
# epoch 244, minibatch 24/24, validation error 36.562500 %
#  epoch 244, minibatch 24/24, test error of best model 37.500000 %
# epoch 245, minibatch 24/24, validation error 36.562500 %
# epoch 246, minibatch 24/24, validation error 36.562500 %
# epoch 247, minibatch 24/24, validation error 36.500000 %
#  epoch 247, minibatch 24/24, test error of best model 37.500000 %
# epoch 248, minibatch 24/24, validation error 36.375000 %
#  epoch 248, minibatch 24/24, test error of best model 37.500000 %
# epoch 249, minibatch 24/24, validation error 36.375000 %
# epoch 250, minibatch 24/24, validation error 36.250000 %
#  epoch 250, minibatch 24/24, test error of best model 37.500000 %
# epoch 251, minibatch 24/24, validation error 36.312500 %
# epoch 252, minibatch 24/24, validation error 36.062500 %
#  epoch 252, minibatch 24/24, test error of best model 37.500000 %
# epoch 253, minibatch 24/24, validation error 35.875000 %
#  epoch 253, minibatch 24/24, test error of best model 37.500000 %
# epoch 254, minibatch 24/24, validation error 35.937500 %
# epoch 255, minibatch 24/24, validation error 35.937500 %
# epoch 256, minibatch 24/24, validation error 35.875000 %
# epoch 257, minibatch 24/24, validation error 35.937500 %
# epoch 258, minibatch 24/24, validation error 35.937500 %
# epoch 259, minibatch 24/24, validation error 35.812500 %
#  epoch 259, minibatch 24/24, test error of best model 37.333333 %
# epoch 260, minibatch 24/24, validation error 35.937500 %
# epoch 261, minibatch 24/24, validation error 35.937500 %
# epoch 262, minibatch 24/24, validation error 36.125000 %
# epoch 263, minibatch 24/24, validation error 36.000000 %
# epoch 264, minibatch 24/24, validation error 36.000000 %
# epoch 265, minibatch 24/24, validation error 36.125000 %
# epoch 266, minibatch 24/24, validation error 35.875000 %
# epoch 267, minibatch 24/24, validation error 35.875000 %
# epoch 268, minibatch 24/24, validation error 35.562500 %
#  epoch 268, minibatch 24/24, test error of best model 37.000000 %
# epoch 269, minibatch 24/24, validation error 35.687500 %
# epoch 270, minibatch 24/24, validation error 35.687500 %
# epoch 271, minibatch 24/24, validation error 35.812500 %
# epoch 272, minibatch 24/24, validation error 35.875000 %
# epoch 273, minibatch 24/24, validation error 35.875000 %
# epoch 274, minibatch 24/24, validation error 36.125000 %
# epoch 275, minibatch 24/24, validation error 36.125000 %
# epoch 276, minibatch 24/24, validation error 36.062500 %
# epoch 277, minibatch 24/24, validation error 36.062500 %
# epoch 278, minibatch 24/24, validation error 36.125000 %
# epoch 279, minibatch 24/24, validation error 36.125000 %
# epoch 280, minibatch 24/24, validation error 36.125000 %
# epoch 281, minibatch 24/24, validation error 36.125000 %
# epoch 282, minibatch 24/24, validation error 36.125000 %
# epoch 283, minibatch 24/24, validation error 36.125000 %
# epoch 284, minibatch 24/24, validation error 36.125000 %
# epoch 285, minibatch 24/24, validation error 36.187500 %
# epoch 286, minibatch 24/24, validation error 36.187500 %
# epoch 287, minibatch 24/24, validation error 36.250000 %
# epoch 288, minibatch 24/24, validation error 36.250000 %
# epoch 289, minibatch 24/24, validation error 36.062500 %
# epoch 290, minibatch 24/24, validation error 36.062500 %
# epoch 291, minibatch 24/24, validation error 36.062500 %
# epoch 292, minibatch 24/24, validation error 36.125000 %
# epoch 293, minibatch 24/24, validation error 36.125000 %
# epoch 294, minibatch 24/24, validation error 36.062500 %
# epoch 295, minibatch 24/24, validation error 36.062500 %
# epoch 296, minibatch 24/24, validation error 36.062500 %
# epoch 297, minibatch 24/24, validation error 36.062500 %
# epoch 298, minibatch 24/24, validation error 36.062500 %
# epoch 299, minibatch 24/24, validation error 36.062500 %
# epoch 300, minibatch 24/24, validation error 36.062500 %
# epoch 301, minibatch 24/24, validation error 36.062500 %
# epoch 302, minibatch 24/24, validation error 36.125000 %
# epoch 303, minibatch 24/24, validation error 36.062500 %
# epoch 304, minibatch 24/24, validation error 36.062500 %
# epoch 305, minibatch 24/24, validation error 36.000000 %
# epoch 306, minibatch 24/24, validation error 35.937500 %
# epoch 307, minibatch 24/24, validation error 35.937500 %
# epoch 308, minibatch 24/24, validation error 35.937500 %
# epoch 309, minibatch 24/24, validation error 35.875000 %
# epoch 310, minibatch 24/24, validation error 35.875000 %
# epoch 311, minibatch 24/24, validation error 35.687500 %
# epoch 312, minibatch 24/24, validation error 35.625000 %
# epoch 313, minibatch 24/24, validation error 35.625000 %
# epoch 314, minibatch 24/24, validation error 35.625000 %
# epoch 315, minibatch 24/24, validation error 35.625000 %
# epoch 316, minibatch 24/24, validation error 35.562500 %
# epoch 317, minibatch 24/24, validation error 35.500000 %
#  epoch 317, minibatch 24/24, test error of best model 34.833333 %
# epoch 318, minibatch 24/24, validation error 35.500000 %
# epoch 319, minibatch 24/24, validation error 35.375000 %
#  epoch 319, minibatch 24/24, test error of best model 34.833333 %
# epoch 320, minibatch 24/24, validation error 35.375000 %
# epoch 321, minibatch 24/24, validation error 35.687500 %
# epoch 322, minibatch 24/24, validation error 35.687500 %
# epoch 323, minibatch 24/24, validation error 35.687500 %
# epoch 324, minibatch 24/24, validation error 35.687500 %
# epoch 325, minibatch 24/24, validation error 35.687500 %
# epoch 326, minibatch 24/24, validation error 35.687500 %
# epoch 327, minibatch 24/24, validation error 35.687500 %
# epoch 328, minibatch 24/24, validation error 35.750000 %
# epoch 329, minibatch 24/24, validation error 35.750000 %
# epoch 330, minibatch 24/24, validation error 35.750000 %
# epoch 331, minibatch 24/24, validation error 35.687500 %
# epoch 332, minibatch 24/24, validation error 35.687500 %
# epoch 333, minibatch 24/24, validation error 35.562500 %
# epoch 334, minibatch 24/24, validation error 35.562500 %
# epoch 335, minibatch 24/24, validation error 35.562500 %
# epoch 336, minibatch 24/24, validation error 35.562500 %
# epoch 337, minibatch 24/24, validation error 35.687500 %
# epoch 338, minibatch 24/24, validation error 35.687500 %
# epoch 339, minibatch 24/24, validation error 35.687500 %
# epoch 340, minibatch 24/24, validation error 35.750000 %
# epoch 341, minibatch 24/24, validation error 35.750000 %
# epoch 342, minibatch 24/24, validation error 35.750000 %
# epoch 343, minibatch 24/24, validation error 35.625000 %
# epoch 344, minibatch 24/24, validation error 35.687500 %
# epoch 345, minibatch 24/24, validation error 35.687500 %
# epoch 346, minibatch 24/24, validation error 35.687500 %
# epoch 347, minibatch 24/24, validation error 35.687500 %
# epoch 348, minibatch 24/24, validation error 35.750000 %
# epoch 349, minibatch 24/24, validation error 35.875000 %
# epoch 350, minibatch 24/24, validation error 35.875000 %
# epoch 351, minibatch 24/24, validation error 35.875000 %
# epoch 352, minibatch 24/24, validation error 36.000000 %
# epoch 353, minibatch 24/24, validation error 36.000000 %
# epoch 354, minibatch 24/24, validation error 35.937500 %
# ...
# Pre-training layer 1, epoch 2711, cost
#  51.1626074718
# Pre-training layer 1, epoch 2712, cost
#  51.1647156534
# Pre-training layer 1, epoch 2713, cost
#  51.1691114181
# Pre-training layer 1, epoch 2714, cost
#  51.1780760018
# Pre-training layer 1, epoch 2715, cost
#  51.1619506534
# Pre-training layer 1, epoch 2716, cost
#  51.1603513244
# Pre-training layer 1, epoch 2717, cost
#  51.1623149838
# Pre-training layer 1, epoch 2718, cost
#  51.1593579981
# Pre-training layer 1, epoch 2719, cost
#  51.1625778047
# Pre-training layer 1, epoch 2720, cost
#  51.1646588115
# Pre-training layer 1, epoch 2721, cost
#  51.1581762293
# Pre-training layer 1, epoch 2722, cost
#  51.1653070335
# Pre-training layer 1, epoch 2723, cost
#  51.1619020346
# Pre-training layer 1, epoch 2724, cost
#  51.1631083132
# Pre-training layer 1, epoch 2725, cost
#  51.1681687106
# Pre-training layer 1, epoch 2726, cost
#  51.1672980704
# Pre-training layer 1, epoch 2727, cost
#  51.1615533016
# Pre-training layer 1, epoch 2728, cost
#  51.1636377883
# Pre-training layer 1, epoch 2729, cost
#  51.1605471486
# Pre-training layer 1, epoch 2730, cost
#  51.1602092005
# Pre-training layer 1, epoch 2731, cost
#  51.1640671617
# Pre-training layer 1, epoch 2732, cost
#  51.1602241247
# Pre-training layer 1, epoch 2733, cost
#  51.1591160322
# Pre-training layer 1, epoch 2734, cost
#  51.1644793962
# Pre-training layer 1, epoch 2735, cost
#  51.1614905257
# Pre-training layer 1, epoch 2736, cost
#  51.1681372125
# Pre-training layer 1, epoch 2737, cost
#  51.1615118846
# Pre-training layer 1, epoch 2738, cost
#  51.1581779518
# Pre-training layer 1, epoch 2739, cost
#  51.1683795284
# Pre-training layer 1, epoch 2740, cost
#  51.1645535477
# Pre-training layer 1, epoch 2741, cost
#  51.1594189078
# Pre-training layer 1, epoch 2742, cost
#  51.1585405686
# Pre-training layer 1, epoch 2743, cost
#  51.1674707451
# Pre-training layer 1, epoch 2744, cost
#  51.1598081978
# Pre-training layer 1, epoch 2745, cost
#  51.1629664018
# Pre-training layer 1, epoch 2746, cost
#  51.1561770921
# Pre-training layer 1, epoch 2747, cost
#  51.1623794461
# Pre-training layer 1, epoch 2748, cost
#  51.1583375595
# Pre-training layer 1, epoch 2749, cost
#  51.1578438033
# Pre-training layer 1, epoch 2750, cost
#  51.1588927889
# Pre-training layer 1, epoch 2751, cost
#  51.1607368048
# Pre-training layer 1, epoch 2752, cost
#  51.1548773823
# Pre-training layer 1, epoch 2753, cost
#  51.1618366727
# Pre-training layer 1, epoch 2754, cost
#  51.1637005411
# Pre-training layer 1, epoch 2755, cost
#  51.1656791765
# Pre-training layer 1, epoch 2756, cost
#  51.1595150291
# Pre-training layer 1, epoch 2757, cost
#  51.1606193718
# Pre-training layer 1, epoch 2758, cost
#  51.1624792945
# Pre-training layer 1, epoch 2759, cost
#  51.1681674322
# Pre-training layer 1, epoch 2760, cost
#  51.1582474981
# Pre-training layer 1, epoch 2761, cost
#  51.153199499
# Pre-training layer 1, epoch 2762, cost
#  51.162072846
# Pre-training layer 1, epoch 2763, cost
#  51.1553965243
# Pre-training layer 1, epoch 2764, cost
#  51.1632845543
# Pre-training layer 1, epoch 2765, cost
#  51.1565632008
# Pre-training layer 1, epoch 2766, cost
#  51.1578865201
# Pre-training layer 1, epoch 2767, cost
#  51.1573067063
# Pre-training layer 1, epoch 2768, cost
#  51.1602222841
# Pre-training layer 1, epoch 2769, cost
#  51.1529764871
# Pre-training layer 1, epoch 2770, cost
#  51.160624138
# Pre-training layer 1, epoch 2771, cost
#  51.1649030505
# Pre-training layer 1, epoch 2772, cost
#  51.1544029858
# Pre-training layer 1, epoch 2773, cost
#  51.154087081
# Pre-training layer 1, epoch 2774, cost
#  51.1666791303
# Pre-training layer 1, epoch 2775, cost
#  51.1656171535
# Pre-training layer 1, epoch 2776, cost
#  51.1708086628
# Pre-training layer 1, epoch 2777, cost
#  51.1604034405
# Pre-training layer 1, epoch 2778, cost
#  51.1552855185
# Pre-training layer 1, epoch 2779, cost
#  51.1507420416
# Pre-training layer 1, epoch 2780, cost
#  51.1526070212
# Pre-training layer 1, epoch 2781, cost
#  51.1575585627
# Pre-training layer 1, epoch 2782, cost
#  51.160543805
# Pre-training layer 1, epoch 2783, cost
#  51.1633280861
# Pre-training layer 1, epoch 2784, cost
#  51.1544799992
# Pre-training layer 1, epoch 2785, cost
#  51.1508584161
# Pre-training layer 1, epoch 2786, cost
#  51.1529211042
# Pre-training layer 1, epoch 2787, cost
#  51.1631157551
# Pre-training layer 1, epoch 2788, cost
#  51.1578082378
# Pre-training layer 1, epoch 2789, cost
#  51.1604052391
# Pre-training layer 1, epoch 2790, cost
#  51.1577987003
# Pre-training layer 1, epoch 2791, cost
#  51.1573677639
# Pre-training layer 1, epoch 2792, cost
#  51.1615100237
# Pre-training layer 1, epoch 2793, cost
#  51.1536637816
# Pre-training layer 1, epoch 2794, cost
#  51.1666298188
# Pre-training layer 1, epoch 2795, cost
#  51.1659448468
# Pre-training layer 1, epoch 2796, cost
#  51.1536900146
# Pre-training layer 1, epoch 2797, cost
#  51.1482666135
# Pre-training layer 1, epoch 2798, cost
#  51.1569249761
# Pre-training layer 1, epoch 2799, cost
#  51.1628465657
# Pre-training layer 1, epoch 2800, cost
#  51.1578042308
# Pre-training layer 1, epoch 2801, cost
#  51.1561625352
# Pre-training layer 1, epoch 2802, cost
#  51.1607815412
# Pre-training layer 1, epoch 2803, cost
#  51.151118692
# Pre-training layer 1, epoch 2804, cost
#  51.1580726146
# Pre-training layer 1, epoch 2805, cost
#  51.1484939483
# Pre-training layer 1, epoch 2806, cost
#  51.1538043443
# Pre-training layer 1, epoch 2807, cost
#  51.1597249164
# Pre-training layer 1, epoch 2808, cost
#  51.1579037768
# Pre-training layer 1, epoch 2809, cost
#  51.1585574744
# Pre-training layer 1, epoch 2810, cost
#  51.1564596714
# Pre-training layer 1, epoch 2811, cost
#  51.1540524611
# Pre-training layer 1, epoch 2812, cost
#  51.1506912487
# Pre-training layer 1, epoch 2813, cost
#  51.1551307074
# Pre-training layer 1, epoch 2814, cost
#  51.1559429256
# Pre-training layer 1, epoch 2815, cost
#  51.1550135422
# Pre-training layer 1, epoch 2816, cost
#  51.1537477005
# Pre-training layer 1, epoch 2817, cost
#  51.1544828079
# Pre-training layer 1, epoch 2818, cost
#  51.1557888646
# Pre-training layer 1, epoch 2819, cost
#  51.1539970292
# Pre-training layer 1, epoch 2820, cost
#  51.1516933836
# Pre-training layer 1, epoch 2821, cost
#  51.1605212799
# Pre-training layer 1, epoch 2822, cost
#  51.153347033
# Pre-training layer 1, epoch 2823, cost
#  51.1557538933
# Pre-training layer 1, epoch 2824, cost
#  51.1502142895
# Pre-training layer 1, epoch 2825, cost
#  51.1504436388
# Pre-training layer 1, epoch 2826, cost
#  51.1452567952
# Pre-training layer 1, epoch 2827, cost
#  51.1548813677
# Pre-training layer 1, epoch 2828, cost
#  51.1474699433
# Pre-training layer 1, epoch 2829, cost
#  51.1550942384
# Pre-training layer 1, epoch 2830, cost
#  51.1543588893
# Pre-training layer 1, epoch 2831, cost
#  51.1581083158
# Pre-training layer 1, epoch 2832, cost
#  51.1510612146
# Pre-training layer 1, epoch 2833, cost
#  51.1531092635
# Pre-training layer 1, epoch 2834, cost
#  51.1606884737
# Pre-training layer 1, epoch 2835, cost
#  51.1483767614
# Pre-training layer 1, epoch 2836, cost
#  51.1516523929
# Pre-training layer 1, epoch 2837, cost
#  51.1541158794
# Pre-training layer 1, epoch 2838, cost
#  51.1490553939
# Pre-training layer 1, epoch 2839, cost
#  51.1521856334
# Pre-training layer 1, epoch 2840, cost
#  51.155215143
# Pre-training layer 1, epoch 2841, cost
#  51.1441091487
# Pre-training layer 1, epoch 2842, cost
#  51.1609481947
# Pre-training layer 1, epoch 2843, cost
#  51.1533471806
# Pre-training layer 1, epoch 2844, cost
#  51.1606075643
# Pre-training layer 1, epoch 2845, cost
#  51.1526670469
# Pre-training layer 1, epoch 2846, cost
#  51.1489647076
# Pre-training layer 1, epoch 2847, cost
#  51.1503403383
# Pre-training layer 1, epoch 2848, cost
#  51.1500975107
# Pre-training layer 1, epoch 2849, cost
#  51.1480441892
# Pre-training layer 1, epoch 2850, cost
#  51.1493108484
# Pre-training layer 1, epoch 2851, cost
#  51.1453545579
# Pre-training layer 1, epoch 2852, cost
#  51.1537938744
# Pre-training layer 1, epoch 2853, cost
#  51.1497302773
# Pre-training layer 1, epoch 2854, cost
#  51.1490849193
# Pre-training layer 1, epoch 2855, cost
#  51.1554325708
# Pre-training layer 1, epoch 2856, cost
#  51.1510369127
# Pre-training layer 1, epoch 2857, cost
#  51.1517851413
# Pre-training layer 1, epoch 2858, cost
#  51.1491093884
# Pre-training layer 1, epoch 2859, cost
#  51.1530462547
# Pre-training layer 1, epoch 2860, cost
#  51.1521674951
# Pre-training layer 1, epoch 2861, cost
#  51.15673698
# Pre-training layer 1, epoch 2862, cost
#  51.1481059535
# Pre-training layer 1, epoch 2863, cost
#  51.1570532602
# Pre-training layer 1, epoch 2864, cost
#  51.1548179245
# Pre-training layer 1, epoch 2865, cost
#  51.1497443146
# Pre-training layer 1, epoch 2866, cost
#  51.1615864265
# Pre-training layer 1, epoch 2867, cost
#  51.1494124944
# Pre-training layer 1, epoch 2868, cost
#  51.1519035911
# Pre-training layer 1, epoch 2869, cost
#  51.1677304936
# Pre-training layer 1, epoch 2870, cost
#  51.1482352975
# Pre-training layer 1, epoch 2871, cost
#  51.154328824
# Pre-training layer 1, epoch 2872, cost
#  51.1482303708
# Pre-training layer 1, epoch 2873, cost
#  51.14893013
# Pre-training layer 1, epoch 2874, cost
#  51.1483067667
# Pre-training layer 1, epoch 2875, cost
#  51.1552977312
# Pre-training layer 1, epoch 2876, cost
#  51.1420970167
# Pre-training layer 1, epoch 2877, cost
#  51.1497570947
# Pre-training layer 1, epoch 2878, cost
#  51.1524386793
# Pre-training layer 1, epoch 2879, cost
#  51.1538247
# Pre-training layer 1, epoch 2880, cost
#  51.1510759278
# Pre-training layer 1, epoch 2881, cost
#  51.154796158
# Pre-training layer 1, epoch 2882, cost
#  51.1547547347
# Pre-training layer 1, epoch 2883, cost
#  51.148117959
# Pre-training layer 1, epoch 2884, cost
#  51.1475772242
# Pre-training layer 1, epoch 2885, cost
#  51.1460408369
# Pre-training layer 1, epoch 2886, cost
#  51.1478275818
# Pre-training layer 1, epoch 2887, cost
#  51.1477662316
# Pre-training layer 1, epoch 2888, cost
#  51.1502728115
# Pre-training layer 1, epoch 2889, cost
#  51.1462488871
# Pre-training layer 1, epoch 2890, cost
#  51.149396365
# Pre-training layer 1, epoch 2891, cost
#  51.148751475
# Pre-training layer 1, epoch 2892, cost
#  51.1484458007
# Pre-training layer 1, epoch 2893, cost
#  51.1532053942
# Pre-training layer 1, epoch 2894, cost
#  51.1393862821
# Pre-training layer 1, epoch 2895, cost
#  51.143722594
# Pre-training layer 1, epoch 2896, cost
#  51.1484481452
# Pre-training layer 1, epoch 2897, cost
#  51.1455212578
# Pre-training layer 1, epoch 2898, cost
#  51.1492007959
# Pre-training layer 1, epoch 2899, cost
#  51.1491847682
# Pre-training layer 1, epoch 2900, cost
#  51.1442766723
# Pre-training layer 1, epoch 2901, cost
#  51.1555454766
# Pre-training layer 1, epoch 2902, cost
#  51.1453859669
# Pre-training layer 1, epoch 2903, cost
#  51.1535716117
# Pre-training layer 1, epoch 2904, cost
#  51.1450834784
# Pre-training layer 1, epoch 2905, cost
#  51.1454032947
# Pre-training layer 1, epoch 2906, cost
#  51.1433539741
# Pre-training layer 1, epoch 2907, cost
#  51.1473190862
# Pre-training layer 1, epoch 2908, cost
#  51.149883629
# Pre-training layer 1, epoch 2909, cost
#  51.1426187612
# Pre-training layer 1, epoch 2910, cost
#  51.1547386367
# Pre-training layer 1, epoch 2911, cost
#  51.1527803143
# Pre-training layer 1, epoch 2912, cost
#  51.145618533
# Pre-training layer 1, epoch 2913, cost
#  51.1559512906
# Pre-training layer 1, epoch 2914, cost
#  51.1446725757
# Pre-training layer 1, epoch 2915, cost
#  51.1531252327
# Pre-training layer 1, epoch 2916, cost
#  51.1421041297
# Pre-training layer 1, epoch 2917, cost
#  51.1474710066
# Pre-training layer 1, epoch 2918, cost
#  51.1492826794
# Pre-training layer 1, epoch 2919, cost
#  51.1448578458
# Pre-training layer 1, epoch 2920, cost
#  51.1439176008
# Pre-training layer 1, epoch 2921, cost
#  51.147711267
# Pre-training layer 1, epoch 2922, cost
#  51.1498719714
# Pre-training layer 1, epoch 2923, cost
#  51.1508235271
# Pre-training layer 1, epoch 2924, cost
#  51.1471717313
# Pre-training layer 1, epoch 2925, cost
#  51.1462575258
# Pre-training layer 1, epoch 2926, cost
#  51.1412065889
# Pre-training layer 1, epoch 2927, cost
#  51.1437017001
# Pre-training layer 1, epoch 2928, cost
#  51.1447219508
# Pre-training layer 1, epoch 2929, cost
#  51.1405294206
# Pre-training layer 1, epoch 2930, cost
#  51.142352501
# Pre-training layer 1, epoch 2931, cost
#  51.14366994
# Pre-training layer 1, epoch 2932, cost
#  51.1503615887
# Pre-training layer 1, epoch 2933, cost
#  51.1494118058
# Pre-training layer 1, epoch 2934, cost
#  51.1348614295
# Pre-training layer 1, epoch 2935, cost
#  51.1487857674
# Pre-training layer 1, epoch 2936, cost
#  51.1448084757
# Pre-training layer 1, epoch 2937, cost
#  51.1450086591
# Pre-training layer 1, epoch 2938, cost
#  51.1532974162
# Pre-training layer 1, epoch 2939, cost
#  51.1466919691
# Pre-training layer 1, epoch 2940, cost
#  51.1438318804
# Pre-training layer 1, epoch 2941, cost
#  51.1447270296
# Pre-training layer 1, epoch 2942, cost
#  51.1359576803
# Pre-training layer 1, epoch 2943, cost
#  51.1466596526
# Pre-training layer 1, epoch 2944, cost
#  51.1470947359
# Pre-training layer 1, epoch 2945, cost
#  51.1524190055
# Pre-training layer 1, epoch 2946, cost
#  51.1405944983
# Pre-training layer 1, epoch 2947, cost
#  51.131524316
# Pre-training layer 1, epoch 2948, cost
#  51.1439665142
# Pre-training layer 1, epoch 2949, cost
#  51.1413104363
# Pre-training layer 1, epoch 2950, cost
#  51.1434145363
# Pre-training layer 1, epoch 2951, cost
#  51.1360412214
# Pre-training layer 1, epoch 2952, cost
#  51.1552964992
# Pre-training layer 1, epoch 2953, cost
#  51.1420919666
# Pre-training layer 1, epoch 2954, cost
#  51.1418503984
# Pre-training layer 1, epoch 2955, cost
#  51.1396708726
# Pre-training layer 1, epoch 2956, cost
#  51.1428602457
# Pre-training layer 1, epoch 2957, cost
#  51.1447573948
# Pre-training layer 1, epoch 2958, cost
#  51.1398041205
# Pre-training layer 1, epoch 2959, cost
#  51.1418631082
# Pre-training layer 1, epoch 2960, cost
#  51.1433997142
# Pre-training layer 1, epoch 2961, cost
#  51.1467337
# Pre-training layer 1, epoch 2962, cost
#  51.1401770867
# Pre-training layer 1, epoch 2963, cost
#  51.1485171073
# Pre-training layer 1, epoch 2964, cost
#  51.1468188555
# Pre-training layer 1, epoch 2965, cost
#  51.1387813281
# Pre-training layer 1, epoch 2966, cost
#  51.1463402644
# Pre-training layer 1, epoch 2967, cost
#  51.1425898288
# Pre-training layer 1, epoch 2968, cost
#  51.1364295473
# Pre-training layer 1, epoch 2969, cost
#  51.1410656867
# Pre-training layer 1, epoch 2970, cost
#  51.1321706877
# Pre-training layer 1, epoch 2971, cost
#  51.1396627007
# Pre-training layer 1, epoch 2972, cost
#  51.1396845873
# Pre-training layer 1, epoch 2973, cost
#  51.1396572044
# Pre-training layer 1, epoch 2974, cost
#  51.1394243035
# Pre-training layer 1, epoch 2975, cost
#  51.1438829549
# Pre-training layer 1, epoch 2976, cost
#  51.1425002564
# Pre-training layer 1, epoch 2977, cost
#  51.1421525396
# Pre-training layer 1, epoch 2978, cost
#  51.1377243778
# Pre-training layer 1, epoch 2979, cost
#  51.1446745112
# Pre-training layer 1, epoch 2980, cost
#  51.1455257989
# Pre-training layer 1, epoch 2981, cost
#  51.1386040701
# Pre-training layer 1, epoch 2982, cost
#  51.1388097646
# Pre-training layer 1, epoch 2983, cost
#  51.1452640395
# Pre-training layer 1, epoch 2984, cost
#  51.1453394896
# Pre-training layer 1, epoch 2985, cost
#  51.1471870665
# Pre-training layer 1, epoch 2986, cost
#  51.139445317
# Pre-training layer 1, epoch 2987, cost
#  51.1418451266
# Pre-training layer 1, epoch 2988, cost
#  51.1414220658
# Pre-training layer 1, epoch 2989, cost
#  51.1374644545
# Pre-training layer 1, epoch 2990, cost
#  51.1392326874
# Pre-training layer 1, epoch 2991, cost
#  51.1471604271
# Pre-training layer 1, epoch 2992, cost
#  51.1451839685
# Pre-training layer 1, epoch 2993, cost
#  51.1428963074
# Pre-training layer 1, epoch 2994, cost
#  51.1441305176
# Pre-training layer 1, epoch 2995, cost
#  51.1460039003
# Pre-training layer 1, epoch 2996, cost
#  51.1459182019
# Pre-training layer 1, epoch 2997, cost
#  51.1400274577
# Pre-training layer 1, epoch 2998, cost
#  51.1471440395
# Pre-training layer 1, epoch 2999, cost
#  51.138819864
# Pre-training layer 1, epoch 3000, cost
#  51.137333256
# Pre-training layer 1, epoch 3001, cost
#  51.1391568724
# Pre-training layer 1, epoch 3002, cost
#  51.1409353925
# Pre-training layer 1, epoch 3003, cost
#  51.1470336621
# Pre-training layer 1, epoch 3004, cost
#  51.1397650435
# Pre-training layer 1, epoch 3005, cost
#  51.1422540303
# Pre-training layer 1, epoch 3006, cost
#  51.141923459
# Pre-training layer 1, epoch 3007, cost

# %%
#LOO_out_performance_for_all(ddis)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-bc27e0896ebe> in <module>()
# ----> 1 LOO_out_performance_for_all(ddis)
#
# NameError: name 'LOO_out_performance_for_all' is not defined

# %%
x = logging._handlers.copy()
for i in x:
    log.removeHandler(i)
    i.flush()
    i.close()
