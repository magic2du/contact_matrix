# %%
import sys, os
sys.path.append('../../../libs/')
import IO_class
from IO_class import FileOperator
from sklearn import cross_validation
import sklearn
import numpy as np
import csv
from dateutil import parser
from datetime import timedelta
from sklearn import svm
import numpy as np
import pandas as pd
import pdb
import pickle
import numpy as np
from sklearn.cross_validation import train_test_split
from sklearn import preprocessing
import sklearn
import scipy.stats as ss
from sklearn.svm import LinearSVC
import random
from DL_libs import *
from itertools import izip #new
# Out:
# /usr/local/lib/python2.7/dist-packages/scipy/spatial/__init__.py:91: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility
#   from .qhull import *
# /usr/local/lib/python2.7/dist-packages/scipy/spatial/__init__.py:91: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility
#   from .qhull import *
# /usr/local/lib/python2.7/dist-packages/scipy/lib/_util.py:35: DeprecationWarning: Module scipy.linalg.blas.fblas is deprecated, use scipy.linalg.blas instead
#   DeprecationWarning)

# %%
#filename = 'SUCCESS_log_CrossValidation_load_DL_remoteFisherM1_DL_RE_US_DL_RE_US_1_1_19MAY2014.txt'
filename = 'listOfDDIsHaveOver2InterfacesHave40-75_Examples_2010_real_selected.txt' #for testing
#filename = 'list_of_SUCCESS_log_run3DID_STAT_200_275_examples_201001MAY2014.txt'
file_obj = FileOperator(filename)
ddis = file_obj.readStripLines()
# Out:
# number of lines in listOfDDIsHaveOver2InterfacesHave40-75_Examples_2010_real_selected.txt:37

# %%
ddi  = ddis[3]

# %%
class DDI_family_base(object):
    #def __init__(self, ddi, Vectors_Fishers_aaIndex_raw_folder = '/home/du/Vectors_Fishers_aaIndex_raw/'):
    def __init__(self, ddi, Vectors_Fishers_aaIndex_raw_folder = '/home/du/Documents/Vectors_Fishers_aaIndex_raw_2014/'):
        """ get total number of sequences in a ddi familgy
        Attributes:
            ddi: string ddi name
            Vectors_Fishers_aaIndex_raw_folder: string, folder
            total_number_of_sequences: int
            raw_data: dict raw_data[2]
        LOO_data['FisherM1'][1]

        """
        self.ddi = ddi
        self.Vectors_Fishers_aaIndex_raw_folder = Vectors_Fishers_aaIndex_raw_folder
        self.ddi_folder = self.Vectors_Fishers_aaIndex_raw_folder + ddi + '/'
        self.total_number_of_sequences = self.get_total_number_of_sequences()
        self.raw_data = {}
        self.positve_negative_number = {}
        self.equal_size_data = {}
        for seq_no in range(1, self.total_number_of_sequences+1):
            self.raw_data[seq_no] = self.get_raw_data_for_selected_seq(seq_no)
            try:
                #positive_file = self.ddi_folder + 'numPos_'+ str(seq_no) + '.txt'
                #file_obj = FileOperator(positive_file)
                #lines = file_obj.readStripLines()
                #import pdb; pdb.set_trace()
                count_pos = int(np.sum(self.raw_data[seq_no][:, -1]))
                count_neg = self.raw_data[seq_no].shape[0] - count_pos
                #self.positve_negative_number[seq_no] = {'numPos': int(float(lines[0]))}
                #assert int(float(lines[0])) == count_pos
                self.positve_negative_number[seq_no] = {'numPos': count_pos}
                #negative_file = self.ddi_folder + 'numNeg_'+ str(seq_no) + '.txt'
                #file_obj = FileOperator(negative_file)
                #lines = file_obj.readStripLines()
                #self.positve_negative_number[seq_no]['numNeg'] =  int(float(lines[0]))
                self.positve_negative_number[seq_no]['numNeg'] =  count_neg
            except Exception,e:
                print ddi, seq_no
                print str(e)
            # get data for equal positive and negative
            n_pos = self.positve_negative_number[seq_no]['numPos']
            n_neg = self.positve_negative_number[seq_no]['numNeg']
            index_neg = range(n_pos, n_pos + n_neg)
            random.shuffle(index_neg)
            index_neg = index_neg[: n_pos]
            positive_examples = self.raw_data[seq_no][ : n_pos, :]
            negative_examples = self.raw_data[seq_no][index_neg, :]
            self.equal_size_data[seq_no] = np.vstack((positive_examples, negative_examples))
    def get_LOO_training_and_reduced_traing(self, seq_no, fisher_mode = 'FisherM1ONLY' , reduce_ratio = 8):
        """ get the leave one out traing data, reduced traing
        Parameters:
            seq_no: 
            fisher_mode: default 'FisherM1ONLY'
        Returns:
            (train_X_LOO, train_y_LOO),(train_X_reduced, train_y_reduced),  (test_X, test_y)
        """
        train_X_LOO = np.array([])
        train_y_LOO = np.array([])
        train_X_reduced = np.array([])
        train_y_reduced = np.array([])

        total_number_of_sequences = self.total_number_of_sequences
        equal_size_data_selected_sequence = self.equal_size_data[seq_no]

        #get test data for selected sequence
        test_X, test_y = self.select_X_y(equal_size_data_selected_sequence, fisher_mode = fisher_mode)
        total_sequences = range(1, total_number_of_sequences+1)
        loo_sequences = [i for i in total_sequences if i != seq_no]
        number_of_reduced = len(loo_sequences)/reduce_ratio if len(loo_sequences)/reduce_ratio !=0 else 1
        random.shuffle(loo_sequences)
        reduced_sequences = loo_sequences[:number_of_reduced]

        #for loo data
        for current_no in loo_sequences:
            raw_current_data = self.equal_size_data[current_no]
            current_X, current_y = self.select_X_y(raw_current_data, fisher_mode = fisher_mode)
            if train_X_LOO.ndim ==1:
                train_X_LOO = current_X
            else:
                train_X_LOO = np.vstack((train_X_LOO, current_X))
            train_y_LOO = np.concatenate((train_y_LOO, current_y))

        #for reduced data
        for current_no in reduced_sequences:
            raw_current_data = self.equal_size_data[current_no]
            current_X, current_y = self.select_X_y(raw_current_data, fisher_mode = fisher_mode)
            if train_X_reduced.ndim ==1:
                train_X_reduced = current_X
            else:
                train_X_reduced = np.vstack((train_X_reduced, current_X))
            train_y_reduced = np.concatenate((train_y_reduced, current_y))                

        return (train_X_LOO, train_y_LOO),(train_X_reduced, train_y_reduced), (test_X, test_y)
    def get_total_number_of_sequences(self):
        """ get total number of sequences in a ddi familgy
        Parameters:
            ddi: string
            Vectors_Fishers_aaIndex_raw_folder: string
        Returns:
            n: int
        """
        folder_path = self.Vectors_Fishers_aaIndex_raw_folder + self.ddi + '/' 
        filename = folder_path +'allPairs.txt'
        all_pairs = np.loadtxt(filename)
        return len(all_pairs)

    def get_raw_data_for_selected_seq(self, seq_no):
        """ get raw data for selected seq no in a family
        Parameters:
            ddi: 
            seq_no: 
        Returns:
            data: raw data in the sequence file
        """
        folder_path = self.Vectors_Fishers_aaIndex_raw_folder + self.ddi + '/' 
        filename = folder_path + 'F0_20_F1_20_Sliding_17_11_F0_20_F1_20_Sliding_17_11_ouput_'+ str(seq_no) + '.txt'
        data = np.loadtxt(filename)
        return data
    def select_X_y(self, data, fisher_mode = ''):
        """ select subset from the raw input data set
        Parameters:
            data: data from matlab txt file
            fisher_mode: subset base on this Fisher of AAONLY...
        Returns:
            selected X,  y
        """
        y = data[:,-1] # get lable
        if fisher_mode == 'FisherM1': # fisher m1 plus AA index
            a = data[:, 20:227]
            b = data[:, 247:454]
            X = np.hstack((a,b))
        elif fisher_mode == 'FisherM1ONLY': 
            a = data[:, 20:40]
            b = data[:, 247:267]
            X = np.hstack((a,b))
        elif fisher_mode == 'AAONLY':
            a = data[:, 40:227]
            b = data[:, 267:454]
            X = np.hstack((a,b))
        else:
            raise('there is an error in mode')
        return X, y

# %%
import sklearn.preprocessing
class Precessing_Scaler_0_9(sklearn.preprocessing.StandardScaler):
    def __init__(self):
        super(Precessing_Scaler_0_9, self).__init__(self, with_std=0.333)
    def transform(self, X): # transform data to 0.1 to 0.9
        new_X = super(Precessing_Scaler_0_9, self).transform(X)
        print 
        new_X[new_X > 1] = 1
        new_X[new_X < -1] = -1
        new_X = (new_X + 1) * 0.4 + 0.1
        return new_X
    def fit_transform(self):
        print 'Did not implement'
def performance_score(target_label, predicted_label, predicted_score = False, print_report = True): 
    """ get performance matrix for prediction
        Attributes:
            target_label: int 0, 1
            predicted_label: 0, 1 or ranking
            predicted_score: bool if False, predicted_label is from 0, 1. If Ture, predicted_label is ranked, need to get AUC score.
            print_report: if True, print the perfromannce on screen
    """
    import sklearn
    from sklearn.metrics import roc_auc_score
    score = {}
    if predicted_score == False:
        score['accuracy'] = sklearn.metrics.accuracy_score(target_label, predicted_label)
        score['precision'] = sklearn.metrics.precision_score(target_label, predicted_label, pos_label=1)
        score['recall'] = sklearn.metrics.recall_score(target_label, predicted_label, pos_label=1)
    if predicted_score == True:
        auc_score  = roc_auc_score(target_label, predicted_label)
        score['auc_score'] = auc_score
        target_label = [x >= 0.5 for x in target_label]
        score['accuracy'] = sklearn.metrics.accuracy_score(target_label, predicted_label)
        score['precision'] = sklearn.metrics.precision_score(target_label, predicted_label, pos_label=1)
        score['recall'] = sklearn.metrics.recall_score(target_label, predicted_label, pos_label=1)
    if print_report == True:
        for key, value in score.iteritems():
            print key, '{percent:.1%}'.format(percent=value)
    return score
class LOO_out_performance_for_one_ddi(object):
        """ get the performance of ddi families
        Attributes:
            ddi: string ddi name
            Vectors_Fishers_aaIndex_raw_folder: string, folder
            total_number_of_sequences: int
            raw_data: dict raw_data[2]

        """
        def __init__(self, ddi):
            self.ddi_obj = DDI_family_base(ddi)
        def analysis_score(self, target_label, predicted_label): #new
            score = (sklearn.metrics.accuracy_score(target_label, predicted_label),
                     sklearn.metrics.precision_score(target_label, predicted_label, pos_label=1),
                     sklearn.metrics.recall_score(target_label, predicted_label, pos_label=1))
            return score
        def saveAsCsv(self, *arguments, **filename): #new
            for (arg, fname) in izip(arguments, filename):
                csvfile = file(filename[fname] + '_report.csv', 'wb')
                writer = csv.writer(csvfile)
                writer.writerow(['DDI', 'no.', 'FisherMode', 'method', 'isTest', 'accuracy', 'precision', 'recall']) #, 'AUC'])
                writer.writerows(arg)
                csvfile.close()
        def get_LOO_perfermance(self, fisher_mode, settings = None):
            analysis_scr = []
            for seq_no in range(1, self.ddi_obj.total_number_of_sequences+1):
                print seq_no
                print "SVM"
                (train_X_LOO, train_y_LOO),(train_X_reduced, train_y_reduced), (test_X, test_y) = self.ddi_obj.get_LOO_training_and_reduced_traing(seq_no, reduce_ratio = 8)
                standard_scaler = preprocessing.StandardScaler().fit(train_X_reduced)
                scaled_train_X = standard_scaler.transform(train_X_reduced)
                scaled_test_X = standard_scaler.transform(test_X)
                Linear_SVC = LinearSVC(C=1, penalty="l2")
                Linear_SVC.fit(scaled_train_X, train_y_reduced)
                predicted_test_y = Linear_SVC.predict(scaled_test_X)
                isTest = True; #new
                analysis_scr.append((ddi, seq_no, fisher_mode, 'SVM', isTest) + self.analysis_score(test_y, predicted_test_y)) #new
                
                print 'precision on test: ', sklearn.metrics.precision_score(test_y, predicted_test_y, pos_label=1)
                print 'recall on test: ',sklearn.metrics.recall_score(test_y, predicted_test_y, pos_label=1)
                
                
                Linear_SVC = LinearSVC(C=1, penalty="l2")
                Linear_SVC.fit(scaled_train_X, train_y_reduced)
                predicted_train_y = Linear_SVC.predict(scaled_train_X)
                isTest = True; #new
                
                print 'precision on training: ', sklearn.metrics.precision_score(train_y_reduced, predicted_train_y, pos_label=1)
                print 'recall on training: ',sklearn.metrics.recall_score(train_y_reduced, predicted_train_y, pos_label=1)
                
                print "direct deep learning"
                # direct deep learning 
                min_max_scaler = Precessing_Scaler_0_9()
                X_train_pre_validation_minmax = min_max_scaler.fit(train_X_reduced)
                X_train_pre_validation_minmax = min_max_scaler.transform(train_X_reduced)
                x_test_minmax = min_max_scaler.transform(test_X)
                pretraining_X_minmax = min_max_scaler.transform(train_X_LOO)
                x_train_minmax, x_validation_minmax, y_train_minmax, y_validation_minmax = train_test_split(X_train_pre_validation_minmax, 
                                                                                                  train_y_reduced
                                                                    , test_size=0.2, random_state=42)
                finetune_lr = 1
                batch_size = 100
                pretraining_epochs = cal_epochs(1000, x_train_minmax, batch_size = batch_size)
                #pretrain_lr=0.001
                pretrain_lr = 0.001
                training_epochs = 1000
                hidden_layers_sizes= [100, 100]
                corruption_levels = [0,0]
                sda = trainSda(x_train_minmax, y_train_minmax,
                             x_validation_minmax, y_validation_minmax , 
                             x_test_minmax, test_y,
                             hidden_layers_sizes = hidden_layers_sizes, corruption_levels = corruption_levels, batch_size = batch_size , \
                             training_epochs = training_epochs, pretraining_epochs = pretraining_epochs, 
                             pretrain_lr = pretrain_lr, finetune_lr=finetune_lr
                 )
                print 'hidden_layers_sizes:', hidden_layers_sizes
                print 'corruption_levels:', corruption_levels
                training_predicted = sda.predict(x_train_minmax)
                y_train = y_train_minmax
                isTest = False; #new
                analysis_scr.append((ddi, seq_no, fisher_mode, 'DL', isTest) + self.analysis_score(y_train, training_predicted)) #new
                
                print 'train accuracy: ', '{percent:.1%}'.format(percent=sklearn.metrics.accuracy_score(y_train, training_predicted)) 
                print 'precision: ', '{percent:.1%}'.format(percent=sklearn.metrics.precision_score(y_train, training_predicted, pos_label=1)) 
                print 'recall: ', '{percent:.1%}'.format( percent= sklearn.metrics.recall_score(y_train, training_predicted, pos_label=1))
                
                
                test_predicted = sda.predict(x_test_minmax)
                y_test = test_y
                isTest = True; #new
                analysis_scr.append((ddi, seq_no, fisher_mode, 'DL', isTest) + self.analysis_score(y_test, test_predicted)) #new
                
                print 'testing accuracy: ', '{percent:.1%}'.format(percent=sklearn.metrics.accuracy_score(y_test, test_predicted)) 
                print 'precision: ', '{percent:.1%}'.format(percent=sklearn.metrics.precision_score(y_test, test_predicted, pos_label=1)) 
                print 'recall: ', '{percent:.1%}'.format( percent= sklearn.metrics.recall_score(y_test, test_predicted, pos_label=1))
                
                
                # deep learning using unlabeled data for pretraining
                print 'deep learning with unlabel data'
                pretraining_epochs = cal_epochs(1000, pretraining_X_minmax, batch_size = batch_size)
                sda_unlabel = trainSda(x_train_minmax, y_train_minmax,
                             x_validation_minmax, y_validation_minmax , 
                             x_test_minmax, test_y, 
                             pretraining_X_minmax = pretraining_X_minmax,
                             hidden_layers_sizes = hidden_layers_sizes, corruption_levels = corruption_levels, batch_size = batch_size , \
                             training_epochs = training_epochs, pretraining_epochs = pretraining_epochs, 
                             pretrain_lr = pretrain_lr, finetune_lr=finetune_lr
                 )
                print 'hidden_layers_sizes:', hidden_layers_sizes
                print 'corruption_levels:', corruption_levels
                training_predicted = sda_unlabel.predict(x_train_minmax)
                y_train = y_train_minmax
                isTest = False; #new
                analysis_scr.append((ddi, seq_no, fisher_mode, 'DL_U', isTest) + self.analysis_score(y_train, training_predicted)) #new
                
                print 'train accuracy: ', '{percent:.1%}'.format(percent=sklearn.metrics.accuracy_score(y_train, training_predicted)) 
                print 'precision: ', '{percent:.1%}'.format(percent=sklearn.metrics.precision_score(y_train, training_predicted, pos_label=1)) 
                print 'recall: ', '{percent:.1%}'.format( percent= sklearn.metrics.recall_score(y_train, training_predicted, pos_label=1))
                
                
                test_predicted = sda_unlabel.predict(x_test_minmax)
                y_test = test_y
                
                print 'testing accuracy: ', '{percent:.1%}'.format(percent=sklearn.metrics.accuracy_score(y_test, test_predicted)) 
                print 'precision: ', '{percent:.1%}'.format(percent=sklearn.metrics.precision_score(y_test, test_predicted, pos_label=1)) 
                print 'recall: ', '{percent:.1%}'.format( percent= sklearn.metrics.recall_score(y_test, test_predicted, pos_label=1))
                
                isTest = True; #new
                analysis_scr.append((ddi, seq_no, fisher_mode, 'DL_U', isTest) + self.analysis_score(y_test, test_predicted)) #new
            self.saveAsCsv(analysis_scr, filename = 'test_score_finetune_lr' +str(finetune_lr)+
                           'pretraining_epochs'+ str(pretraining_epochs) +'hidden_layers_sizes' +str(hidden_layers_sizes[0])
                           +'.txt')

# %%
one_ddi_family = LOO_out_performance_for_one_ddi(ddi)
one_ddi_family.get_LOO_perfermance('FisherM1', '')
# Out:
# 1
# SVM
# precision on test:
#  0.542857142857
# recall on test:  0.520547945205
# precision on training:
#  0.591439688716
# recall on training:  0.537102473498
# direct deep learning
#
#
#
# ... building the model
# ... getting the pretraining functions
# ... pre-training the model
# Pre-training layer 0, epoch 0, cost  61.0436500744
# Pre-training layer 0, epoch 1, cost  59.7100833863
# Pre-training layer 0, epoch 2, cost  58.4159199499
# Pre-training layer 0, epoch 3, cost  57.1606264192
# Pre-training layer 0, epoch 4, cost  55.9436369476
# Pre-training layer 0, epoch 5, cost  54.7643558104
# Pre-training layer 0, epoch 6, cost
#  53.6221599715
# Pre-training layer 0, epoch 7, cost  52.5164015914
# Pre-training layer 0, epoch 8, cost  51.4464104771
# Pre-training layer 0, epoch 9, cost  50.4114964785
# Pre-training layer 0, epoch 10, cost  49.4109518361
# Pre-training layer 0, epoch 11, cost  48.4440534849
# Pre-training layer 0, epoch 12, cost  47.5100653192
# Pre-training layer 0, epoch 13, cost
#  46.6082404182
# Pre-training layer 0, epoch 14, cost  45.7378232302
# Pre-training layer 0, epoch 15, cost  44.8980517102
# Pre-training layer 0, epoch 16, cost  44.0881594019
# Pre-training layer 0, epoch 17, cost  43.3073774519
# Pre-training layer 0, epoch 18, cost  42.5549365452
# Pre-training layer 0, epoch 19, cost  41.8300687465
# Pre-training layer 0, epoch 20, cost
#  41.1320092357
# Pre-training layer 0, epoch 21, cost  40.4599979237
# Pre-training layer 0, epoch 22, cost  39.8132809403
# Pre-training layer 0, epoch 23, cost  39.191111983
# Pre-training layer 0, epoch 24, cost  38.5927535247
# Pre-training layer 0, epoch 25, cost  38.0174778742
# Pre-training layer 0, epoch 26, cost  37.4645680933
# Pre-training layer 0, epoch 27, cost
#  36.9333187709
# Pre-training layer 0, epoch 28, cost  36.4230366638
# Pre-training layer 0, epoch 29, cost  35.9330412103
# Pre-training layer 0, epoch 30, cost  35.462664929
# Pre-training layer 0, epoch 31, cost  35.0112537161
# Pre-training layer 0, epoch 32, cost  34.5781670532
# Pre-training layer 0, epoch 33, cost  34.1627781424
# Pre-training layer 0, epoch 34, cost
#  33.7644739795
# Pre-training layer 0, epoch 35, cost  33.382655382
# Pre-training layer 0, epoch 36, cost  33.016736982
# Pre-training layer 0, epoch 37, cost  32.6661471953
# Pre-training layer 0, epoch 38, cost  32.3303281772
# Pre-training layer 0, epoch 39, cost  32.0087357694
# Pre-training layer 0, epoch 40, cost  31.7008394466
# Pre-training layer 0, epoch 41, cost
#  31.4061222641
# Pre-training layer 0, epoch 42, cost  31.1240808091
# Pre-training layer 0, epoch 43, cost  30.8542251564
# Pre-training layer 0, epoch 44, cost  30.5960788271
# Pre-training layer 0, epoch 45, cost  30.3491787494
# Pre-training layer 0, epoch 46, cost  30.1130752181
# Pre-training layer 0, epoch 47, cost  29.8873318507
# Pre-training layer 0, epoch 48, cost
#  29.6715255372
# Pre-training layer 0, epoch 49, cost  29.4652463796
# Pre-training layer 0, epoch 50, cost  29.2680976195
# Pre-training layer 0, epoch 51, cost  29.0796955499
# Pre-training layer 0, epoch 52, cost  28.8996694104
# Pre-training layer 0, epoch 53, cost  28.7276612632
# Pre-training layer 0, epoch 54, cost  28.5633258494
# Pre-training layer 0, epoch 55, cost
#  28.406330424
# Pre-training layer 0, epoch 56, cost  28.2563545709
# Pre-training layer 0, epoch 57, cost  28.1130899969
# Pre-training layer 0, epoch 58, cost  27.9762403061
# Pre-training layer 0, epoch 59, cost  27.8455207561
# Pre-training layer 0, epoch 60, cost  27.7206579963
# Pre-training layer 0, epoch 61, cost  27.6013897916
# Pre-training layer 0, epoch 62, cost
#  27.4874647318
# Pre-training layer 0, epoch 63, cost  27.3786419298
# Pre-training layer 0, epoch 64, cost  27.27469071
# Pre-training layer 0, epoch 65, cost  27.1753902892
# Pre-training layer 0, epoch 66, cost  27.0805294522
# Pre-training layer 0, epoch 67, cost  26.9899062238
# Pre-training layer 0, epoch 68, cost  26.903327539
# Pre-training layer 0, epoch 69, cost
#  26.8206089139
# Pre-training layer 0, epoch 70, cost  26.741574118
# Pre-training layer 0, epoch 71, cost  26.6660548497
# Pre-training layer 0, epoch 72, cost  26.5938904168
# Pre-training layer 0, epoch 73, cost  26.5249274227
# Pre-training layer 0, epoch 74, cost  26.4590194591
# Pre-training layer 0, epoch 75, cost  26.3960268067
# Pre-training layer 0, epoch 76, cost
#  26.3358161443
# Pre-training layer 0, epoch 77, cost  26.2782602665
# Pre-training layer 0, epoch 78, cost  26.2232378106
# Pre-training layer 0, epoch 79, cost  26.1706329941
# Pre-training layer 0, epoch 80, cost  26.1203353606
# Pre-training layer 0, epoch 81, cost  26.0722395367
# Pre-training layer 0, epoch 82, cost  26.0262449985
# Pre-training layer 0, epoch 83, cost
#  25.9822558475
# Pre-training layer 0, epoch 84, cost  25.940180597
# Pre-training layer 0, epoch 85, cost  25.899931967
# Pre-training layer 0, epoch 86, cost  25.8614266893
# Pre-training layer 0, epoch 87, cost  25.824585321
# Pre-training layer 0, epoch 88, cost  25.7893320667
# Pre-training layer 0, epoch 89, cost  25.7555946093
# Pre-training layer 0, epoch 90, cost
#  25.7233039486
# Pre-training layer 0, epoch 91, cost  25.6923942478
# Pre-training layer 0, epoch 92, cost  25.662802687
# Pre-training layer 0, epoch 93, cost  25.634469324
# Pre-training layer 0, epoch 94, cost  25.6073369616
# Pre-training layer 0, epoch 95, cost  25.5813510213
# Pre-training layer 0, epoch 96, cost  25.556459423
# Pre-training layer 0, epoch 97, cost
#  25.5326124705
# Pre-training layer 0, epoch 98, cost  25.5097627421
# Pre-training layer 0, epoch 99, cost  25.4878649867
# Pre-training layer 0, epoch 100, cost  25.4668760248
# Pre-training layer 0, epoch 101, cost  25.4467546536
# Pre-training layer 0, epoch 102, cost  25.4274615571
# Pre-training layer 0, epoch 103, cost  25.4089592201
# Pre-training layer 0, epoch 104, cost
#  25.391211846
# Pre-training layer 0, epoch 105, cost  25.3741852787
# Pre-training layer 0, epoch 106, cost  25.3578469278
# Pre-training layer 0, epoch 107, cost  25.3421656972
# Pre-training layer 0, epoch 108, cost  25.3271119173
# Pre-training layer 0, epoch 109, cost  25.3126572794
# Pre-training layer 0, epoch 110, cost  25.2987747742
# Pre-training layer 0, epoch 111, cost
#  25.2854386322
# Pre-training layer 0, epoch 112, cost  25.2726242669
# Pre-training layer 0, epoch 113, cost  25.260308221
# Pre-training layer 0, epoch 114, cost  25.2484681147
# Pre-training layer 0, epoch 115, cost  25.237082596
# Pre-training layer 0, epoch 116, cost  25.2261312939
# Pre-training layer 0, epoch 117, cost  25.215594773
# Pre-training layer 0, epoch 118, cost
#  25.2054544909
# Pre-training layer 0, epoch 119, cost  25.1956927568
# Pre-training layer 0, epoch 120, cost  25.1862926922
# Pre-training layer 0, epoch 121, cost  25.1772381938
# Pre-training layer 0, epoch 122, cost  25.1685138974
# Pre-training layer 0, epoch 123, cost  25.1601051437
# Pre-training layer 0, epoch 124, cost  25.151997946
# Pre-training layer 0, epoch 125, cost
#  25.1441789587
# Pre-training layer 0, epoch 126, cost  25.1366354477
# Pre-training layer 0, epoch 127, cost  25.1293552623
# Pre-training layer 0, epoch 128, cost  25.1223268079
# Pre-training layer 0, epoch 129, cost  25.1155390199
# Pre-training layer 0, epoch 130, cost  25.1089813398
# Pre-training layer 0, epoch 131, cost  25.1026436908
# Pre-training layer 0, epoch 132, cost
#  25.0965164563
# Pre-training layer 0, epoch 133, cost  25.0905904577
# Pre-training layer 0, epoch 134, cost  25.0848569346
# Pre-training layer 0, epoch 135, cost  25.079307525
# Pre-training layer 0, epoch 136, cost  25.0739342468
# Pre-training layer 0, epoch 137, cost  25.0687294804
# Pre-training layer 0, epoch 138, cost  25.0636859515
# Pre-training layer 0, epoch 139, cost
#  25.0587967152
# Pre-training layer 0, epoch 140, cost  25.0540551408
# Pre-training layer 0, epoch 141, cost  25.0494548969
# Pre-training layer 0, epoch 142, cost  25.0449899377
# Pre-training layer 0, epoch 143, cost  25.0406544898
# Pre-training layer 0, epoch 144, cost  25.0364430393
# Pre-training layer 0, epoch 145, cost  25.0323503201
# Pre-training layer 0, epoch 146, cost
#  25.0283713021
# Pre-training layer 0, epoch 147, cost  25.0245011805
# Pre-training layer 0, epoch 148, cost  25.0207353653
# Pre-training layer 0, epoch 149, cost  25.0170694712
# Pre-training layer 0, epoch 150, cost  25.0134993085
# Pre-training layer 0, epoch 151, cost  25.0100208738
# Pre-training layer 0, epoch 152, cost  25.0066303416
# Pre-training layer 0, epoch 153, cost
#  25.0033240559
# Pre-training layer 0, epoch 154, cost  25.0000985225
# Pre-training layer 0, epoch 155, cost  24.9969504018
# Pre-training layer 0, epoch 156, cost  24.9938765012
# Pre-training layer 0, epoch 157, cost  24.990873769
# Pre-training layer 0, epoch 158, cost  24.9879392873
# Pre-training layer 0, epoch 159, cost  24.9850702665
# Pre-training layer 0, epoch 160, cost
#  24.982264039
# Pre-training layer 0, epoch 161, cost  24.9795180539
# Pre-training layer 0, epoch 162, cost  24.9768298716
# Pre-training layer 0, epoch 163, cost  24.9741971586
# Pre-training layer 0, epoch 164, cost  24.9716176831
# Pre-training layer 0, epoch 165, cost  24.9690893099
# Pre-training layer 0, epoch 166, cost  24.9666099964
# Pre-training layer 0, epoch 167, cost
#  24.9641777884
# Pre-training layer 0, epoch 168, cost  24.9617908158
# Pre-training layer 0, epoch 169, cost  24.9594472891
# Pre-training layer 0, epoch 170, cost  24.9571454959
# Pre-training layer 0, epoch 171, cost  24.9548837971
# Pre-training layer 0, epoch 172, cost  24.9526606237
# Pre-training layer 0, epoch 173, cost  24.950474474
# Pre-training layer 0, epoch 174, cost
#  24.9483239102
# Pre-training layer 0, epoch 175, cost  24.9462075558
# Pre-training layer 0, epoch 176, cost  24.9441240926
# Pre-training layer 0, epoch 177, cost  24.9420722587
# Pre-training layer 0, epoch 178, cost  24.9400508452
# Pre-training layer 0, epoch 179, cost  24.9380586946
# Pre-training layer 0, epoch 180, cost  24.936094698
# Pre-training layer 0, epoch 181, cost
#  24.9341577932
# Pre-training layer 0, epoch 182, cost  24.9322469628
# Pre-training layer 0, epoch 183, cost  24.9303612318
# Pre-training layer 0, epoch 184, cost  24.9284996663
# Pre-training layer 0, epoch 185, cost  24.9266613711
# Pre-training layer 0, epoch 186, cost  24.9248454885
# Pre-training layer 0, epoch 187, cost  24.9230511965
# Pre-training layer 0, epoch 188, cost
#  24.9212777073
# Pre-training layer 0, epoch 189, cost  24.9195242654
# Pre-training layer 0, epoch 190, cost  24.9177901471
# Pre-training layer 0, epoch 191, cost  24.916074658
# Pre-training layer 0, epoch 192, cost  24.9143771329
# Pre-training layer 0, epoch 193, cost  24.9126969335
# Pre-training layer 0, epoch 194, cost  24.911033448
# Pre-training layer 0, epoch 195, cost
#  24.9093860894
# Pre-training layer 0, epoch 196, cost  24.9077542951
# Pre-training layer 0, epoch 197, cost  24.9061375251
# Pre-training layer 0, epoch 198, cost  24.9045352616
# Pre-training layer 0, epoch 199, cost  24.9029470078
# Pre-training layer 0, epoch 200, cost  24.9013722871
# Pre-training layer 0, epoch 201, cost  24.8998106422
# Pre-training layer 0, epoch 202, cost
#  24.8982616342
# Pre-training layer 0, epoch 203, cost  24.8967248421
# Pre-training layer 0, epoch 204, cost  24.8951998617
# Pre-training layer 0, epoch 205, cost  24.8936863051
# Pre-training layer 0, epoch 206, cost  24.8921838001
# Pre-training layer 0, epoch 207, cost  24.8906919892
# Pre-training layer 0, epoch 208, cost  24.8892105293
# Pre-training layer 0, epoch 209, cost
#  24.8877390909
# Pre-training layer 0, epoch 210, cost  24.8862773579
# Pre-training layer 0, epoch 211, cost  24.8848250265
# Pre-training layer 0, epoch 212, cost  24.8833818049
# Pre-training layer 0, epoch 213, cost  24.8819474131
# Pre-training layer 0, epoch 214, cost  24.8805215821
# Pre-training layer 0, epoch 215, cost  24.8791040533
# Pre-training layer 0, epoch 216, cost
#  24.8776945786
# Pre-training layer 0, epoch 217, cost  24.8762929193
# Pre-training layer 0, epoch 218, cost  24.8748988464
# Pre-training layer 0, epoch 219, cost  24.8735121397
# Pre-training layer 0, epoch 220, cost  24.8721325876
# Pre-training layer 0, epoch 221, cost  24.8707599868
# Pre-training layer 0, epoch 222, cost  24.8693941417
# Pre-training layer 0, epoch 223, cost
#  24.8680348647
# Pre-training layer 0, epoch 224, cost  24.8666819751
# Pre-training layer 0, epoch 225, cost  24.8653352993
# Pre-training layer 0, epoch 226, cost  24.8639946705
# Pre-training layer 0, epoch 227, cost  24.8626599282
# Pre-training layer 0, epoch 228, cost  24.8613309181
# Pre-training layer 0, epoch 229, cost  24.8600074919
# Pre-training layer 0, epoch 230, cost
#  24.8586895068
# Pre-training layer 0, epoch 231, cost  24.8573768257
# Pre-training layer 0, epoch 232, cost  24.8560693164
# Pre-training layer 0, epoch 233, cost  24.854766852
# Pre-training layer 0, epoch 234, cost  24.8534693102
# Pre-training layer 0, epoch 235, cost  24.8521765737
# Pre-training layer 0, epoch 236, cost  24.8508885291
# Pre-training layer 0, epoch 237, cost
#  24.8496050676
# Pre-training layer 0, epoch 238, cost  24.8483260845
# Pre-training layer 0, epoch 239, cost  24.847051479
# Pre-training layer 0, epoch 240, cost  24.8457811538
# Pre-training layer 0, epoch 241, cost  24.8445150157
# Pre-training layer 0, epoch 242, cost  24.8432529746
# Pre-training layer 0, epoch 243, cost  24.8419949439
# Pre-training layer 0, epoch 244, cost
#  24.8407408401
# Pre-training layer 0, epoch 245, cost  24.8394905829
# Pre-training layer 0, epoch 246, cost  24.8382440949
# Pre-training layer 0, epoch 247, cost  24.8370013015
# Pre-training layer 0, epoch 248, cost  24.835762131
# Pre-training layer 0, epoch 249, cost  24.8345265141
# Pre-training layer 1, epoch 0, cost
#  140.720828318
# Pre-training layer 1, epoch 1, cost  136.015546018
# Pre-training layer 1, epoch 2, cost  131.561047224
# Pre-training layer 1, epoch 3, cost
#  127.34857191
# Pre-training layer 1, epoch 4, cost  123.368683093
# Pre-training layer 1, epoch 5, cost  119.611500266
# Pre-training layer 1, epoch 6, cost
#  116.066896856
# Pre-training layer 1, epoch 7, cost  112.724662665
# Pre-training layer 1, epoch 8, cost  109.574635172
# Pre-training layer 1, epoch 9, cost
#  106.606804556
# Pre-training layer 1, epoch 10, cost  103.811397027
# Pre-training layer 1, epoch 11, cost  101.178940212
# Pre-training layer 1, epoch 12, cost
#  98.7003133521
# Pre-training layer 1, epoch 13, cost  96.3667842745
# Pre-training layer 1, epoch 14, cost  94.1700345418
# Pre-training layer 1, epoch 15, cost
#  92.1021739154
# Pre-training layer 1, epoch 16, cost  90.1557451893
# Pre-training layer 1, epoch 17, cost  88.3237205095
# Pre-training layer 1, epoch 18, cost
#  86.5994904077
# Pre-training layer 1, epoch 19, cost  84.9768468835
# Pre-training layer 1, epoch 20, cost  83.4499619499
# Pre-training layer 1, epoch 21, cost
#  82.0133630725
# Pre-training layer 1, epoch 22, cost  80.6619068911
# Pre-training layer 1, epoch 23, cost  79.3907525058
# Pre-training layer 1, epoch 24, cost
#  78.1953354496
# Pre-training layer 1, epoch 25, cost  77.0713432646
# Pre-training layer 1, epoch 26, cost  76.0146933645
# Pre-training layer 1, epoch 27, cost
#  75.0215136209
# Pre-training layer 1, epoch 28, cost  74.0881258671
# Pre-training layer 1, epoch 29, cost  73.2110322975
# Pre-training layer 1, epoch 30, cost
#  72.3869045561
# Pre-training layer 1, epoch 31, cost  71.6125751755
# Pre-training layer 1, epoch 32, cost  70.8850309422
# Pre-training layer 1, epoch 33, cost
#  70.2014077305
# Pre-training layer 1, epoch 34, cost  69.5589863562
# Pre-training layer 1, epoch 35, cost  68.9551890446
# Pre-training layer 1, epoch 36, cost
#  68.3875761688
# Pre-training layer 1, epoch 37, cost  67.853842994
# Pre-training layer 1, epoch 38, cost  67.3518162388
# Pre-training layer 1, epoch 39, cost
#  66.8794503351
# Pre-training layer 1, epoch 40, cost  66.4348233343
# Pre-training layer 1, epoch 41, cost  66.0161324527
# Pre-training layer 1, epoch 42, cost
#  65.621689288
# Pre-training layer 1, epoch 43, cost  65.249914762
# Pre-training layer 1, epoch 44, cost  64.8993338586
# Pre-training layer 1, epoch 45, cost
#  64.5685702324
# Pre-training layer 1, epoch 46, cost  64.2563407613
# Pre-training layer 1, epoch 47, cost  63.9614501114
# Pre-training layer 1, epoch 48, cost
#  63.6827853754
# Pre-training layer 1, epoch 49, cost  63.4193108367
# Pre-training layer 1, epoch 50, cost  63.1700628985
# Pre-training layer 1, epoch 51, cost
#  62.9341452129
# Pre-training layer 1, epoch 52, cost  62.7107240314
# Pre-training layer 1, epoch 53, cost  62.4990237927
# Pre-training layer 1, epoch 54, cost
#  62.2983229582
# Pre-training layer 1, epoch 55, cost  62.107950096
# Pre-training layer 1, epoch 56, cost  61.9272802144
# Pre-training layer 1, epoch 57, cost
#  61.7557313394
# Pre-training layer 1, epoch 58, cost  61.5927613278
# Pre-training layer 1, epoch 59, cost  61.4378649079
# Pre-training layer 1, epoch 60, cost
#  61.290570936
# Pre-training layer 1, epoch 61, cost  61.1504398571
# Pre-training layer 1, epoch 62, cost  61.0170613582
# Pre-training layer 1, epoch 63, cost
#  60.890052201
# Pre-training layer 1, epoch 64, cost  60.7690542226
# Pre-training layer 1, epoch 65, cost  60.6537324922
# Pre-training layer 1, epoch 66, cost
#  60.543773612
# Pre-training layer 1, epoch 67, cost  60.438884152
# Pre-training layer 1, epoch 68, cost  60.3387892074
# Pre-training layer 1, epoch 69, cost
#  60.2432310703
# Pre-training layer 1, epoch 70, cost  60.1519680052
# Pre-training layer 1, epoch 71, cost  60.0647731211
# Pre-training layer 1, epoch 72, cost
#  59.9814333314
# Pre-training layer 1, epoch 73, cost  59.9017483949
# Pre-training layer 1, epoch 74, cost  59.8255300309
# Pre-training layer 1, epoch 75, cost
#  59.7526011033
# Pre-training layer 1, epoch 76, cost  59.6827948656
# Pre-training layer 1, epoch 77, cost  59.6159542652
# Pre-training layer 1, epoch 78, cost
#  59.5519312987
# Pre-training layer 1, epoch 79, cost  59.4905864163
# Pre-training layer 1, epoch 80, cost  59.4317879704
# Pre-training layer 1, epoch 81, cost
#  59.375411705
# Pre-training layer 1, epoch 82, cost  59.3213402816
# Pre-training layer 1, epoch 83, cost  59.2694628411
# Pre-training layer 1, epoch 84, cost
#  59.2196745956
# Pre-training layer 1, epoch 85, cost  59.1718764503
# Pre-training layer 1, epoch 86, cost  59.1259746516
# Pre-training layer 1, epoch 87, cost
#  59.0818804603
# Pre-training layer 1, epoch 88, cost  59.0395098473
# Pre-training layer 1, epoch 89, cost  58.9987832097
# Pre-training layer 1, epoch 90, cost
#  58.9596251072
# Pre-training layer 1, epoch 91, cost  58.9219640159
# Pre-training layer 1, epoch 92, cost  58.8857320979
# Pre-training layer 1, epoch 93, cost
#  58.8508649877
# Pre-training layer 1, epoch 94, cost  58.8173015909
# Pre-training layer 1, epoch 95, cost  58.7849838976
# Pre-training layer 1, epoch 96, cost
#  58.7538568067
# Pre-training layer 1, epoch 97, cost  58.7238679621
# Pre-training layer 1, epoch 98, cost  58.6949675992
# Pre-training layer 1, epoch 99, cost
#  58.6671084006
# Pre-training layer 1, epoch 100, cost  58.6402453618
# Pre-training layer 1, epoch 101, cost  58.614335664
# Pre-training layer 1, epoch 102, cost
#  58.5893385558
# Pre-training layer 1, epoch 103, cost  58.5652152415
# Pre-training layer 1, epoch 104, cost  58.541928776
# Pre-training layer 1, epoch 105, cost
#  58.5194439668
# Pre-training layer 1, epoch 106, cost  58.4977272812
# Pre-training layer 1, epoch 107, cost  58.4767467588
# Pre-training layer 1, epoch 108, cost
#  58.4564719298
# Pre-training layer 1, epoch 109, cost  58.4368737376
# Pre-training layer 1, epoch 110, cost  58.417924466
# Pre-training layer 1, epoch 111, cost
#  58.3995976707
# Pre-training layer 1, epoch 112, cost  58.381868114
# Pre-training layer 1, epoch 113, cost  58.3647117046
# Pre-training layer 1, epoch 114, cost
#  58.3481054394
# Pre-training layer 1, epoch 115, cost  58.332027349
# Pre-training layer 1, epoch 116, cost  58.3164564467
# Pre-training layer 1, epoch 117, cost
#  58.3013726798
# Pre-training layer 1, epoch 118, cost  58.2867568835
# Pre-training layer 1, epoch 119, cost  58.2725907376
# Pre-training layer 1, epoch 120, cost
#  58.2588567256
# Pre-training layer 1, epoch 121, cost  58.2455380955
# Pre-training layer 1, epoch 122, cost  58.2326188235
# Pre-training layer 1, epoch 123, cost
#  58.2200835785
# Pre-training layer 1, epoch 124, cost  58.2079176897
# Pre-training layer 1, epoch 125, cost  58.1961071153
# Pre-training layer 1, epoch 126, cost
#  58.1846384122
# Pre-training layer 1, epoch 127, cost  58.1734987088
# Pre-training layer 1, epoch 128, cost  58.1626756779
# Pre-training layer 1, epoch 129, cost
#  58.1521575111
# Pre-training layer 1, epoch 130, cost  58.1419328957
# Pre-training layer 1, epoch 131, cost  58.1319909909
# Pre-training layer 1, epoch 132, cost
#  58.122321407
# Pre-training layer 1, epoch 133, cost  58.1129141845
# Pre-training layer 1, epoch 134, cost  58.1037597743
# Pre-training layer 1, epoch 135, cost
#  58.0948490198
# Pre-training layer 1, epoch 136, cost  58.0861731389
# Pre-training layer 1, epoch 137, cost  58.0777237071
# Pre-training layer 1, epoch 138, cost
#  58.0694926419
# Pre-training layer 1, epoch 139, cost  58.0614721875
# Pre-training layer 1, epoch 140, cost  58.0536549002
# Pre-training layer 1, epoch 141, cost
#  58.0460336348
# Pre-training layer 1, epoch 142, cost  58.0386015318
# Pre-training layer 1, epoch 143, cost  58.0313520045
# Pre-training layer 1, epoch 144, cost
#  58.0242787272
# Pre-training layer 1, epoch 145, cost  58.0173756243
# Pre-training layer 1, epoch 146, cost  58.0106368591
# Pre-training layer 1, epoch 147, cost
#  58.0040568239
# Pre-training layer 1, epoch 148, cost  57.9976301297
# Pre-training layer 1, epoch 149, cost  57.9913515976
# Pre-training layer 1, epoch 150, cost
#  57.9852162492
# Pre-training layer 1, epoch 151, cost  57.9792192986
# Pre-training layer 1, epoch 152, cost  57.973356144
# Pre-training layer 1, epoch 153, cost
#  57.9676223604
# Pre-training layer 1, epoch 154, cost  57.9620136916
# Pre-training layer 1, epoch 155, cost  57.9565260438
# Pre-training layer 1, epoch 156, cost
#  57.9511554782
# Pre-training layer 1, epoch 157, cost  57.9458982053
# Pre-training layer 1, epoch 158, cost  57.9407505784
# Pre-training layer 1, epoch 159, cost
#  57.9357090875
# Pre-training layer 1, epoch 160, cost  57.9307703543
# Pre-training layer 1, epoch 161, cost  57.9259311264
# Pre-training layer 1, epoch 162, cost
#  57.9211882721
# Pre-training layer 1, epoch 163, cost  57.9165387759
# Pre-training layer 1, epoch 164, cost  57.9119797338
# Pre-training layer 1, epoch 165, cost
#  57.9075083483
# Pre-training layer 1, epoch 166, cost  57.9031219248
# Pre-training layer 1, epoch 167, cost  57.898817867
# Pre-training layer 1, epoch 168, cost
#  57.8945936731
# Pre-training layer 1, epoch 169, cost  57.8904469323
# Pre-training layer 1, epoch 170, cost  57.886375321
# Pre-training layer 1, epoch 171, cost
#  57.8823765992
# Pre-training layer 1, epoch 172, cost  57.8784486077
# Pre-training layer 1, epoch 173, cost  57.8745892644
# Pre-training layer 1, epoch 174, cost
#  57.8707965615
# Pre-training layer 1, epoch 175, cost  57.8670685628
# Pre-training layer 1, epoch 176, cost  57.8634034007
# Pre-training layer 1, epoch 177, cost
#  57.8597992735
# Pre-training layer 1, epoch 178, cost  57.856254443
# Pre-training layer 1, epoch 179, cost  57.8527672321
# Pre-training layer 1, epoch 180, cost
#  57.8493360222
# Pre-training layer 1, epoch 181, cost  57.8459592512
# Pre-training layer 1, epoch 182, cost  57.8426354113
# Pre-training layer 1, epoch 183, cost
#  57.8393630469
# Pre-training layer 1, epoch 184, cost  57.8361407525
# Pre-training layer 1, epoch 185, cost  57.8329671711
# Pre-training layer 1, epoch 186, cost
#  57.8298409921
# Pre-training layer 1, epoch 187, cost  57.8267609496
# Pre-training layer 1, epoch 188, cost  57.8237258208
# Pre-training layer 1, epoch 189, cost
#  57.8207344243
# Pre-training layer 1, epoch 190, cost  57.8177856188
# Pre-training layer 1, epoch 191, cost  57.8148783011
# Pre-training layer 1, epoch 192, cost
#  57.8120114052
# Pre-training layer 1, epoch 193, cost  57.8091839007
# Pre-training layer 1, epoch 194, cost  57.8063947914
# Pre-training layer 1, epoch 195, cost
#  57.8036431141
# Pre-training layer 1, epoch 196, cost  57.8009279376
# Pre-training layer 1, epoch 197, cost  57.7982483611
# Pre-training layer 1, epoch 198, cost
#  57.7956035136
# Pre-training layer 1, epoch 199, cost  57.7929925521
# Pre-training layer 1, epoch 200, cost  57.7904146614
# Pre-training layer 1, epoch 201, cost
#  57.7878690525
# Pre-training layer 1, epoch 202, cost  57.7853549619
# Pre-training layer 1, epoch 203, cost  57.7828716506
# Pre-training layer 1, epoch 204, cost
#  57.7804184032
# Pre-training layer 1, epoch 205, cost  57.7779945271
# Pre-training layer 1, epoch 206, cost  57.7755993516
# Pre-training layer 1, epoch 207, cost
#  57.7732322272
# Pre-training layer 1, epoch 208, cost  57.7708925247
# Pre-training layer 1, epoch 209, cost  57.7685796347
# Pre-training layer 1, epoch 210, cost
#  57.7662929668
# Pre-training layer 1, epoch 211, cost  57.7640319486
# Pre-training layer 1, epoch 212, cost  57.7617960257
# Pre-training layer 1, epoch 213, cost
#  57.7595846604
# Pre-training layer 1, epoch 214, cost  57.7573973315
# Pre-training layer 1, epoch 215, cost  57.7552335336
# Pre-training layer 1, epoch 216, cost
#  57.7530927767
# Pre-training layer 1, epoch 217, cost  57.7509745853
# Pre-training layer 1, epoch 218, cost  57.7488784981
# Pre-training layer 1, epoch 219, cost
#  57.7468040678
# Pre-training layer 1, epoch 220, cost  57.7447508598
# Pre-training layer 1, epoch 221, cost  57.7427184527
# Pre-training layer 1, epoch 222, cost
#  57.7407064373
# Pre-training layer 1, epoch 223, cost  57.738714416
# Pre-training layer 1, epoch 224, cost  57.7367420029
# Pre-training layer 1, epoch 225, cost
#  57.7347888232
# Pre-training layer 1, epoch 226, cost  57.7328545125
# Pre-training layer 1, epoch 227, cost  57.730938717
# Pre-training layer 1, epoch 228, cost
#  57.7290410927
# Pre-training layer 1, epoch 229, cost  57.727161305
# Pre-training layer 1, epoch 230, cost  57.725299029
# Pre-training layer 1, epoch 231, cost
#  57.7234539483
# Pre-training layer 1, epoch 232, cost  57.7216257554
# Pre-training layer 1, epoch 233, cost  57.719814151
# Pre-training layer 1, epoch 234, cost
#  57.7180188439
# Pre-training layer 1, epoch 235, cost  57.7162395507
# Pre-training layer 1, epoch 236, cost  57.7144759955
# Pre-training layer 1, epoch 237, cost
#  57.7127279094
# Pre-training layer 1, epoch 238, cost  57.710995031
# Pre-training layer 1, epoch 239, cost  57.7092771051
# Pre-training layer 1, epoch 240, cost
#  57.7075738834
# Pre-training layer 1, epoch 241, cost  57.7058851239
# Pre-training layer 1, epoch 242, cost  57.7042105904
# Pre-training layer 1, epoch 243, cost
#  57.7025500529
# Pre-training layer 1, epoch 244, cost  57.7009032869
# Pre-training layer 1, epoch 245, cost  57.6992700735
# Pre-training layer 1, epoch 246, cost
#  57.697650199
# Pre-training layer 1, epoch 247, cost  57.696043455
# Pre-training layer 1, epoch 248, cost  57.6944496379
# Pre-training layer 1, epoch 249, cost
#  57.692868549
# ... getting the finetuning functions
# ... finetunning the model
# epoch 1, minibatch 4/4, validation error 61.000000 %
#  epoch 1, minibatch 4/4, test error of best model 27.000000 %
# epoch 2, minibatch 4/4, validation error 61.000000 %
# epoch 3, minibatch 4/4, validation error 60.000000 %
#  epoch 3, minibatch 4/4, test error of best model 27.000000 %
# epoch 4, minibatch 4/4, validation error 56.000000 %
#  epoch 4, minibatch 4/4, test error of best model 30.000000 %
# epoch 5, minibatch 4/4, validation error 60.000000 %
# epoch 6, minibatch 4/4, validation error 58.000000 %
# epoch 7, minibatch 4/4, validation error 58.000000 %
# epoch 8, minibatch 4/4, validation error 57.000000 %
# epoch 9, minibatch 4/4, validation error 58.000000 %
# epoch 10, minibatch 4/4, validation error 55.000000 %
#  epoch 10, minibatch 4/4, test error of best model 35.000000 %
# epoch 11, minibatch 4/4, validation error 54.000000 %
#  epoch 11, minibatch 4/4, test error of best model 36.000000 %
# epoch 12, minibatch 4/4, validation error 53.000000 %
#  epoch 12, minibatch 4/4, test error of best model 35.000000 %
# epoch 13, minibatch 4/4, validation error 53.000000 %
# epoch 14, minibatch 4/4, validation error 53.000000 %
# epoch 15, minibatch 4/4, validation error 53.000000 %
# epoch 16, minibatch 4/4, validation error 50.000000 %
#  epoch 16, minibatch 4/4, test error of best model 38.000000 %
# epoch 17, minibatch 4/4, validation error 50.000000 %
# epoch 18, minibatch 4/4, validation error 50.000000 %
# epoch 19, minibatch 4/4, validation error 50.000000 %
# epoch 20, minibatch 4/4, validation error 50.000000 %
# epoch 21, minibatch 4/4, validation error 50.000000 %
# epoch 22, minibatch 4/4, validation error 49.000000 %
#  epoch 22, minibatch 4/4, test error of best model 39.000000 %
# epoch 23, minibatch 4/4, validation error 49.000000 %
# epoch 24, minibatch 4/4, validation error 49.000000 %
# epoch 25, minibatch 4/4, validation error 49.000000 %
# epoch 26, minibatch 4/4, validation error 49.000000 %
# epoch 27, minibatch 4/4, validation error 49.000000 %
# epoch 28, minibatch 4/4, validation error 50.000000 %
# epoch 29, minibatch 4/4, validation error 50.000000 %
# epoch 30, minibatch 4/4, validation error 50.000000 %
# epoch 31, minibatch 4/4, validation error 51.000000 %
# epoch 32, minibatch 4/4, validation error 51.000000 %
# epoch 33, minibatch 4/4, validation error 53.000000 %
# epoch 34, minibatch 4/4, validation error 54.000000 %
# epoch 35, minibatch 4/4, validation error 53.000000 %
# epoch 36, minibatch 4/4, validation error 53.000000 %
# epoch 37, minibatch 4/4, validation error 53.000000 %
# epoch 38, minibatch 4/4, validation error 53.000000 %
# epoch 39, minibatch 4/4, validation error 53.000000 %
# epoch 40, minibatch 4/4, validation error 53.000000 %
# epoch 41, minibatch 4/4, validation error 53.000000 %
# epoch 42, minibatch 4/4, validation error 52.000000 %
# epoch 43, minibatch 4/4, validation error 53.000000 %
# epoch 44, minibatch 4/4, validation error 53.000000 %
# epoch 45, minibatch 4/4, validation error 53.000000 %
# epoch 46, minibatch 4/4, validation error 52.000000 %
# epoch 47, minibatch 4/4, validation error 52.000000 %
# epoch 48, minibatch 4/4, validation error 52.000000 %
# epoch 49, minibatch 4/4, validation error 52.000000 %
# epoch 50, minibatch 4/4, validation error 52.000000 %
# epoch 51, minibatch 4/4, validation error 52.000000 %
# epoch 52, minibatch 4/4, validation error 52.000000 %
# epoch 53, minibatch 4/4, validation error 52.000000 %
# epoch 54, minibatch 4/4, validation error 52.000000 %
# epoch 55, minibatch 4/4, validation error 52.000000 %
# epoch 56, minibatch 4/4, validation error 52.000000 %
# epoch 57, minibatch 4/4, validation error 51.000000 %
# epoch 58, minibatch 4/4, validation error 51.000000 %
# epoch 59, minibatch 4/4, validation error 51.000000 %
# epoch 60, minibatch 4/4, validation error 53.000000 %
# epoch 61, minibatch 4/4, validation error 53.000000 %
# epoch 62, minibatch 4/4, validation error 53.000000 %
# epoch 63, minibatch 4/4, validation error 54.000000 %
# epoch 64, minibatch 4/4, validation error 54.000000 %
# epoch 65, minibatch 4/4, validation error 54.000000 %
# epoch 66, minibatch 4/4, validation error 54.000000 %
# epoch 67, minibatch 4/4, validation error 54.000000 %
# epoch 68, minibatch 4/4, validation error 55.000000 %
# epoch 69, minibatch 4/4, validation error 55.000000 %
# epoch 70, minibatch 4/4, validation error 55.000000 %
# epoch 71, minibatch 4/4, validation error 55.000000 %
# epoch 72, minibatch 4/4, validation error 55.000000 %
# epoch 73, minibatch 4/4, validation error 54.000000 %
# epoch 74, minibatch 4/4, validation error 54.000000 %
# epoch 75, minibatch 4/4, validation error 54.000000 %
# epoch 76, minibatch 4/4, validation error 53.000000 %
# epoch 77, minibatch 4/4, validation error 53.000000 %
# epoch 78, minibatch 4/4, validation error 53.000000 %
# epoch 79, minibatch 4/4, validation error 53.000000 %
# epoch 80, minibatch 4/4, validation error 53.000000 %
# epoch 81, minibatch 4/4, validation error 53.000000 %
# epoch 82, minibatch 4/4, validation error 53.000000 %
# epoch 83, minibatch 4/4, validation error 53.000000 %
# epoch 84, minibatch 4/4, validation error 53.000000 %
# epoch 85, minibatch 4/4, validation error 53.000000 %
# epoch 86, minibatch 4/4, validation error 52.000000 %
# epoch 87, minibatch 4/4, validation error 51.000000 %
# epoch 88, minibatch 4/4, validation error 51.000000 %
# epoch 89, minibatch 4/4, validation error 51.000000 %
# epoch 90, minibatch 4/4, validation error 51.000000 %
# epoch 91, minibatch 4/4, validation error 51.000000 %
# epoch 92, minibatch 4/4, validation error 51.000000 %
# epoch 93, minibatch 4/4, validation error 51.000000 %
# epoch 94, minibatch 4/4, validation error 51.000000 %
# epoch 95, minibatch 4/4, validation error 51.000000 %
# epoch 96, minibatch 4/4, validation error 51.000000 %
# epoch 97, minibatch 4/4, validation error 51.000000 %
# epoch 98, minibatch 4/4, validation error 52.000000 %
# epoch 99, minibatch 4/4, validation error 52.000000 %
# epoch 100, minibatch 4/4, validation error 52.000000 %
# epoch 101, minibatch 4/4, validation error 52.000000 %
# epoch 102, minibatch 4/4, validation error 52.000000 %
# epoch 103, minibatch 4/4, validation error 52.000000 %
# epoch 104, minibatch 4/4, validation error 52.000000 %
# epoch 105, minibatch 4/4, validation error 52.000000 %
# epoch 106, minibatch 4/4, validation error 52.000000 %
# epoch 107, minibatch 4/4, validation error 52.000000 %
# epoch 108, minibatch 4/4, validation error 52.000000 %
# epoch 109, minibatch 4/4, validation error 52.000000 %
# epoch 110, minibatch 4/4, validation error 52.000000 %
# epoch 111, minibatch 4/4, validation error 52.000000 %
# epoch 112, minibatch 4/4, validation error 52.000000 %
# epoch 113, minibatch 4/4, validation error 52.000000 %
# epoch 114, minibatch 4/4, validation error 52.000000 %
# epoch 115, minibatch 4/4, validation error 51.000000 %
# epoch 116, minibatch 4/4, validation error 51.000000 %
# epoch 117, minibatch 4/4, validation error 51.000000 %
# epoch 118, minibatch 4/4, validation error 51.000000 %
# epoch 119, minibatch 4/4, validation error 51.000000 %
# epoch 120, minibatch 4/4, validation error 51.000000 %
# epoch 121, minibatch 4/4, validation error 51.000000 %
# epoch 122, minibatch 4/4, validation error 51.000000 %
# epoch 123, minibatch 4/4, validation error 50.000000 %
# epoch 124, minibatch 4/4, validation error 49.000000 %
# epoch 125, minibatch 4/4, validation error 49.000000 %
# epoch 126, minibatch 4/4, validation error 49.000000 %
# epoch 127, minibatch 4/4, validation error 49.000000 %
# epoch 128, minibatch 4/4, validation error 49.000000 %
# epoch 129, minibatch 4/4, validation error 49.000000 %
# epoch 130, minibatch 4/4, validation error 49.000000 %
# epoch 131, minibatch 4/4, validation error 49.000000 %
# epoch 132, minibatch 4/4, validation error 49.000000 %
# epoch 133, minibatch 4/4, validation error 49.000000 %
# epoch 134, minibatch 4/4, validation error 48.000000 %
#  epoch 134, minibatch 4/4, test error of best model 35.000000 %
# epoch 135, minibatch 4/4, validation error 46.000000 %
#  epoch 135, minibatch 4/4, test error of best model 34.000000 %
# epoch 136, minibatch 4/4, validation error 46.000000 %
# epoch 137, minibatch 4/4, validation error 46.000000 %
# epoch 138, minibatch 4/4, validation error 46.000000 %
# epoch 139, minibatch 4/4, validation error 46.000000 %
# epoch 140, minibatch 4/4, validation error 45.000000 %
#  epoch 140, minibatch 4/4, test error of best model 36.000000 %
# epoch 141, minibatch 4/4, validation error 46.000000 %
# epoch 142, minibatch 4/4, validation error 46.000000 %
# epoch 143, minibatch 4/4, validation error 46.000000 %
# epoch 144, minibatch 4/4, validation error 48.000000 %
# epoch 145, minibatch 4/4, validation error 48.000000 %
# epoch 146, minibatch 4/4, validation error 49.000000 %
# epoch 147, minibatch 4/4, validation error 50.000000 %
# epoch 148, minibatch 4/4, validation error 50.000000 %
# epoch 149, minibatch 4/4, validation error 50.000000 %
# epoch 150, minibatch 4/4, validation error 51.000000 %
# epoch 151, minibatch 4/4, validation error 51.000000 %
# epoch 152, minibatch 4/4, validation error 51.000000 %
# epoch 153, minibatch 4/4, validation error 51.000000 %
# epoch 154, minibatch 4/4, validation error 51.000000 %
# epoch 155, minibatch 4/4, validation error 51.000000 %
# epoch 156, minibatch 4/4, validation error 52.000000 %
# epoch 157, minibatch 4/4, validation error 52.000000 %
# epoch 158, minibatch 4/4, validation error 52.000000 %
# epoch 159, minibatch 4/4, validation error 52.000000 %
# epoch 160, minibatch 4/4, validation error 51.000000 %
# epoch 161, minibatch 4/4, validation error 51.000000 %
# epoch 162, minibatch 4/4, validation error 50.000000 %
# epoch 163, minibatch 4/4, validation error 50.000000 %
# epoch 164, minibatch 4/4, validation error 50.000000 %
# epoch 165, minibatch 4/4, validation error 49.000000 %
# epoch 166, minibatch 4/4, validation error 49.000000 %
# epoch 167, minibatch 4/4, validation error 49.000000 %
# epoch 168, minibatch 4/4, validation error 49.000000 %
# epoch 169, minibatch 4/4, validation error 49.000000 %
# epoch 170, minibatch 4/4, validation error 49.000000 %
# epoch 171, minibatch 4/4, validation error 49.000000 %
# epoch 172, minibatch 4/4, validation error 49.000000 %
# epoch 173, minibatch 4/4, validation error 48.000000 %
# epoch 174, minibatch 4/4, validation error 48.000000 %
# epoch 175, minibatch 4/4, validation error 48.000000 %
# epoch 176, minibatch 4/4, validation error 48.000000 %
# epoch 177, minibatch 4/4, validation error 48.000000 %
# epoch 178, minibatch 4/4, validation error 48.000000 %
# epoch 179, minibatch 4/4, validation error 48.000000 %
# epoch 180, minibatch 4/4, validation error 48.000000 %
# epoch 181, minibatch 4/4, validation error 48.000000 %
# epoch 182, minibatch 4/4, validation error 47.000000 %
# epoch 183, minibatch 4/4, validation error 47.000000 %
# epoch 184, minibatch 4/4, validation error 47.000000 %
# epoch 185, minibatch 4/4, validation error 47.000000 %
# epoch 186, minibatch 4/4, validation error 47.000000 %
# epoch 187, minibatch 4/4, validation error 46.000000 %
# epoch 188, minibatch 4/4, validation error 46.000000 %
# epoch 189, minibatch 4/4, validation error 46.000000 %
# epoch 190, minibatch 4/4, validation error 46.000000 %
# epoch 191, minibatch 4/4, validation error 45.000000 %
# epoch 192, minibatch 4/4, validation error 45.000000 %
# epoch 193, minibatch 4/4, validation error 45.000000 %
# epoch 194, minibatch 4/4, validation error 45.000000 %
# epoch 195, minibatch 4/4, validation error 45.000000 %
# epoch 196, minibatch 4/4, validation error 45.000000 %
# epoch 197, minibatch 4/4, validation error 45.000000 %
# epoch 198, minibatch 4/4, validation error 45.000000 %
# epoch 199, minibatch 4/4, validation error 45.000000 %
# epoch 200, minibatch 4/4, validation error 45.000000 %
# epoch 201, minibatch 4/4, validation error 45.000000 %
# epoch 202, minibatch 4/4, validation error 45.000000 %
# epoch 203, minibatch 4/4, validation error 44.000000 %
#  epoch 203, minibatch 4/4, test error of best model 36.000000 %
# epoch 204, minibatch 4/4, validation error 43.000000 %
#  epoch 204, minibatch 4/4, test error of best model 35.000000 %
# epoch 205, minibatch 4/4, validation error 43.000000 %
# epoch 206, minibatch 4/4, validation error 43.000000 %
# epoch 207, minibatch 4/4, validation error 45.000000 %
# epoch 208, minibatch 4/4, validation error 45.000000 %
# epoch 209, minibatch 4/4, validation error 45.000000 %
# epoch 210, minibatch 4/4, validation error 45.000000 %
# epoch 211, minibatch 4/4, validation error 45.000000 %
# epoch 212, minibatch 4/4, validation error 45.000000 %
# epoch 213, minibatch 4/4, validation error 45.000000 %
# epoch 214, minibatch 4/4, validation error 45.000000 %
# epoch 215, minibatch 4/4, validation error 44.000000 %
# epoch 216, minibatch 4/4, validation error 44.000000 %
# epoch 217, minibatch 4/4, validation error 44.000000 %
# epoch 218, minibatch 4/4, validation error 45.000000 %
# epoch 219, minibatch 4/4, validation error 45.000000 %
# epoch 220, minibatch 4/4, validation error 45.000000 %
# epoch 221, minibatch 4/4, validation error 45.000000 %
# epoch 222, minibatch 4/4, validation error 45.000000 %
# epoch 223, minibatch 4/4, validation error 45.000000 %
# epoch 224, minibatch 4/4, validation error 45.000000 %
# epoch 225, minibatch 4/4, validation error 45.000000 %
# epoch 226, minibatch 4/4, validation error 45.000000 %
# epoch 227, minibatch 4/4, validation error 46.000000 %
# epoch 228, minibatch 4/4, validation error 46.000000 %
# epoch 229, minibatch 4/4, validation error 45.000000 %
# epoch 230, minibatch 4/4, validation error 45.000000 %
# epoch 231, minibatch 4/4, validation error 45.000000 %
# epoch 232, minibatch 4/4, validation error 45.000000 %
# epoch 233, minibatch 4/4, validation error 45.000000 %
# epoch 234, minibatch 4/4, validation error 45.000000 %
# epoch 235, minibatch 4/4, validation error 45.000000 %
# epoch 236, minibatch 4/4, validation error 45.000000 %
# epoch 237, minibatch 4/4, validation error 45.000000 %
# epoch 238, minibatch 4/4, validation error 45.000000 %
# epoch 239, minibatch 4/4, validation error 45.000000 %
# epoch 240, minibatch 4/4, validation error 45.000000 %
# epoch 241, minibatch 4/4, validation error 45.000000 %
# epoch 242, minibatch 4/4, validation error 45.000000 %
# epoch 243, minibatch 4/4, validation error 45.000000 %
# epoch 244, minibatch 4/4, validation error 45.000000 %
# epoch 245, minibatch 4/4, validation error 45.000000 %
# epoch 246, minibatch 4/4, validation error 43.000000 %
# epoch 247, minibatch 4/4, validation error 43.000000 %
# epoch 248, minibatch 4/4, validation error 43.000000 %
# epoch 249, minibatch 4/4, validation error 43.000000 %
# epoch 250, minibatch 4/4, validation error 44.000000 %
# epoch 251, minibatch 4/4, validation error 44.000000 %
# epoch 252, minibatch 4/4, validation error 44.000000 %
# epoch 253, minibatch 4/4, validation error 44.000000 %
# epoch 254, minibatch 4/4, validation error 44.000000 %
# epoch 255, minibatch 4/4, validation error 44.000000 %
# epoch 256, minibatch 4/4, validation error 44.000000 %
# epoch 257, minibatch 4/4, validation error 44.000000 %
# epoch 258, minibatch 4/4, validation error 44.000000 %
# epoch 259, minibatch 4/4, validation error 44.000000 %
# epoch 260, minibatch 4/4, validation error 44.000000 %
# epoch 261, minibatch 4/4, validation error 44.000000 %
# epoch 262, minibatch 4/4, validation error 44.000000 %
# epoch 263, minibatch 4/4, validation error 44.000000 %
# epoch 264, minibatch 4/4, validation error 44.000000 %
# epoch 265, minibatch 4/4, validation error 44.000000 %
# epoch 266, minibatch 4/4, validation error 44.000000 %
# epoch 267, minibatch 4/4, validation error 44.000000 %
# epoch 268, minibatch 4/4, validation error 44.000000 %
# epoch 269, minibatch 4/4, validation error 44.000000 %
# epoch 270, minibatch 4/4, validation error 44.000000 %
# epoch 271, minibatch 4/4, validation error 44.000000 %
# epoch 272, minibatch 4/4, validation error 44.000000 %
# epoch 273, minibatch 4/4, validation error 44.000000 %
# epoch 274, minibatch 4/4, validation error 44.000000 %
# epoch 275, minibatch 4/4, validation error 44.000000 %
# epoch 276, minibatch 4/4, validation error 44.000000 %
# epoch 277, minibatch 4/4, validation error 44.000000 %
# epoch 278, minibatch 4/4, validation error 43.000000 %
# epoch 279, minibatch 4/4, validation error 43.000000 %
# epoch 280, minibatch 4/4, validation error 43.000000 %
# epoch 281, minibatch 4/4, validation error 43.000000 %
# epoch 282, minibatch 4/4, validation error 43.000000 %
# epoch 283, minibatch 4/4, validation error 43.000000 %
# epoch 284, minibatch 4/4, validation error 43.000000 %
# epoch 285, minibatch 4/4, validation error 44.000000 %
# epoch 286, minibatch 4/4, validation error 44.000000 %
# epoch 287, minibatch 4/4, validation error 44.000000 %
# epoch 288, minibatch 4/4, validation error 44.000000 %
# epoch 289, minibatch 4/4, validation error 44.000000 %
# epoch 290, minibatch 4/4, validation error 44.000000 %
# epoch 291, minibatch 4/4, validation error 44.000000 %
# epoch 292, minibatch 4/4, validation error 44.000000 %
# epoch 293, minibatch 4/4, validation error 44.000000 %
# epoch 294, minibatch 4/4, validation error 44.000000 %
# epoch 295, minibatch 4/4, validation error 44.000000 %
# epoch 296, minibatch 4/4, validation error 44.000000 %
# epoch 297, minibatch 4/4, validation error 44.000000 %
# epoch 298, minibatch 4/4, validation error 44.000000 %
# epoch 299, minibatch 4/4, validation error 44.000000 %
# epoch 300, minibatch 4/4, validation error 44.000000 %
# epoch 301, minibatch 4/4, validation error 44.000000 %
# epoch 302, minibatch 4/4, validation error 44.000000 %
# epoch 303, minibatch 4/4, validation error 44.000000 %
# epoch 304, minibatch 4/4, validation error 44.000000 %
# epoch 305, minibatch 4/4, validation error 44.000000 %
# epoch 306, minibatch 4/4, validation error 44.000000 %
# epoch 307, minibatch 4/4, validation error 43.000000 %
# epoch 308, minibatch 4/4, validation error 43.000000 %
# epoch 309, minibatch 4/4, validation error 43.000000 %
# epoch 310, minibatch 4/4, validation error 43.000000 %
# epoch 311, minibatch 4/4, validation error 43.000000 %
# epoch 312, minibatch 4/4, validation error 42.000000 %
#  epoch 312, minibatch 4/4, test error of best model 31.000000 %
# epoch 313, minibatch 4/4, validation error 42.000000 %
# epoch 314, minibatch 4/4, validation error 41.000000 %
#  epoch 314, minibatch 4/4, test error of best model 30.000000 %
# epoch 315, minibatch 4/4, validation error 41.000000 %
# epoch 316, minibatch 4/4, validation error 41.000000 %
# epoch 317, minibatch 4/4, validation error 41.000000 %
# epoch 318, minibatch 4/4, validation error 41.000000 %
# epoch 319, minibatch 4/4, validation error 41.000000 %
# epoch 320, minibatch 4/4, validation error 41.000000 %
# epoch 321, minibatch 4/4, validation error 41.000000 %
# epoch 322, minibatch 4/4, validation error 42.000000 %
# epoch 323, minibatch 4/4, validation error 42.000000 %
# epoch 324, minibatch 4/4, validation error 42.000000 %
# epoch 325, minibatch 4/4, validation error 42.000000 %
# epoch 326, minibatch 4/4, validation error 41.000000 %
# epoch 327, minibatch 4/4, validation error 41.000000 %
# epoch 328, minibatch 4/4, validation error 42.000000 %
# epoch 329, minibatch 4/4, validation error 42.000000 %
# epoch 330, minibatch 4/4, validation error 42.000000 %
# epoch 331, minibatch 4/4, validation error 42.000000 %
# epoch 332, minibatch 4/4, validation error 41.000000 %
# epoch 333, minibatch 4/4, validation error 41.000000 %
# epoch 334, minibatch 4/4, validation error 41.000000 %
# epoch 335, minibatch 4/4, validation error 41.000000 %
# epoch 336, minibatch 4/4, validation error 41.000000 %
# epoch 337, minibatch 4/4, validation error 41.000000 %
# epoch 338, minibatch 4/4, validation error 41.000000 %
# epoch 339, minibatch 4/4, validation error 41.000000 %
# epoch 340, minibatch 4/4, validation error 41.000000 %
# epoch 341, minibatch 4/4, validation error 41.000000 %
# epoch 342, minibatch 4/4, validation error 41.000000 %
# epoch 343, minibatch 4/4, validation error 41.000000 %
# epoch 344, minibatch 4/4, validation error 40.000000 %
#  epoch 344, minibatch 4/4, test error of best model 30.000000 %
# epoch 345, minibatch 4/4, validation error 40.000000 %
# epoch 346, minibatch 4/4, validation error 40.000000 %
# epoch 347, minibatch 4/4, validation error 41.000000 %
# epoch 348, minibatch 4/4, validation error 41.000000 %
# epoch 349, minibatch 4/4, validation error 41.000000 %
# epoch 350, minibatch 4/4, validation error 41.000000 %
# epoch 351, minibatch 4/4, validation error 41.000000 %
# epoch 352, minibatch 4/4, validation error 41.000000 %
# epoch 353, minibatch 4/4, validation error 41.000000 %
# epoch 354, minibatch 4/4, validation error 41.000000 %
# epoch 355, minibatch 4/4, validation error 41.000000 %
# epoch 356, minibatch 4/4, validation error 41.000000 %
# epoch 357, minibatch 4/4, validation error 41.000000 %
# epoch 358, minibatch 4/4, validation error 41.000000 %
# epoch 359, minibatch 4/4, validation error 41.000000 %
# epoch 360, minibatch 4/4, validation error 40.000000 %
# epoch 361, minibatch 4/4, validation error 40.000000 %
# epoch 362, minibatch 4/4, validation error 40.000000 %
# epoch 363, minibatch 4/4, validation error 40.000000 %
# epoch 364, minibatch 4/4, validation error 40.000000 %
# epoch 365, minibatch 4/4, validation error 40.000000 %
# epoch 366, minibatch 4/4, validation error 40.000000 %
# epoch 367, minibatch 4/4, validation error 39.000000 %
#  epoch 367, minibatch 4/4, test error of best model 29.000000 %
# epoch 368, minibatch 4/4, validation error 39.000000 %
# epoch 369, minibatch 4/4, validation error 39.000000 %
# epoch 370, minibatch 4/4, validation error 39.000000 %
# epoch 371, minibatch 4/4, validation error 39.000000 %
# epoch 372, minibatch 4/4, validation error 40.000000 %
# ...
# epoch 828, minibatch 2/2, validation error nan %
# epoch 829, minibatch 2/2, validation error nan %
# epoch 830, minibatch 2/2, validation error nan %
# epoch 831, minibatch 2/2, validation error nan %
# epoch 832, minibatch 2/2, validation error nan %
# epoch 833, minibatch 2/2, validation error nan %
# epoch 834, minibatch 2/2, validation error nan %
# epoch 835, minibatch 2/2, validation error nan %
# epoch 836, minibatch 2/2, validation error nan %
# epoch 837, minibatch 2/2, validation error nan %
# epoch 838, minibatch 2/2, validation error nan %
# epoch 839, minibatch 2/2, validation error nan %
# epoch 840, minibatch 2/2, validation error nan %
# epoch 841, minibatch 2/2, validation error nan %
# epoch 842, minibatch 2/2, validation error nan %
# epoch 843, minibatch 2/2, validation error nan %
# epoch 844, minibatch 2/2, validation error nan %
# epoch 845, minibatch 2/2, validation error nan %
# epoch 846, minibatch 2/2, validation error nan %
# epoch 847, minibatch 2/2, validation error nan %
# epoch 848, minibatch 2/2, validation error nan %
# epoch 849, minibatch 2/2, validation error nan %
# epoch 850, minibatch 2/2, validation error nan %
# epoch 851, minibatch 2/2, validation error nan %
# epoch 852, minibatch 2/2, validation error nan %
# epoch 853, minibatch 2/2, validation error nan %
# epoch 854, minibatch 2/2, validation error nan %
# epoch 855, minibatch 2/2, validation error nan %
# epoch 856, minibatch 2/2, validation error nan %
# epoch 857, minibatch 2/2, validation error nan %
# epoch 858, minibatch 2/2, validation error nan %
# epoch 859, minibatch 2/2, validation error nan %
# epoch 860, minibatch 2/2, validation error nan %
# epoch 861, minibatch 2/2, validation error nan %
# epoch 862, minibatch 2/2, validation error nan %
# epoch 863, minibatch 2/2, validation error nan %
# epoch 864, minibatch 2/2, validation error nan %
# epoch 865, minibatch 2/2, validation error nan %
# epoch 866, minibatch 2/2, validation error nan %
# epoch 867, minibatch 2/2, validation error nan %
# epoch 868, minibatch 2/2, validation error nan %
# epoch 869, minibatch 2/2, validation error nan %
# epoch 870, minibatch 2/2, validation error nan %
# epoch 871, minibatch 2/2, validation error nan %
# epoch 872, minibatch 2/2, validation error nan %
# epoch 873, minibatch 2/2, validation error nan %
# epoch 874, minibatch 2/2, validation error nan %
# epoch 875, minibatch 2/2, validation error nan %
# epoch 876, minibatch 2/2, validation error nan %
# epoch 877, minibatch 2/2, validation error nan %
# epoch 878, minibatch 2/2, validation error nan %
# epoch 879, minibatch 2/2, validation error nan %
# epoch 880, minibatch 2/2, validation error nan %
# epoch 881, minibatch 2/2, validation error nan %
# epoch 882, minibatch 2/2, validation error nan %
# epoch 883, minibatch 2/2, validation error nan %
# epoch 884, minibatch 2/2, validation error nan %
# epoch 885, minibatch 2/2, validation error nan %
# epoch 886, minibatch 2/2, validation error nan %
# epoch 887, minibatch 2/2, validation error nan %
# epoch 888, minibatch 2/2, validation error nan %
# epoch 889, minibatch 2/2, validation error nan %
# epoch 890, minibatch 2/2, validation error nan %
# epoch 891, minibatch 2/2, validation error nan %
# epoch 892, minibatch 2/2, validation error nan %
# epoch 893, minibatch 2/2, validation error nan %
# epoch 894, minibatch 2/2, validation error nan %
# epoch 895, minibatch 2/2, validation error nan %
# epoch 896, minibatch 2/2, validation error nan %
# epoch 897, minibatch 2/2, validation error nan %
# epoch 898, minibatch 2/2, validation error nan %
# epoch 899, minibatch 2/2, validation error nan %
# epoch 900, minibatch 2/2, validation error nan %
# epoch 901, minibatch 2/2, validation error nan %
# epoch 902, minibatch 2/2, validation error nan %
# epoch 903, minibatch 2/2, validation error nan %
# epoch 904, minibatch 2/2, validation error nan %
# epoch 905, minibatch 2/2, validation error nan %
# epoch 906, minibatch 2/2, validation error nan %
# epoch 907, minibatch 2/2, validation error nan %
# epoch 908, minibatch 2/2, validation error nan %
# epoch 909, minibatch 2/2, validation error nan %
# epoch 910, minibatch 2/2, validation error nan %
# epoch 911, minibatch 2/2, validation error nan %
# epoch 912, minibatch 2/2, validation error nan %
# epoch 913, minibatch 2/2, validation error nan %
# epoch 914, minibatch 2/2, validation error nan %
# epoch 915, minibatch 2/2, validation error nan %
# epoch 916, minibatch 2/2, validation error nan %
# epoch 917, minibatch 2/2, validation error nan %
# epoch 918, minibatch 2/2, validation error nan %
# epoch 919, minibatch 2/2, validation error nan %
# epoch 920, minibatch 2/2, validation error nan %
# epoch 921, minibatch 2/2, validation error nan %
# epoch 922, minibatch 2/2, validation error nan %
# epoch 923, minibatch 2/2, validation error nan %
# epoch 924, minibatch 2/2, validation error nan %
# epoch 925, minibatch 2/2, validation error nan %
# epoch 926, minibatch 2/2, validation error nan %
# epoch 927, minibatch 2/2, validation error nan %
# epoch 928, minibatch 2/2, validation error nan %
# epoch 929, minibatch 2/2, validation error nan %
# epoch 930, minibatch 2/2, validation error nan %
# epoch 931, minibatch 2/2, validation error nan %
# epoch 932, minibatch 2/2, validation error nan %
# epoch 933, minibatch 2/2, validation error nan %
# epoch 934, minibatch 2/2, validation error nan %
# epoch 935, minibatch 2/2, validation error nan %
# epoch 936, minibatch 2/2, validation error nan %
# epoch 937, minibatch 2/2, validation error nan %
# epoch 938, minibatch 2/2, validation error nan %
# epoch 939, minibatch 2/2, validation error nan %
# epoch 940, minibatch 2/2, validation error nan %
# epoch 941, minibatch 2/2, validation error nan %
# epoch 942, minibatch 2/2, validation error nan %
# epoch 943, minibatch 2/2, validation error nan %
# epoch 944, minibatch 2/2, validation error nan %
# epoch 945, minibatch 2/2, validation error nan %
# epoch 946, minibatch 2/2, validation error nan %
# epoch 947, minibatch 2/2, validation error nan %
# epoch 948, minibatch 2/2, validation error nan %
# epoch 949, minibatch 2/2, validation error nan %
# epoch 950, minibatch 2/2, validation error nan %
# epoch 951, minibatch 2/2, validation error nan %
# epoch 952, minibatch 2/2, validation error nan %
# epoch 953, minibatch 2/2, validation error nan %
# epoch 954, minibatch 2/2, validation error nan %
# epoch 955, minibatch 2/2, validation error nan %
# epoch 956, minibatch 2/2, validation error nan %
# epoch 957, minibatch 2/2, validation error nan %
# epoch 958, minibatch 2/2, validation error nan %
# epoch 959, minibatch 2/2, validation error nan %
# epoch 960, minibatch 2/2, validation error nan %
# epoch 961, minibatch 2/2, validation error nan %
# epoch 962, minibatch 2/2, validation error nan %
# epoch 963, minibatch 2/2, validation error nan %
# epoch 964, minibatch 2/2, validation error nan %
# epoch 965, minibatch 2/2, validation error nan %
# epoch 966, minibatch 2/2, validation error nan %
# epoch 967, minibatch 2/2, validation error nan %
# epoch 968, minibatch 2/2, validation error nan %
# epoch 969, minibatch 2/2, validation error nan %
# epoch 970, minibatch 2/2, validation error nan %
# epoch 971, minibatch 2/2, validation error nan %
# epoch 972, minibatch 2/2, validation error nan %
# epoch 973, minibatch 2/2, validation error nan %
# epoch 974, minibatch 2/2, validation error nan %
# epoch 975, minibatch 2/2, validation error nan %
# epoch 976, minibatch 2/2, validation error nan %
# epoch 977, minibatch 2/2, validation error nan %
# epoch 978, minibatch 2/2, validation error nan %
# epoch 979, minibatch 2/2, validation error nan %
# epoch 980, minibatch 2/2, validation error nan %
# epoch 981, minibatch 2/2, validation error nan %
# epoch 982, minibatch 2/2, validation error nan %
# epoch 983, minibatch 2/2, validation error nan %
# epoch 984, minibatch 2/2, validation error nan %
# epoch 985, minibatch 2/2, validation error nan %
# epoch 986, minibatch 2/2, validation error nan %
# epoch 987, minibatch 2/2, validation error nan %
# epoch 988, minibatch 2/2, validation error nan %
# epoch 989, minibatch 2/2, validation error nan %
# epoch 990, minibatch 2/2, validation error nan %
# epoch 991, minibatch 2/2, validation error nan %
# epoch 992, minibatch 2/2, validation error nan %
# epoch 993, minibatch 2/2, validation error nan %
# epoch 994, minibatch 2/2, validation error nan %
# epoch 995, minibatch 2/2, validation error nan %
# epoch 996, minibatch 2/2, validation error nan %
# epoch 997, minibatch 2/2, validation error nan %
# epoch 998, minibatch 2/2, validation error nan %
# epoch 999, minibatch 2/2, validation error nan %
# epoch 1000, minibatch 2/2, validation error nan %
# hidden_layers_sizes: [100, 100]
# corruption_levels: [0, 0]
# train accuracy:
#  78.5%
# precision:  73.2%
# recall:  90.3%
# testing accuracy:  69.2%
# precision:  67.0%
# recall:  75.6%
# 17
# SVM
# precision on test:
#  0.545454545455
# recall on test:  0.486486486486
# precision on training:  0.618421052632
# recall on training:  0.508108108108
# direct deep learning
#
#
#
# ... building the model
# ... getting the pretraining functions
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-92363cd2f153> in <module>()
#       1 one_ddi_family = LOO_out_performance_for_one_ddi(ddi)
# ----> 2 one_ddi_family.get_LOO_perfermance('FisherM1', '')
#
# <ipython-input-11-954d52491ffb> in get_LOO_perfermance(self, fisher_mode, settings)
#     111                              hidden_layers_sizes = hidden_layers_sizes, corruption_levels = corruption_levels, batch_size = batch_size , \
#     112                              training_epochs = training_epochs, pretraining_epochs = pretraining_epochs,
# --> 113                              pretrain_lr = pretrain_lr, finetune_lr=finetune_lr
#     114                  )
#     115                 print 'hidden_layers_sizes:', hidden_layers_sizes
#
# /home/du/Dropbox/Project/libs/DL_libs.py in trainSda(X_train_minmax, y_train, X_validation_minmax, y_validation, X_test_minmax, y_test, pretraining_X_minmax, hidden_layers_sizes, corruption_levels, batch_size, training_epochs, pretraining_epochs, pretrain_lr, finetune_lr)
#     624     if pretraining_X_minmax == None:
#     625         pretraining_fns = sda.pretraining_functions(train_set_x=train_set_x,
# --> 626                                                     batch_size=batch_size)
#     627     else:
#     628         pretraining_X_minmax  = shuffle(pretraining_X_minmax, random_state=0)
#
# /home/du/Dropbox/Project/libs/DL_libs.py in pretraining_functions(self, train_set_x, batch_size)
#     495                                  updates=updates,
#     496                                  givens={self.x: train_set_x[batch_begin:
# --> 497                                                              batch_end]})
#     498             # append `fn` to the list of functions
#     499             pretrain_fns.append(fn)
#
# /usr/local/lib/python2.7/dist-packages/theano/compile/function.pyc in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     221                 allow_input_downcast=allow_input_downcast,
#     222                 on_unused_input=on_unused_input,
# --> 223                 profile=profile)
#     224     # We need to add the flag check_aliased inputs if we have any mutable or
#     225     # borrowed used defined inputs
#
# /usr/local/lib/python2.7/dist-packages/theano/compile/pfunc.pyc in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     510     return orig_function(inputs, cloned_outputs, mode,
#     511             accept_inplace=accept_inplace, name=name, profile=profile,
# --> 512             on_unused_input=on_unused_input)
#     513
#     514
#
# /usr/local/lib/python2.7/dist-packages/theano/compile/function_module.pyc in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input)
#    1309                    accept_inplace=accept_inplace,
#    1310                    profile=profile,
# -> 1311                    on_unused_input=on_unused_input).create(
#    1312                        defaults)
#    1313
#
# /usr/local/lib/python2.7/dist-packages/theano/compile/function_module.pyc in __init__(self, inputs, outputs, mode, accept_inplace, function_builder, profile, on_unused_input)
#    1020             gof.Op.add_stack_trace_on_call = False
#    1021             start_optimizer = time.time()
# -> 1022             optimizer_profile = optimizer(fgraph)
#    1023             end_optimizer = time.time()
#    1024             opt_time = end_optimizer - start_optimizer
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/opt.pyc in __call__(self, fgraph)
#      89         Same as self.optimize(fgraph)
#      90         """
# ---> 91         return self.optimize(fgraph)
#      92
#      93     def add_requirements(self, fgraph):
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/opt.pyc in optimize(self, fgraph, *args, **kwargs)
#      80             orig = theano.tensor.basic.constant.enable
#      81             theano.tensor.basic.constant.enable = False
# ---> 82             ret = self.apply(fgraph, *args, **kwargs)
#      83         finally:
#      84             theano.tensor.basic.constant.enable = orig
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/opt.pyc in apply(self, fgraph)
#     181             try:
#     182                 t0 = time.time()
# --> 183                 sub_prof = optimizer.optimize(fgraph)
#     184                 l.append(float(time.time() - t0))
#     185                 sub_profs.append(sub_prof)
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/opt.pyc in optimize(self, fgraph, *args, **kwargs)
#      80             orig = theano.tensor.basic.constant.enable
#      81             theano.tensor.basic.constant.enable = False
# ---> 82             ret = self.apply(fgraph, *args, **kwargs)
#      83         finally:
#      84             theano.tensor.basic.constant.enable = orig
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/opt.pyc in apply(self, fgraph, start_from)
#    1598                     for lopt in self.local_optimizers:
#    1599                         t_opt = time.time()
# -> 1600                         lopt_change = self.process_node(fgraph, node, lopt)
#    1601                         time_opts[lopt] += time.time() - t_opt
#    1602                         if lopt_change:
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/opt.pyc in process_node(self, fgraph, node, lopt)
#    1284         lopt = lopt or self.local_opt
#    1285         try:
# -> 1286             replacements = lopt.transform(node)
#    1287         except Exception, e:
#    1288             if self.failure_callback is not None:
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/opt.pyc in transform(self, node)
#    1101                 return pattern.clone()
#    1102         u = match(self.in_pattern, node.out, unify.Unification(), True,
# -> 1103                   self.pdb)
#    1104         if u:
#    1105             p = self.out_pattern
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/opt.pyc in match(pattern, expr, u, allow_multiple_clients, pdb)
#    1049                     return retry_with_equiv()
#    1050                 for p, v in zip(pattern[1:], expr.owner.inputs):
# -> 1051                     u = match(p, v, u, self.allow_multiple_clients)
#    1052                     if not u:
#    1053                         return False
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/opt.pyc in match(pattern, expr, u, allow_multiple_clients, pdb)
#    1060                         % pattern)
#    1061                 constraint = pattern.get('constraint', lambda expr: True)
# -> 1062                 if constraint(expr):
#    1063                     return match(real_pattern, expr, u,
#    1064                                  pattern.get('allow_multiple_clients',
#
# /usr/local/lib/python2.7/dist-packages/theano/tensor/opt.pyc in _is_minus1(expr)
#    4032         return numpy.allclose(v, -1)
#    4033     except NotScalarConstantError:
# -> 4034         return False
#    4035
#    4036 #1+erf(x)=>erfc(-x)
#
# KeyboardInterrupt:

# %%
one_ddi_family.get_LOO_perfermance('AAONLY', '1')
# Out:
# 1
# SVM
# precision on test:
#  0.493506493506
# recall on test:  0.558823529412
# direct deep learning
# ... building the model
# ... getting the pretraining functions
# ... pre-training the model
# Pre-training layer 0, epoch 0, cost  63.5688703827
# Pre-training layer 0, epoch 1, cost  57.926744179
# Pre-training layer 0, epoch 2, cost
#  52.9103500176
# Pre-training layer 0, epoch 3, cost  48.4728498244
# Pre-training layer 0, epoch 4, cost  44.5676252783
# Pre-training layer 0, epoch 5, cost
#  41.1486432219
# Pre-training layer 0, epoch 6, cost  38.1706009545
# Pre-training layer 0, epoch 7, cost  35.5890538646
# Pre-training layer 0, epoch 8, cost
#  33.3606653607
# Pre-training layer 0, epoch 9, cost  31.4436467359
# Pre-training layer 0, epoch 10, cost  29.7983604444
# Pre-training layer 0, epoch 11, cost
#  28.3879736869
# Pre-training layer 0, epoch 12, cost  27.1790156235
# Pre-training layer 0, epoch 13, cost  26.1417245224
# Pre-training layer 0, epoch 14, cost
#  25.2501424078
# Pre-training layer 0, epoch 15, cost  24.4819826456
# Pre-training layer 0, epoch 16, cost  23.8183350717
# Pre-training layer 0, epoch 17, cost
#  23.2432815655
# Pre-training layer 0, epoch 18, cost  22.7434833952
# Pre-training layer 0, epoch 19, cost  22.3077826561
# Pre-training layer 0, epoch 20, cost
#  21.9268418937
# Pre-training layer 0, epoch 21, cost  21.5928321067
# Pre-training layer 0, epoch 22, cost  21.2991702827
# Pre-training layer 0, epoch 23, cost
#  21.0403025827
# Pre-training layer 0, epoch 24, cost  20.8115270748
# Pre-training layer 0, epoch 25, cost  20.6088494287
# Pre-training layer 0, epoch 26, cost
#  20.4288654427
# Pre-training layer 0, epoch 27, cost  20.26866513
# Pre-training layer 0, epoch 28, cost  20.1257540421
# Pre-training layer 0, epoch 29, cost
#  19.9979883827
# Pre-training layer 0, epoch 30, cost  19.8835212065
# Pre-training layer 0, epoch 31, cost  19.780757587
# Pre-training layer 0, epoch 32, cost
#  19.6883170979
# Pre-training layer 0, epoch 33, cost  19.6050022989
# Pre-training layer 0, epoch 34, cost  19.5297721866
# Pre-training layer 0, epoch 35, cost
#  19.4617197696
# Pre-training layer 0, epoch 36, cost  19.4000530876
# Pre-training layer 0, epoch 37, cost  19.3440791143
# Pre-training layer 0, epoch 38, cost
#  19.2931900806
# Pre-training layer 0, epoch 39, cost  19.2468518368
# Pre-training layer 0, epoch 40, cost  19.2045939315
# Pre-training layer 0, epoch 41, cost
#  19.1660011403
# Pre-training layer 0, epoch 42, cost  19.1307062203
# Pre-training layer 0, epoch 43, cost  19.0983837018
# Pre-training layer 0, epoch 44, cost
#  19.0687445596
# Pre-training layer 0, epoch 45, cost  19.0415316297
# Pre-training layer 0, epoch 46, cost  19.0165156612
# Pre-training layer 0, epoch 47, cost
#  18.9934919073
# Pre-training layer 0, epoch 48, cost  18.972277177
# Pre-training layer 0, epoch 49, cost  18.9527072795
# Pre-training layer 0, epoch 50, cost
#  18.9346348056
# Pre-training layer 0, epoch 51, cost  18.9179271959
# Pre-training layer 0, epoch 52, cost  18.9024650578
# Pre-training layer 0, epoch 53, cost
#  18.8881406944
# Pre-training layer 0, epoch 54, cost  18.8748568166
# Pre-training layer 0, epoch 55, cost  18.862525414
# Pre-training layer 0, epoch 56, cost
#  18.8510667622
# Pre-training layer 0, epoch 57, cost  18.840408549
# Pre-training layer 0, epoch 58, cost  18.8304851035
# Pre-training layer 0, epoch 59, cost
#  18.8212367148
# Pre-training layer 0, epoch 60, cost  18.8126090286
# Pre-training layer 0, epoch 61, cost  18.8045525121
# Pre-training layer 0, epoch 62, cost
#  18.7970219789
# Pre-training layer 0, epoch 63, cost  18.7899761656
# Pre-training layer 0, epoch 64, cost  18.7833773547
# Pre-training layer 0, epoch 65, cost
#  18.7771910376
# Pre-training layer 0, epoch 66, cost  18.7713856137
# Pre-training layer 0, epoch 67, cost  18.7659321202
# Pre-training layer 0, epoch 68, cost
#  18.76080399
# Pre-training layer 0, epoch 69, cost  18.7559768348
# Pre-training layer 0, epoch 70, cost  18.7514282489
# Pre-training layer 0, epoch 71, cost
#  18.7471376333
# Pre-training layer 0, epoch 72, cost  18.7430860366
# Pre-training layer 0, epoch 73, cost  18.7392560119
# Pre-training layer 0, epoch 74, cost
#  18.7356314863
# Pre-training layer 0, epoch 75, cost  18.7321976441
# Pre-training layer 1, epoch 0, cost
#  141.87507339
# Pre-training layer 1, epoch 1, cost
#  128.869708774
# Pre-training layer 1, epoch 2, cost
#  118.042616412
# Pre-training layer 1, epoch 3, cost
#  109.091278647
# Pre-training layer 1, epoch 4, cost
#  101.716215703
# Pre-training layer 1, epoch 5, cost
#  95.6474870944
# Pre-training layer 1, epoch 6, cost
#  90.6528391421
# Pre-training layer 1, epoch 7, cost
#  86.5377923308
# Pre-training layer 1, epoch 8, cost
#  83.1422403949
# Pre-training layer 1, epoch 9, cost
#  80.3355466594
# Pre-training layer 1, epoch 10, cost
#  78.0114033264
# Pre-training layer 1, epoch 11, cost
#  76.0832149159
# Pre-training layer 1, epoch 12, cost
#  74.480276263
# Pre-training layer 1, epoch 13, cost
#  73.144720502
# Pre-training layer 1, epoch 14, cost
#  72.0291096619
# Pre-training layer 1, epoch 15, cost
#  71.0945299101
# Pre-training layer 1, epoch 16, cost
#  70.3090707112
# Pre-training layer 1, epoch 17, cost
#  69.6465917475
# Pre-training layer 1, epoch 18, cost
#  69.0857074209
# Pre-training layer 1, epoch 19, cost
#  68.6089414598
# Pre-training layer 1, epoch 20, cost
#  68.2020204564
# Pre-training layer 1, epoch 21, cost
#  67.8532848743
# Pre-training layer 1, epoch 22, cost
#  67.5532009755
# Pre-training layer 1, epoch 23, cost
#  67.2939594113
# Pre-training layer 1, epoch 24, cost
#  67.0691475049
# Pre-training layer 1, epoch 25, cost
#  66.873483358
# Pre-training layer 1, epoch 26, cost
#  66.7026011328
# Pre-training layer 1, epoch 27, cost
#  66.552878208
# Pre-training layer 1, epoch 28, cost
#  66.4212962791
# Pre-training layer 1, epoch 29, cost
#  66.3053297916
# Pre-training layer 1, epoch 30, cost
#  66.2028562773
# Pre-training layer 1, epoch 31, cost
#  66.1120841942
# Pre-training layer 1, epoch 32, cost
#  66.0314947373
# Pre-training layer 1, epoch 33, cost
#  65.9597947961
# Pre-training layer 1, epoch 34, cost
#  65.8958788128
# Pre-training layer 1, epoch 35, cost
#  65.8387977593
# Pre-training layer 1, epoch 36, cost
#  65.7877338158
# Pre-training layer 1, epoch 37, cost
#  65.7419796282
# Pre-training layer 1, epoch 38, cost
#  65.7009212507
# Pre-training layer 1, epoch 39, cost
#  65.6640240634
# Pre-training layer 1, epoch 40, cost
#  65.6308210966
# Pre-training layer 1, epoch 41, cost
#  65.6009033109
# Pre-training layer 1, epoch 42, cost
#  65.5739114695
# Pre-training layer 1, epoch 43, cost
#  65.5495293113
# Pre-training layer 1, epoch 44, cost
#  65.5274777936
# Pre-training layer 1, epoch 45, cost
#  65.5075102125
# Pre-training layer 1, epoch 46, cost
#  65.4894080517
# Pre-training layer 1, epoch 47, cost
#  65.4729774351
# Pre-training layer 1, epoch 48, cost
#  65.4580460833
# Pre-training layer 1, epoch 49, cost
#  65.4444606921
# Pre-training layer 1, epoch 50, cost
#  65.4320846666
# Pre-training layer 1, epoch 51, cost
#  65.4207961557
# Pre-training layer 1, epoch 52, cost
#  65.4104863418
# Pre-training layer 1, epoch 53, cost
#  65.4010579482
# Pre-training layer 1, epoch 54, cost
#  65.3924239332
# Pre-training layer 1, epoch 55, cost
#  65.3845063445
# Pre-training layer 1, epoch 56, cost
#  65.3772353118
# Pre-training layer 1, epoch 57, cost
#  65.3705481598
# Pre-training layer 1, epoch 58, cost
#  65.3643886252
# Pre-training layer 1, epoch 59, cost
#  65.3587061646
# Pre-training layer 1, epoch 60, cost
#  65.3534553415
# Pre-training layer 1, epoch 61, cost
#  65.3485952838
# Pre-training layer 1, epoch 62, cost
#  65.3440892009
# Pre-training layer 1, epoch 63, cost
#  65.3399039559
# Pre-training layer 1, epoch 64, cost
#  65.3360096844
# Pre-training layer 1, epoch 65, cost
#  65.3323794554
# Pre-training layer 1, epoch 66, cost
#  65.3289889686
# Pre-training layer 1, epoch 67, cost
#  65.3258162853
# Pre-training layer 1, epoch 68, cost
#  65.3228415875
# Pre-training layer 1, epoch 69, cost
#  65.3200469628
# Pre-training layer 1, epoch 70, cost
#  65.3174162126
# Pre-training layer 1, epoch 71, cost
#  65.3149346801
# Pre-training layer 1, epoch 72, cost
#  65.3125890964
# Pre-training layer 1, epoch 73, cost
#  65.3103674428
# Pre-training layer 1, epoch 74, cost
#  65.3082588275
# Pre-training layer 1, epoch 75, cost
#  65.3062533745
# ... getting the finetuning functions
# ... finetunning the model
# epoch 1, minibatch 13/13, validation error 50.000000 %
#  epoch 1, minibatch 13/13, test error of best model 43.333333 %
# epoch 2, minibatch 13/13, validation error 50.000000 %
# epoch 3, minibatch 13/13, validation error 50.000000 %
# epoch 4, minibatch 13/13, validation error 50.000000 %
# epoch 5, minibatch 13/13, validation error 50.000000 %
# epoch 6, minibatch 13/13, validation error 50.000000 %
# epoch 7, minibatch 13/13, validation error 50.000000 %
# epoch 8, minibatch 13/13, validation error 50.000000 %
# epoch 9, minibatch 13/13, validation error 50.000000 %
# epoch 10, minibatch 13/13, validation error 50.000000 %
# hidden_layers_sizes: [100, 100]
# corruption_levels: [0, 0]
# train accuracy:
#  49.8%
# precision:  49.8%
# recall:  100.0%
# testing accuracy:
#  50.0%
# precision:  50.0%
# recall:  100.0%
# deep learning with unlabel data
# ... building the model
# ... getting the pretraining functions
# The pretraining code ran for 0.10m
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-f1a291fe5526> in <module>()
# ----> 1 one_ddi_family.get_LOO_perfermance('AAONLY', '1')
#
# <ipython-input-6-4c735d4c74b6> in get_LOO_perfermance(self, fisher_mode, classifier)
#      95                              hidden_layers_sizes = hidden_layers_sizes, corruption_levels = corruption_levels, batch_size = batch_size , \
#      96                              training_epochs = training_epochs, pretraining_epochs = pretraining_epochs,
# ---> 97                              pretrain_lr = pretrain_lr, finetune_lr=finetune_lr
#      98                  )
#      99                 print 'hidden_layers_sizes:', hidden_layers_sizes
#
# /home/sun/Downloads/contactmatrix/contactmatrixanddeeplearningcode/DL_libs.pyc in trainSda(X_train_minmax, y_train, X_validation_minmax, y_validation, X_test_minmax, y_test, pretraining_X_minmax, hidden_layers_sizes, corruption_levels, batch_size, training_epochs, pretraining_epochs, pretrain_lr, finetune_lr)
#     630
#     631         pretraining_fns = sda.pretraining_functions(train_set_x=pretraining_X,
# --> 632                                                     batch_size=batch_size)
#     633
#     634     print '... pre-training the model'
#
# /home/sun/Downloads/contactmatrix/contactmatrixanddeeplearningcode/DL_libs.pyc in pretraining_functions(self, train_set_x, batch_size)
#     495                                  updates=updates,
#     496                                  givens={self.x: train_set_x[batch_begin:
# --> 497                                                              batch_end]})
#     498             # append `fn` to the list of functions
#     499             pretrain_fns.append(fn)
#
# /usr/local/lib/python2.7/dist-packages/theano/compile/function.pyc in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     221                 allow_input_downcast=allow_input_downcast,
#     222                 on_unused_input=on_unused_input,
# --> 223                 profile=profile)
#     224     # We need to add the flag check_aliased inputs if we have any mutable or
#     225     # borrowed used defined inputs
#
# /usr/local/lib/python2.7/dist-packages/theano/compile/pfunc.pyc in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     510     return orig_function(inputs, cloned_outputs, mode,
#     511             accept_inplace=accept_inplace, name=name, profile=profile,
# --> 512             on_unused_input=on_unused_input)
#     513
#     514
#
# /usr/local/lib/python2.7/dist-packages/theano/compile/function_module.pyc in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input)
#    1309                    accept_inplace=accept_inplace,
#    1310                    profile=profile,
# -> 1311                    on_unused_input=on_unused_input).create(
#    1312                        defaults)
#    1313
#
# /usr/local/lib/python2.7/dist-packages/theano/compile/function_module.pyc in __init__(self, inputs, outputs, mode, accept_inplace, function_builder, profile, on_unused_input)
#    1020             gof.Op.add_stack_trace_on_call = False
#    1021             start_optimizer = time.time()
# -> 1022             optimizer_profile = optimizer(fgraph)
#    1023             end_optimizer = time.time()
#    1024             opt_time = end_optimizer - start_optimizer
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/opt.pyc in __call__(self, fgraph)
#      89         Same as self.optimize(fgraph)
#      90         """
# ---> 91         return self.optimize(fgraph)
#      92
#      93     def add_requirements(self, fgraph):
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/opt.pyc in optimize(self, fgraph, *args, **kwargs)
#      80             orig = theano.tensor.basic.constant.enable
#      81             theano.tensor.basic.constant.enable = False
# ---> 82             ret = self.apply(fgraph, *args, **kwargs)
#      83         finally:
#      84             theano.tensor.basic.constant.enable = orig
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/opt.pyc in apply(self, fgraph)
#     181             try:
#     182                 t0 = time.time()
# --> 183                 sub_prof = optimizer.optimize(fgraph)
#     184                 l.append(float(time.time() - t0))
#     185                 sub_profs.append(sub_prof)
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/opt.pyc in optimize(self, fgraph, *args, **kwargs)
#      80             orig = theano.tensor.basic.constant.enable
#      81             theano.tensor.basic.constant.enable = False
# ---> 82             ret = self.apply(fgraph, *args, **kwargs)
#      83         finally:
#      84             theano.tensor.basic.constant.enable = orig
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/opt.pyc in apply(self, fgraph, start_from)
#    1556                 fgraph.change_tracker.reset()
#    1557                 t_opt = time.time()
# -> 1558                 gopt.apply(fgraph)
#    1559                 time_opts[gopt] += time.time() - t_opt
#    1560                 if fgraph.change_tracker.changed:
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/opt.pyc in apply(self, fgraph, start_from)
#    1556                 fgraph.change_tracker.reset()
#    1557                 t_opt = time.time()
# -> 1558                 gopt.apply(fgraph)
#    1559                 time_opts[gopt] += time.time() - t_opt
#    1560                 if fgraph.change_tracker.changed:
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/opt.pyc in apply(self, fgraph, start_from)
#    1359         nb_nodes_start = len(fgraph.apply_nodes)
#    1360         t0 = time.time()
# -> 1361         q = deque(graph.io_toposort(fgraph.inputs, start_from))
#    1362         io_t = time.time() - t0
#    1363
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/graph.pyc in io_toposort(inputs, outputs, orderings)
#     807         return rval
#     808
# --> 809     topo = general_toposort(outputs, deps)
#     810     return [o for o in topo if isinstance(o, Apply)]
#     811
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/graph.pyc in general_toposort(r_out, deps, debug_print)
#     748     assert isinstance(r_out, (tuple, list, deque))
#     749
# --> 750     reachable, clients = stack_search(deque(r_out), _deps, 'dfs', True)
#     751     sources = deque([r for r in reachable if not deps_cache.get(r, None)])
#     752
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/graph.pyc in stack_search(start, expand, mode, build_inv)
#     524             rval_list.append(l)
#     525             rval_set.add(id(l))
# --> 526             expand_l = expand(l)
#     527             if expand_l:
#     528                 if build_inv:
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/graph.pyc in _deps(io)
#     734     def _deps(io):
#     735         if io not in deps_cache:
# --> 736             d = deps(io)
#     737             if d:
#     738                 if not isinstance(d, (list, OrderedSet)):
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/graph.pyc in deps(obj)
#     802             elif isinstance(obj, Apply):
#     803                 rval = list(obj.inputs)
# --> 804             rval.extend(orderings.get(obj, []))
#     805         else:
#     806             assert not orderings.get(obj, [])
#
# KeyboardInterrupt:

# %%
data =a
a = data[:, 20:227]
b = data[:, 247:454]
X = np.hstack((a,b))
print a.shape, b.shape, X.shape,  X
